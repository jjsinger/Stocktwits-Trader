# %%
from stocktwits_secrets import client_secret, client_id, redirect_url, access_token
from alpaca import make_order, get_account_metadata, get_buying_power, get_asset_price

import csv
import requests
import json
import os
import yfinance as yf
import time
import pandas as pd

import emojis
import datetime as dt
import stockquotes as sq

import pprint
from http_request_randomizer.requests.proxy.requestProxy import RequestProxy
from html5print import HTMLBeautifier

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip uninstall yfinance

# %%
if send_email
    # %run "email.ipynb"

# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/rodrigobercini/yfinance.git

# %%
# !{sys.executable} -m pip install git+https://github.com/rodrigobercini/yfinance.git
import yfinance as yf
msft = yf.Ticker("MSFT")
print(msft.quarterly_balance_sheet)
print('\n')
print(msft.earnings)
print('\n')
print(msft.cashflow)

# %%
# asdf

# I want to grab one stock

apple = yf.Ticker('AAPL')
# print(dict(apple.info))

# %%
print(apple.financials)
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
assets = pd.DataFrame(get_asset_price())
assets_active = assets[assets.status == 'active']

# %%
# Information available through alpaca API
assets.columns
# Out:
# Index(['id', 'class', 'exchange', 'symbol', 'name', 'status', 'tradable',
#        'marginable', 'shortable', 'easy_to_borrow', 'fractionable'],
#       dtype='object')

# %%
# 
assets[['symbol', 'name', 'exchange']].describe()
# Out:
#        symbol   name exchange
# count   11706  11706    11706
# unique  11657  11009        6
# top       VIV          NASDAQ
# freq        2    598     4833

# %%
# This is a list of stock exchanges
set(assets['exchange'])
# Out:
# {'AMEX', 'ARCA', 'BATS', 'NASDAQ', 'NYSE', 'OTC'}

# %%
len(assets) # 11644
# Out:
# 11706

# %%
ls_assets = set(list(assets['symbol']))

# %%
stock_dict = {}

for x in ls_assets:
    print('Stock: ', x)
    stock_dict[x] = yf.Ticker(x)
# Out:
# Stock:  BBCP
# Stock:  MUDS
# Stock:  MLPS
# Stock:  ARBG
# Stock:  COWN
# Stock:  LFUS
# Stock:  LMPX
# Stock:  OLLI
# Stock:  DXD
# Stock:  GRF
# Stock:  SBEAU
# Stock:  ARYA
# Stock:  CTRL
# Stock:  MCBC
# Stock:  PAICU
# Stock:  ESBA
# Stock:  BFY
# Stock:  CGEN
# Stock:  MCEP
# Stock:  DMAC
# Stock:  WB
# Stock:  TUR
# Stock:  TAT
# Stock:  FCAL
# Stock:  BBAX
# Stock:  ALL-G
# Stock:  ALTA
# Stock:  EMD
# Stock:  HEGD
# Stock:  JMF
# Stock:  RBKB
# Stock:  TRX
# Stock:  NAO
# Stock:  HTBX
# Stock:  IPO
# Stock:  KRG
# Stock:  VIIAU
# Stock:  PLYM-A
# Stock:  HFRO
# Stock:  MUJ
# Stock:  EVV
# Stock:  FFBC
# Stock:  PSMR
# Stock:  NEWM
# Stock:  DIVS
# Stock:  PMPT
# Stock:  ATSPU
# Stock:  WTID
# Stock:  SPGI
# Stock:  FUT
# Stock:  NIE
# Stock:  LRN
# Stock:  VIACA
# Stock:  HEWL
# Stock:  GLIF
# Stock:  KTOS
# Stock:  GARD
# Stock:  SBI
# Stock:  DCRN
# Stock:  JULZ
# Stock:  BIOT
# Stock:  FLNG
# Stock:  RF
# Stock:  BHVN
# Stock:  PYN
# Stock:  MYFW
# Stock:  KMDA
# ...

# %%
stock_dict
# Out:
# {'BBCP': yfinance.Ticker object <BBCP>,
#  'MUDS': yfinance.Ticker object <MUDS>,
#  'MLPS': yfinance.Ticker object <MLPS>,
#  'ARBG': yfinance.Ticker object <ARBG>,
#  'COWN': yfinance.Ticker object <COWN>,
#  'LFUS': yfinance.Ticker object <LFUS>,
#  'LMPX': yfinance.Ticker object <LMPX>,
#  'OLLI': yfinance.Ticker object <OLLI>,
#  'DXD': yfinance.Ticker object <DXD>,
#  'GRF': yfinance.Ticker object <GRF>,
#  'SBEAU': yfinance.Ticker object <SBEAU>,
#  'ARYA': yfinance.Ticker object <ARYA>,
#  'CTRL': yfinance.Ticker object <CTRL>,
#  'MCBC': yfinance.Ticker object <MCBC>,
#  'PAICU': yfinance.Ticker object <PAICU>,
#  'ESBA': yfinance.Ticker object <ESBA>,
#  'BFY': yfinance.Ticker object <BFY>,
#  'CGEN': yfinance.Ticker object <CGEN>,
#  'MCEP': yfinance.Ticker object <MCEP>,
#  'DMAC': yfinance.Ticker object <DMAC>,
#  'WB': yfinance.Ticker object <WB>,
#  'TUR': yfinance.Ticker object <TUR>,
#  'TAT': yfinance.Ticker object <TAT>,
#  'FCAL': yfinance.Ticker object <FCAL>,
# ...

# %%
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
s_and_p_500 = table[0]

# %%
s_and_p_500.columns
# Out:
# Index(['Symbol', 'Security', 'SEC filings', 'GICS Sector', 'GICS Sub-Industry',
#        'Headquarters Location', 'Date first added', 'CIK', 'Founded'],
#       dtype='object')

# %%
# for x in s_and_p_500['symbol']:
#     print(yf.Ticker(x))

# %%
len(list(s_and_p_500['Symbol']))
# Out:
# 505

# %%
s_and_p_500.columns = ['symbol', 'Security', 'SEC filings', 'GICS Sector', 'GICS Sub-Industry',
'Headquarters Location', 'Date first added', 'CIK', 'Founded']

# %%
assets.columns = ['id', 'class', 'exchange', 'symbol', 'name', 'status', 'tradable',
       'marginable', 'shortable', 'easy_to_borrow', 'fractionable']

# %%
joined = pd.merge(s_and_p_500, assets, how='inner', on='symbol')
# joined.to_csv("C:\\Users\Snowbird\Documents\Joshua\Personal\Technical\GitHub\Stocktwits\sp_500_assets.csv", index=False)

# %%
len(joined.columns)
# Out:
# 19

# %% [markdown]
# ### Flatten Json Ticker
# - Get 1 ticker
# - Flatten Json Object
# - Export to excel

# %%
# Get listed assets
listed_assets = []
delisted_assets = []

for x in ls_assets:
    if 'DELISTED' not in x:
        listed_assets.append(x)
    else:
        delisted_assets.append(x)

# %%
list(ls_assets)[0:5]
# Out:
# ['BBCP', 'MUDS', 'MLPS', 'ARBG', 'COWN']

# %%
yf.Tickers(['AQNB', 'TPC', 'LASR'])
# Out:
# yfinance.Tickers object <AQNB,TPC,LASR>

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame()
# df1 = {}
for x in yf.Tickers(['AQNB', 'TPC', 'LASR']).tickers:
    df1 = x
    df = pd.DataFrame([df1])
#     df = pd.json_normalize(df1.info)

# %%
str_of_assets = ",".join(listed_assets[0:10])
tickers = yf.Tickers(str_of_assets)
tickers
# Out:
# yfinance.Tickers object <BBCP,MUDS,MLPS,ARBG,COWN,LFUS,LMPX,OLLI,DXD,GRF>

# %%
master_df = pd.DataFrame()
str_of_assets = ",".join(listed_assets)
tickers = yf.Tickers('JNJ, PFE, UNH, ABT, ABBV, MRK, MDT, DHR, LLY')

for tick in tickers.tickers:
    for one_asset in listed_assets:
        if tick.info['symbol'] == one_asset:
            print(type([tick.info]))
            one_row = pd.DataFrame([tick.info])
            
            #Concat dataframes
            frames = [master_df, one_row]
            master_df = pd.concat(frames)
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
master_df['profitMargins']
# Out:
# 0    0.17948
# 0    0.24001
# 0    0.06421
# 0    0.15330
# 0    0.10278
# 0    0.14634
# 0    0.10965
# 0    0.19166
# 0    0.23906
# Name: profitMargins, dtype: float64

# %%
list(master_df.columns)
# Out:
# ['zip',
#  'sector',
#  'fullTimeEmployees',
#  'longBusinessSummary',
#  'city',
#  'phone',
#  'state',
#  'country',
#  'companyOfficers',
#  'website',
#  'maxAge',
#  'address1',
#  'industry',
#  'previousClose',
#  'regularMarketOpen',
#  'twoHundredDayAverage',
#  'trailingAnnualDividendYield',
#  'payoutRatio',
#  'volume24Hr',
#  'regularMarketDayHigh',
#  'navPrice',
#  'averageDailyVolume10Day',
#  'totalAssets',
#  'regularMarketPreviousClose',
#  'fiftyDayAverage',
#  'trailingAnnualDividendRate',
#  'open',
#  'toCurrency',
#  'averageVolume10days',
#  'expireDate',
#  'yield',
#  'algorithm',
#  'dividendRate',
#  'exDividendDate',
#  'beta',
#  'circulatingSupply',
#  'startDate',
#  'regularMarketDayLow',
#  'priceHint',
#  'currency',
#  'trailingPE',
#  'regularMarketVolume',
#  'lastMarket',
#  'maxSupply',
#  'openInterest',
#  'marketCap',
#  'volumeAllCurrencies',
#  'strikePrice',
#  'averageVolume',
#  'priceToSalesTrailing12Months',
#  'dayLow',
#  'ask',
# ...

# %%
master_df = pd.DataFrame()
condensed = list(joined['symbol'])
str_of_assets = ",".join(condensed)
str_of_assets
# Out:
# 'MMM,ABT,ABBV,ABMD,ACN,ATVI,ADBE,AMD,AAP,AES,AFL,A,APD,AKAM,ALK,ALB,ARE,ALXN,ALGN,ALLE,LNT,ALL,GOOGL,GOOG,MO,AMZN,AMCR,AEE,AAL,AEP,AXP,AIG,AMT,AWK,AMP,ABC,AME,AMGN,APH,ADI,ANSS,ANTM,AON,AOS,APA,AAPL,AMAT,APTV,ADM,ANET,AJG,AIZ,T,ATO,ADSK,ADP,AZO,AVB,AVY,BKR,BLL,BAC,BK,BAX,BDX,BRK.B,BBY,BIO,BIIB,BLK,BA,BKNG,BWA,BXP,BSX,BMY,AVGO,BR,BF.B,CHRW,COG,CDNS,CZR,CZR,CPB,COF,CAH,KMX,CCL,CARR,CTLT,CAT,CBOE,CBRE,CDW,CE,CNC,CNP,CERN,CF,SCHW,CHTR,CVX,CMG,CB,CHD,CI,CINF,CTAS,CSCO,C,CFG,CTXS,CLX,CME,CMS,KO,CTSH,CL,CMCSA,CMA,CAG,COP,ED,STZ,COO,CPRT,GLW,CTVA,COST,CCI,CSX,CMI,CVS,DHI,DHR,DRI,DVA,DE,DAL,XRAY,DVN,DXCM,FANG,DLR,DFS,DISCA,DISCK,DISH,DG,DLTR,D,DPZ,DOV,DOW,DTE,DUK,DRE,DD,DXC,EMN,ETN,EBAY,ECL,EIX,EW,EA,EMR,ENPH,ETR,EOG,EFX,EQIX,EQR,ESS,EL,ETSY,EVRG,ES,RE,EXC,EXPE,EXPD,EXR,XOM,FFIV,FB,FAST,FRT,FDX,FIS,FITB,FE,FRC,FISV,FLT,FLIR,FMC,F,FTNT,FTV,FBHS,FOXA,FOX,BEN,FCX,GPS,GRMN,IT,GNRC,GD,GE,GIS,GM,GPC,GILD,GL,GPN,GS,GWW,HAL,HBI,HIG,HAS,HCA,PEAK,HSIC,HSY,HES,HPE,HLT,HFC,HOLX,HD,HON,HRL,HST,HWM,HPQ,HUM
# ...

# %%
master_df = pd.DataFrame()
condensed = list(joined['symbol'])
str_of_assets = ",".join(condensed)
tickers = yf.Tickers(str_of_assets)

for tick in tickers.tickers:
    for one_asset in listed_assets:
        if tick.info['symbol'] == one_asset:
            print(one_asset)
            one_row = pd.DataFrame([tick.info])
            
            #Concat dataframes
            frames = [master_df, one_row]
            master_df = pd.concat(frames)
# Out:
# MMM
# ABT
# ABBV
# ABMD
# ACN
# ATVI
# ADBE
# AMD
# AAP
# AES
# AFL
# A
# APD
# AKAM
# ALK
# ALB
# ARE
# ALXN
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# ABC
# AME
# AMGN
# APH
# ADI
# ANSS
# ANTM
# AON
# AOS
# APA
# AAPL
# AMAT
# APTV
# ADM
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK
# ADP
# AZO
# AVB
# AVY
# BKR
# BLL
# BAC
# BK
# BAX
# BDX
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-215-60dd2395cd17> in <module>
#       6 for tick in tickers.tickers:
#       7     for one_asset in listed_assets:
# ----> 8         if tick.info['symbol'] == one_asset:
#       9             print(one_asset)
#      10             one_row = pd.DataFrame([tick.info])
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\yfinance\ticker.py in info(self)
#     136     @property
#     137     def info(self):
# ...

# %%
master_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5d4874fb6ad5> in <module>
# ----> 1 master_df.columns
#
# NameError: name 'master_df' is not defined

# %%
master_df[master_df['sector'] == 'Healthcare'].head()
# Out:
#           zip      sector  fullTimeEmployees  \
# 0       08933  Healthcare             134500
# 0       10017  Healthcare              78500
# 0       55343  Healthcare             330000
# 0  60064-6400  Healthcare             109000
# 0  60064-6400  Healthcare              47000
#
#                                  longBusinessSummary           city  \
# 0  Johnson & Johnson researches and develops, man...  New Brunswick
# 0  Pfizer Inc. discovers, develops, manufactures,...       New York
# 0  UnitedHealth Group Incorporated operates as a ...     Minnetonka
# 0  Abbott Laboratories discovers, develops, manuf...  North Chicago
# 0  AbbVie Inc. discovers, develops, manufactures,...  North Chicago
#
#           phone state        country companyOfficers  \
# 0  732 524 0400    NJ  United States              []
# 0  212 733 2323    NY  United States              []
# 0  952-936-1300    MN  United States              []
# 0  224 667 6100    IL  United States              []
# ...

# %%
# Do not delete!!
master_df.count()
# Out:
# zip                         65
# sector                      65
# fullTimeEmployees           64
# longBusinessSummary         65
# city                        65
#                             ..
# fax                         17
# underlyingSymbol             0
# underlyingExchangeSymbol     0
# headSymbol                   0
# uuid                        52
# Length: 129, dtype: int64

# %%
master_df.to_csv("C:\\Users\Snowbird\Documents\Joshua\Personal\Technical\GitHub\Stocktwits\sp_500_subset_with_info.csv", index=False)

# %%
master_df[master_df['sector'] == 'Healthcare'].to_csv("C:\\Users\Snowbird\Documents\Joshua\Personal\Technical\GitHub\Stocktwits\sp_500_HC_with_info.csv", index=False)

# %% [markdown]
# ### Check

# %%
joined.groupby('GICS Sector').count()['symbol']
# Out:
# GICS Sector
# Communication Services    26
# Consumer Discretionary    64
# Consumer Staples          32
# Energy                    23
# Financials                65
# Health Care               62
# Industrials               76
# Information Technology    75
# Materials                 28
# Real Estate               29
# Utilities                 28
# Name: symbol, dtype: int64

# %%
joined[joined['Headquarters Location'] == 'Salt Lake City, Utah']
# Out:
#     symbol             Security SEC filings  GICS Sector  GICS Sub-Industry  \
# 183    EXR  Extra Space Storage     reports  Real Estate  Specialized REITs
# 506   ZION        Zions Bancorp     reports   Financials     Regional Banks
#
#     Headquarters Location Date first added      CIK Founded  \
# 183  Salt Lake City, Utah       2016-01-19  1289490    1977
# 506  Salt Lake City, Utah       2001-06-22   109380    1873
#
#                                        id      class exchange  \
# 183  95631989-09cd-4964-860e-f766dfba5081  us_equity     NYSE
# 506  48cbc81a-1c23-4356-92b0-207871c6f6a3  us_equity   NASDAQ
#
#                                        name  status  tradable  marginable  \
# 183               Extra Space Storage, Inc.  active      True        True
# 506  Zions Bancorporation N.A. Common Stock  active      True        True
#
#      shortable  easy_to_borrow  fractionable
# 183       True            True          True
# ...

# %%
joined[joined['GICS Sector'] == 'Energy']
# Out:
#     symbol                   Security SEC filings GICS Sector  \
# 44     APA            APA Corporation     reports      Energy
# 59     BKR            Baker Hughes Co     reports      Energy
# 80     COG            Cabot Oil & Gas     reports      Energy
# 102    CVX              Chevron Corp.     reports      Energy
# 122    COP             ConocoPhillips     reports      Energy
# 141    DVN               Devon Energy     reports      Energy
# 143   FANG         Diamondback Energy     reports      Energy
# 170    EOG              EOG Resources     reports      Energy
# 184    XOM          Exxon Mobil Corp.     reports      Energy
# 220    HAL            Halliburton Co.     reports      Energy
# 228    HES           Hess Corporation     reports      Energy
# 231    HFC         HollyFrontier Corp     reports      Energy
# 276    KMI              Kinder Morgan     reports      Energy
# 301    MRO         Marathon Oil Corp.     reports      Energy
# ...
