# %%
from stocktwits_secrets import client_secret, client_id, redirect_url, access_token
from alpaca import make_order, get_account_metadata, get_buying_power, get_asset_price

import csv
import requests
import json
import os
import yfinance as yf
import time
import pandas as pd

import emojis
import datetime as dt
import stockquotes as sq

import pprint
from http_request_randomizer.requests.proxy.requestProxy import RequestProxy
from html5print import HTMLBeautifier

from yahoo_finance import Share
import yahoo_finance as yfin

# %%
# Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install stockquotes

# %%
# asdf

# I want to grab one stock

apple = yf.Ticker('AAPL')
apple.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 147000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store, that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408-996-1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'previousClose': 133.58,
#  'regularMarketOpen': 136.47,
#  'twoHundredDayAverage': 125.72613,
#  'trailingAnnualDividendYield': 0.0060413233,
#  'payoutRatio': 0.2177,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 137.07,
#  'navPrice': None,
#  'averageDailyVolume10Day': 80913414,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 133.58,
#  'fiftyDayAverage': 127.418236,
#  'trailingAnnualDividendRate': 0.807,
#  'open': 136.47,
#  'toCurrency': None,
#  'averageVolume10days': 80913414,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 0.82,
#  'exDividendDate': 1612483200,
#  'beta': 1.219525,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 132.45,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 36.202873,
#  'regularMarketVolume': 151101053,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2240875593728,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 100094588,
#  'priceToSalesTrailing12Months': 7.6185274,
#  'dayLow': 132.45,
#  'ask': 0,
#  'ytdReturn': None,
#  'askSize': 900,
#  'volume': 151101053,
#  'fiftyTwoWeekHigh': 145.09,
#  'forwardPE': 25.76834,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.39,
#  'fiftyTwoWeekLow': 71.4625,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0061000003,
#  'bidSize': 1000,
#  'dayHigh': 137.07,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'messageBoardId': 'finmb_24937',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 7.744,
#  'beta3Year': None,
#  'profitMargins': 0.21735,
#  'enterpriseToEbitda': 26.747,
#  '52WeekChange': 0.84841037,
#  'morningStarRiskRating': None,
#  'forwardEps': 5.18,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 16788100096,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 3.936,
#  'sharesShort': 127937929,
#  'sharesPercentSharesOut': 0.0076,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1601078400,
#  'heldPercentInstitutions': 0.59765,
#  'netIncomeToCommon': 63929999360,
#  'trailingEps': 3.687,
#  'lastDividendValue': 0.205,
#  'SandP52WeekChange': 0.47778475,
#  'priceToBook': 33.9126,
#  'heldPercentInsiders': 0.00075999997,
#  'nextFiscalYearEnd': 1664150400,
#  'mostRecentQuarter': 1608940800,
#  'shortRatio': 1.29,
#  'sharesShortPreviousMonthDate': 1615766400,
#  'floatShares': 16770636380,
#  'enterpriseValue': 2277770788864,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '4:1',
#  'legalType': None,
#  'lastDividendDate': 1612483200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.293,
#  'dateShortInterest': 1618444800,
#  'pegRatio': 1.6,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0076,
#  'sharesShortPriorMonth': 107011007,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 136.47,
#  'logo_url': 'https://logo.clearbit.com/apple.com'}

# %%
assets = pd.DataFrame(get_asset_price())
assets_active = assets[assets.status == 'active']

# %%
# Information available through alpaca API
assets.columns
# Out:
# Index(['id', 'class', 'exchange', 'symbol', 'name', 'status', 'tradable',
#        'marginable', 'shortable', 'easy_to_borrow', 'fractionable'],
#       dtype='object')

# %%
# 
assets[['symbol', 'name', 'exchange']]
# Out:
#       symbol                                               name exchange
# 0        AAA                    AAF First Priority CLO Bond ETF     ARCA
# 1       AAAU             Goldman Sachs Physical Gold ETF Shares     ARCA
# 2      AAC.U  Ares Acquisition Corporation Units, each consi...     NYSE
# 3       AACG   ATA Creativity Global American Depositary Shares   NASDAQ
# 4       AACQ       Artius Acquisition Inc. Class A Common Stock   NASDAQ
# ...      ...                                                ...      ...
# 11639   MVIS                     MicroVision, Inc. Common Stock   NASDAQ
# 11640   OKTA                    Okta, Inc. Class A Common Stock   NASDAQ
# 11641   PINS               Pinterest, Inc. Class A Common Stock     NYSE
# 11642    AMC                   AMC ENTERTAINMENT HOLDINGS, INC.     NYSE
# 11643   SPOT                            Spotify Technology S.A.     NYSE
#
# [11644 rows x 3 columns]

# %%
# This is a list of stock exchanges
set(assets['exchange'])
# Out:
# {'AMEX', 'ARCA', 'BATS', 'NASDAQ', 'NYSE', 'OTC'}

# %%
len(assets) # 11644
# Out:
# 11644

# %%
ls_assets = set(list(assets['symbol']))
ls_assets
# Out:
# ['AAA',
#  'AAAU',
#  'AAC.U',
#  'AACG',
#  'AACQ',
#  'AACQU',
#  'AADR',
#  'AAIC',
#  'AAIC-B',
#  'AAIC-C',
#  'AAL',
#  'AAMC',
#  'AAME',
#  'AAN',
#  'VVC',
#  'AAOI',
#  'AAP',
#  'AAQC.U',
#  'AAU',
#  'AAVVF',
#  'ILG',
#  'HCRF',
#  'TPGH_DELISTED',
#  'AAWW',
#  'VIIZ',
#  'C016626',
#  'AB',
#  'ABBV',
#  'ABC',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEQ',
#  'BSWN',
#  'TSRO',
#  'HEFV',
#  'H015802',
#  'ABEV',
#  'ABG',
#  'ABGI',
#  'ABILF',
#  'ABM',
#  'ABMD',
#  'ABNB',
#  'ABR',
#  'ABR-A',
#  'ABR-B',
#  'ABR-C',
#  'ABST',
#  'ABTX',
#  'ABUS',
#  'AC',
#  'ACA',
#  'ACAC',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACB',
#  'ACBAU',
#  'ACBI',
#  'ACCD',
#  'ACCO',
#  'ACEL',
#  'ACER',
#  'ACES',
#  'ACET',
#  'ACEV',
#  'ACEVU',
#  'ACGL',
#  'ACGLO',
#  'ACGLP',
#  'ACH',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACI',
#  'ACIC',
#  'ACIC.U',
#  'ACII',
#  'ACII.U',
#  'ACIU',
#  'ACIW',
#  'ACKIT',
#  'ACKIU',
#  'ACLS',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACND',
#  'ACND.U',
#  'ACP',
#  'ACQRU',
#  'ACR',
#  'ACR-C',
#  'ACRE',
#  'ACRS',
#  'ACSG',
#  'ACSI',
#  'ACST',
#  'ACTC',
#  'ACTCU',
#  'ACTG',
#  'ACTV',
#  'ACU',
#  'ACV',
#  'ACVA',
#  'ACWF',
#  'ACWI',
#  'ACWV',
#  'ACY',
#  'ADAP',
#  'ADBE',
#  'ADC',
#  'ADER',
#  'ADES',
#  'ADEX',
#  'ADF.U',
#  'ADFI',
#  'ADIL',
#  'ADIV',
#  'ADM',
#  'ADMA',
#  'ADME',
#  'ADMS',
#  'ADN',
#  'ADNT',
#  'ADOC',
#  'ADOCR',
#  'ADP',
#  'ADRA',
#  'ADRA.U',
#  'ADRE',
#  'ADS',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADX',
#  'ADXN',
#  'ADXS',
#  'ADYX',
#  'ADZCF',
#  'AE',
#  'AEAC',
#  'AEACU',
#  'AEB',
#  'AEE',
#  'AEF',
#  'AEFC',
#  'AEG',
#  'AEGN',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEL-A',
#  'AEL-B',
#  'AEM',
#  'AEMD',
#  'AENZ',
#  'AEO',
#  'AEP',
#  'AEPPL',
#  'AEPPZ',
#  'AER',
#  'AERI',
#  'AES',
#  'AESE',
#  'AESR',
#  'AEVA',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFB',
#  'AFBI',
#  'AFCG',
#  'AFG',
#  'AFGB',
#  'AFGD',
#  'AFGE',
#  'AFHBL',
#  'AFHIF',
#  'AFI',
#  'AFIB',
#  'AFIN',
#  'AFINO',
#  'AFINP',
#  'AFK',
#  'AFL',
#  'AFMC',
#  'AFMD',
#  'AFRM',
#  'AFSM',
#  'AFT',
#  'AFYA',
#  'AG',
#  'AGAC',
#  'AGAC.U',
#  'AGBA',
#  'AGBAU',
#  'AGC',
#  'AGCB',
#  'AGCO',
#  'AGCUU',
#  'AGE',
#  'AGEN',
#  'AGFS',
#  'AGFXF',
#  'AGFY',
#  'AGGRU',
#  'AGGY',
#  'AGI',
#  'AGIO',
#  'AGL',
#  'AGM',
#  'AGM-C',
#  'AGM-D',
#  'AGM-E',
#  'AGM-F',
#  'AGM.A',
#  'AGMH',
#  'AGNC',
#  'AGNCM',
#  'AGNCN',
#  'AGNCP',
#  'AGNG',
#  'AGO',
#  'AGO-B',
#  'AGO-F',
#  'AGQ',
#  'AGRX',
#  'AGS',
#  'AGT',
#  'AGTC',
#  'AGTI',
#  'AGYS',
#  'AGZ',
#  'AGZD',
#  'AHAC',
#  'AHACU',
#  'AHCO',
#  'AHH',
#  'AHH-A',
#  'AHL-C',
#  'AHL-D',
#  'AHL-E',
#  'AHPI',
#  'AHT',
#  'AHT-D',
#  'AHT-F',
#  'AHT-G',
#  'AHT-I',
#  'AI',
#  'AIC',
#  'AIEQ',
#  'AIF',
#  'AIG',
#  'AIG-A',
#  'AIH',
#  'AIHS',
#  'AIIQ',
#  'AIKI',
#  'AIM',
#  'AIMC',
#  'AIN',
#  'AINC',
#  'AINV',
#  'AIO',
#  'AIQ',
#  'AIR',
#  'AIRG',
#  'AIRI',
#  'AIRR',
#  'AIRT',
#  'AIRTP',
#  'AIV',
#  'AIW',
#  'AIZ',
#  'AIZN',
#  'AJAX.U',
#  'AJG',
#  'AJRD',
#  'AJX',
#  'AJXA',
#  'AKAM',
#  'AKAOQ',
#  'AKBA',
#  'AKIC',
#  'AKICU',
#  'AKO.A',
#  'AKO.B',
#  'AKR',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKUS',
#  'AKYA',
#  'AL',
#  'AL-A',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALB',
#  'ALBO',
#  'ALC',
#  'ALCO',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALEX',
#  'ALFA',
#  'ALG',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALIM',
#  'ALIN-A',
#  'ALIN-B',
#  'ALIN-E',
#  'ALJJ',
#  'ALK',
#  'ALKS',
#  'ALKT',
#  'ALL',
#  'ALL-B',
#  'ALL-G',
#  'ALL-H',
#  'ALL-I',
#  'ALLE',
#  'ALLK',
#  'ALLO',
#  'ALLT',
#  'ALLY',
#  'ALLY-A',
#  'ALNA',
#  'ALNY',
#  'ALOT',
#  'ALP-Q',
#  'ALPN',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALSK',
#  'ALSN',
#  'ALT',
#  'ALTG-A',
#  'ALTL',
#  'ALTM',
#  'ALTO',
#  'ALTR',
#  'ALTS',
#  'ALTU',
#  'ALTUU',
#  'ALTY',
#  'ALUS',
#  'ALUS.U',
#  'ALV',
#  'ALVR',
#  'ALX',
#  'ALXN',
#  'ALXO',
#  'ALYA',
#  'AM',
#  'AMAL',
#  'AMAOU',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMBO',
#  'AMCA',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMER',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMH-D',
#  'AMH-E',
#  'AMH-G',
#  'AMH-H',
#  'AMHC',
#  'AMHCU',
#  'AMJ',
#  'AMK',
#  'AMKR',
#  'AMLP',
#  'AMN',
#  'AMNA',
#  'AMNB',
#  'AMND',
#  'AMOM',
#  'AMOT',
#  'AMOV',
#  'AMP',
#  'AMPE',
#  'AMPG',
#  'AMPH',
#  'AMPI',
#  'AMPI.U',
#  'AMPY',
#  'AMR',
#  'AMRB',
#  'AMRC',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMRX',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMT',
#  'AMTB',
#  'AMTI',
#  'AMTR',
#  'AMTX',
#  'AMUB',
#  'AMWD',
#  'AMYT',
#  'AN',
#  'ANAB',
#  'ANAC',
#  'ANAC.U',
#  'ANDA',
#  'ANDAR',
#  'ANDAU',
#  'ANDE',
#  'ANET',
#  'ANEW',
#  'ANF',
#  'ANFIF',
#  'ANGI',
#  'ANGL',
#  'ANGN',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANPC',
#  'ANSS',
#  'ANTE',
#  'ANTH',
#  'ANTM',
#  'ANVS',
#  'ANY',
#  'ANZUU',
#  'AOA',
#  'AOD',
#  'AOK',
#  'AOM',
#  'AON',
#  'AONE',
#  'AONE.U',
#  'AOR',
#  'AOS',
#  'AOSL',
#  'AOUT',
#  'AP',
#  'APA',
#  'APAM',
#  'APD',
#  'APEI',
#  'APEN',
#  'APG',
#  'APGB',
#  'APGB.U',
#  'APH',
#  'APHA',
#  'API',
#  'APLE',
#  'APLS',
#  'APLT',
#  'APM',
#  'APO',
#  'APO-A',
#  'APO-B',
#  'APOG',
#  'APOP',
#  'APP',
#  'APPF',
#  'APPH',
#  'APPN',
#  'APPS',
#  'APR',
#  'APRE',
#  'APRN',
#  'APRZ',
#  'APSG',
#  'APSG.U',
#  'APT',
#  'APTO',
#  'APTS',
#  'APTV',
#  'APTV-A',
#  'APTX',
#  'APVO',
#  'APWC',
#  'APXT',
#  'APXTU',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQN',
#  'AQNA',
#  'AQNB',
#  'AQST',
#  'AQUA',
#  'AQWA',
#  'AR',
#  'ARAV',
#  'ARAY',
#  'ARB',
#  'ARBG',
#  'ARBGU',
#  'ARC',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCH',
#  'ARCM',
#  'ARCO',
#  'ARCT',
#  'ARCW',
#  'ARD',
#  'ARDC',
#  'ARDS',
#  'ARDX',
#  'ARE',
#  'AREC',
#  'ARES',
#  'ARES-A',
#  'ARGD',
#  'ARGO',
#  'ARGO-A',
#  'ARGT',
#  'ARGX',
#  'ARI',
#  'ARKF',
#  'ARKG',
#  'ARKK',
#  'ARKO',
#  'ARKQ',
#  'ARKR',
#  'ARKW',
#  'ARKX',
#  'ARL',
#  'ARLO',
#  'ARLP',
#  'ARMK',
#  'ARMP',
#  'ARMR',
#  'ARNA',
#  'ARNC',
#  'AROC',
#  'AROW',
#  'ARPO',
#  'ARQT',
#  'ARR',
#  'ARR-C',
#  'ARRW',
#  'ARRY',
#  'ARTL',
#  'ARTNA',
#  'ARTW',
#  'ARVL',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'ARYA',
#  'ARYD',
#  'ASA',
#  'ASAI',
#  'ASAN',
#  'ASAQ',
#  'ASAQ.U',
#  'ASAX',
#  'ASAXU',
#  'ASB',
#  'ASB-D',
#  'ASB-E',
#  'ASB-F',
#  'ASC',
#  'ASEA',
#  'ASET',
#  'ASG',
#  'ASGI',
#  'ASGN',
#  'ASH',
#  'ASHR',
#  'ASHS',
#  'ASHX',
#  'ASIX',
#  'ASLE',
#  'ASLN',
#  'ASM',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASPC',
#  'ASPCU',
#  'ASPL',
#  'ASPL.U',
#  'ASPN',
#  'ASPS',
#  'ASPU',
#  'ASPY',
#  'ASR',
#  'ASRT',
#  'ASRV',
#  'ASRVP',
#  'ASTC',
#  'ASTS',
#  'ASUR',
#  'ASX',
#  'ASXC',
#  'ASYS',
#  'ASZ',
#  'ASZ.U',
#  'AT',
#  'ATA',
#  'ATA.U',
#  'ATAC',
#  'ATAC.U',
#  'ATAQ',
#  'ATAQ.U',
#  'ATAX',
#  'ATC',
#  'ATCO',
#  'ATCO-D',
#  'ATCO-E',
#  'ATCO-G',
#  'ATCO-H',
#  'ATCO-I',
#  'ATCX',
#  'ATEC',
#  'ATEN',
#  'ATEX',
#  'ATGE',
#  'ATH',
#  'ATH-A',
#  'ATH-B',
#  'ATH-C',
#  'ATH-D',
#  'ATHA',
#  'ATHE',
#  'ATHM',
#  'ATHN.U',
#  'ATHX',
#  'ATI',
#  'ATIF',
#  'ATKR',
#  'ATLC',
#  'ATLO',
#  'ATMP',
#  'ATMR',
#  'ATMR.U',
#  'ATNF',
#  'ATNI',
#  'ATNM',
#  'ATNX',
#  'ATO',
#  'ATOM',
#  'ATOS',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATRS',
#  'ATSG',
#  'ATSPT',
#  'ATSPU',
#  'ATTO',
#  'ATUS',
#  'ATVCU',
#  'ATVI',
#  'ATXI',
#  'AU',
#  'AUB',
#  'AUBAP',
#  'AUBN',
#  'AUD',
#  'AUDC',
#  'AUGZ',
#  'AUPH',
#  'AURCU',
#  'AUS',
#  'AUS.U',
#  'AUSF',
#  'AUTO',
#  'AUUD',
#  'AUVI',
#  'AUY',
#  'AVA',
#  'AVAL',
#  'AVAN',
#  'AVAN.U',
#  'AVAV',
#  'AVB',
#  'AVCO',
#  'AVCT',
#  'AVD',
#  'AVDE',
#  'AVDG',
#  'AVDL',
#  'AVDR',
#  'AVDV',
#  'AVEM',
#  'AVEO',
#  'AVGO',
#  'AVGOP',
#  'AVGR',
#  'AVHOQ',
#  'AVID',
#  'AVIG',
#  'AVIR',
#  'AVK',
#  'AVLR',
#  'AVMU',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVRO',
#  'AVT',
#  'AVTR',
#  'AVTR-A',
#  'AVUS',
#  'AVUV',
#  'AVXL',
#  'AVYA',
#  'AWAY',
#  'AWF',
#  'AWH',
#  'AWI',
#  'AWK',
#  'AWR',
#  'AWRE',
#  'AWTM',
#  'AWX',
#  'AX',
#  'AXAS',
#  'AXDX',
#  'AXGN',
#  'AXL',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXS-E',
#  'AXSM',
#  'AXTA',
#  'AXTI',
#  'AXU',
#  'AY',
#  'AYI',
#  'AYLA',
#  'AYRO',
#  'AYTU',
#  'AYX',
#  'AZAA',
#  'AZAJ',
#  'AZAL',
#  'AZAO',
#  'AZBA',
#  'AZBJ',
#  'AZBL',
#  'AZBO',
#  'AZEK',
#  'AZN',
#  'AZO',
#  'AZPN',
#  'AZRE',
#  'AZRX',
#  'AZUL',
#  'AZYO',
#  'AZZ',
#  'B',
#  'BA',
#  'BAB',
#  'BAC',
#  'BAC-B',
#  'BAC-E',
#  'BAC-K',
#  'BAC-L',
#  'BAC-M',
#  'BAC-N',
#  'BAC-O',
#  'BAC-P',
#  'BAH',
#  'BAK',
#  'BAL',
#  'BALY',
#  'BAMH',
#  'BAMI',
#  'BANC',
#  'BANC-E',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BAP',
#  'BAPR',
#  'BAR',
#  'BASX',
#  'BATL',
#  'BATRA',
#  'BATRK',
#  'BATT',
#  'BAUG',
#  'BAX',
#  'BB',
#  'BBAR',
#  'BBAX',
#  'BBBY',
#  'BBC',
#  'BBCA',
#  'BBCP',
#  'BBD',
#  'BBDC',
#  'BBDO',
#  'BBEU',
#  'BBGI',
#  'BBH',
#  'BBI',
#  'BBIG',
#  'BBIN',
#  'BBIO',
#  'BBJP',
#  'BBL',
#  'BBMC',
#  'BBN',
#  'BBP',
#  'BBQ',
#  'BBRE',
#  'BBSA',
#  'BBSC',
#  'BBSI',
#  'BBU',
#  'BBUS',
#  'BBVA',
#  'BBW',
#  'BBY',
#  'BC',
#  'BC-A',
#  'BC-B',
#  'BC-C',
#  'BCAB',
#  'BCAC',
#  'BCACU',
#  'BCAT',
#  'BCBP',
#  'BCC',
#  'BCD',
#  'BCDA',
#  'BCE',
#  'BCEI',
#  'BCEL',
#  'BCH',
#  'BCI',
#  'BCLI',
#  'BCM',
#  'BCML',
#  'BCOMF',
#  'BCOR',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRHF',
#  'BCRX',
#  'BCS',
#  'BCSF',
#  'BCTF',
#  'BCTG',
#  'BCTX',
#  'BCV',
#  'BCV-A',
#  'BCX',
#  'BCYP',
#  'BCYPU',
#  'BDC',
#  'BDCX',
#  'BDCZ',
#  'BDDXF',
#  'BDEC',
#  'BDJ',
#  'BDL',
#  'BDN',
#  'BDR',
#  'BDRY',
#  'BDSI',
#  'BDSX',
#  'BDTX',
#  'BDX',
#  'BDXB',
#  'BE',
#  'BEAM',
#  'BECN',
#  'BEDU',
#  'BEDZ',
#  'BEEM',
#  'BEKE',
#  'BELFA',
#  'BELFB',
#  'BEN',
#  'BENE',
#  'BENER',
#  'BENEU',
#  'BEP',
#  'BEP-A',
#  'BEPC',
#  'BEPH',
#  'BERY',
#  'BEST',
#  'BETZ',
#  'BF.A',
#  'BF.B',
#  'BFAM',
#  'BFC',
#  'BFEB',
#  'BFI',
#  'BFIN',
#  'BFIT',
#  'BFK',
#  'BFLY',
#  'BFOR',
#  'BFS',
#  'BFS-D',
#  'BFS-E',
#  'BFST',
#  'BFTR',
#  'BFZ',
#  'BG',
#  'BGB',
#  'BGCP',
#  'BGFV',
#  'BGH',
#  'BGI',
#  'BGIO',
#  'BGLD',
#  'BGNE',
#  'BGR',
#  'BGRN',
#  'BGS',
#  'BGSF',
#  'BGSX.U',
#  'BGT',
#  'BGX',
#  'BGY',
#  'BH.A',
#  'BHAT',
#  'BHB',
#  'BHC',
#  'BHFAL',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHLB',
#  'BHP',
#  'BHR',
#  'BHR-B',
#  'BHR-D',
#  'BHSE',
#  'BHSEU',
#  'BHV',
#  'BHVN',
#  'BIB',
#  'BIBL',
#  'BICK',
#  'BIF',
#  'BIG',
#  'BIGC',
#  'BIGZ',
#  'BIIB',
#  'BIL',
#  'BILI',
#  'BILL',
#  'BILS',
#  'BIMI',
#  'BIO',
#  'BIO.B',
#  'BIOC',
#  'BIOL',
#  'BIOT',
#  'BIOTU',
#  'BIOX',
#  ...]

# %%
stock_dict = {}

for x in ls_assets:
    print('Stock: ', x)
    stock_dict[x] = yf.Ticker(x)
# Out:
# Stock:  AAA
# Stock:  AAAU
# Stock:  AAC.U
# Stock:  AACG
# Stock:  AACQ
# Stock:  AACQU
# Stock:  AADR
# Stock:  AAIC
# Stock:  AAIC-B
# Stock:  AAIC-C
# Stock:  AAL
# Stock:  AAMC
# Stock:  AAME
# Stock:  AAN
# Stock:  VVC
# Stock:  AAOI
# Stock:  AAP
# Stock:  AAQC.U
# Stock:  AAU
# Stock:  AAVVF
# Stock:  ILG
# Stock:  HCRF
# Stock:  TPGH_DELISTED
# Stock:  AAWW
# Stock:  VIIZ
# Stock:  C016626
# Stock:  AB
# Stock:  ABBV
# Stock:  ABC
# Stock:  ABCB
# Stock:  ABCL
# Stock:  ABCM
# Stock:  ABEQ
# Stock:  BSWN
# Stock:  TSRO
# Stock:  HEFV
# Stock:  H015802
# Stock:  ABEV
# Stock:  ABG
# Stock:  ABGI
# Stock:  ABILF
# Stock:  ABM
# Stock:  ABMD
# Stock:  ABNB
# Stock:  ABR
# Stock:  ABR-A
# Stock:  ABR-B
# Stock:  ABR-C
# Stock:  ABST
# Stock:  ABTX
# Stock:  ABUS
# Stock:  AC
# Stock:  ACA
# Stock:  ACAC
# Stock:  ACAD
# Stock:  ACAH
# Stock:  ACAHU
# Stock:  ACB
# Stock:  ACBAU
# Stock:  ACBI
# Stock:  ACCD
# Stock:  ACCO
# Stock:  ACEL
# Stock:  ACER
# Stock:  ACES
# Stock:  ACET
# Stock:  ACEV
# Stock:  ACEVU
# Stock:  ACGL
# Stock:  ACGLO
# Stock:  ACGLP
# Stock:  ACH
# Stock:  ACHC
# Stock:  ACHL
# Stock:  ACHV
# Stock:  ACI
# Stock:  ACIC
# Stock:  ACIC.U
# Stock:  ACII
# Stock:  ACII.U
# Stock:  ACIU
# Stock:  ACIW
# Stock:  ACKIT
# Stock:  ACKIU
# Stock:  ACLS
# Stock:  ACMR
# Stock:  ACN
# Stock:  ACNB
# Stock:  ACND
# Stock:  ACND.U
# Stock:  ACP
# Stock:  ACQRU
# Stock:  ACR
# Stock:  ACR-C
# Stock:  ACRE
# Stock:  ACRS
# Stock:  ACSG
# Stock:  ACSI
# Stock:  ACST
# Stock:  ACTC
# Stock:  ACTCU
# Stock:  ACTG
# Stock:  ACTV
# Stock:  ACU
# Stock:  ACV
# Stock:  ACVA
# Stock:  ACWF
# Stock:  ACWI
# Stock:  ACWV
# Stock:  ACY
# Stock:  ADAP
# Stock:  ADBE
# Stock:  ADC
# Stock:  ADER
# Stock:  ADES
# Stock:  ADEX
# Stock:  ADF.U
# Stock:  ADFI
# Stock:  ADIL
# Stock:  ADIV
# Stock:  ADM
# Stock:  ADMA
# Stock:  ADME
# Stock:  ADMS
# Stock:  ADN
# Stock:  ADNT
# Stock:  ADOC
# Stock:  ADOCR
# Stock:  ADP
# Stock:  ADRA
# Stock:  ADRA.U
# Stock:  ADRE
# Stock:  ADS
# Stock:  ADSK
# Stock:  ADT
# Stock:  ADTN
# Stock:  ADTX
# Stock:  ADUS
# Stock:  ADV
# Stock:  ADVM
# Stock:  ADX
# Stock:  ADXN
# Stock:  ADXS
# Stock:  ADYX
# Stock:  ADZCF
# Stock:  AE
# Stock:  AEAC
# Stock:  AEACU
# Stock:  AEB
# Stock:  AEE
# Stock:  AEF
# Stock:  AEFC
# Stock:  AEG
# Stock:  AEGN
# Stock:  AEHL
# Stock:  AEHR
# Stock:  AEI
# Stock:  AEIS
# Stock:  AEL-A
# Stock:  AEL-B
# Stock:  AEM
# Stock:  AEMD
# Stock:  AENZ
# Stock:  AEO
# Stock:  AEP
# Stock:  AEPPL
# Stock:  AEPPZ
# Stock:  AER
# Stock:  AERI
# Stock:  AES
# Stock:  AESE
# Stock:  AESR
# Stock:  AEVA
# Stock:  AEY
# Stock:  AEYE
# Stock:  AEZS
# Stock:  AFB
# Stock:  AFBI
# Stock:  AFCG
# Stock:  AFG
# Stock:  AFGB
# Stock:  AFGD
# Stock:  AFGE
# Stock:  AFHBL
# Stock:  AFHIF
# Stock:  AFI
# Stock:  AFIB
# Stock:  AFIN
# Stock:  AFINO
# Stock:  AFINP
# Stock:  AFK
# Stock:  AFL
# Stock:  AFMC
# Stock:  AFMD
# Stock:  AFRM
# Stock:  AFSM
# Stock:  AFT
# Stock:  AFYA
# Stock:  AG
# Stock:  AGAC
# Stock:  AGAC.U
# Stock:  AGBA
# Stock:  AGBAU
# Stock:  AGC
# Stock:  AGCB
# Stock:  AGCO
# Stock:  AGCUU
# Stock:  AGE
# Stock:  AGEN
# Stock:  AGFS
# Stock:  AGFXF
# Stock:  AGFY
# Stock:  AGGRU
# Stock:  AGGY
# Stock:  AGI
# Stock:  AGIO
# Stock:  AGL
# Stock:  AGM
# Stock:  AGM-C
# Stock:  AGM-D
# Stock:  AGM-E
# Stock:  AGM-F
# Stock:  AGM.A
# Stock:  AGMH
# Stock:  AGNC
# Stock:  AGNCM
# Stock:  AGNCN
# Stock:  AGNCP
# Stock:  AGNG
# Stock:  AGO
# Stock:  AGO-B
# Stock:  AGO-F
# Stock:  AGQ
# Stock:  AGRX
# Stock:  AGS
# Stock:  AGT
# Stock:  AGTC
# Stock:  AGTI
# Stock:  AGYS
# Stock:  AGZ
# Stock:  AGZD
# Stock:  AHAC
# Stock:  AHACU
# Stock:  AHCO
# Stock:  AHH
# Stock:  AHH-A
# Stock:  AHL-C
# Stock:  AHL-D
# Stock:  AHL-E
# Stock:  AHPI
# Stock:  AHT
# Stock:  AHT-D
# Stock:  AHT-F
# Stock:  AHT-G
# Stock:  AHT-I
# Stock:  AI
# Stock:  AIC
# Stock:  AIEQ
# Stock:  AIF
# Stock:  AIG
# Stock:  AIG-A
# Stock:  AIH
# Stock:  AIHS
# Stock:  AIIQ
# Stock:  AIKI
# Stock:  AIM
# Stock:  AIMC
# Stock:  AIN
# Stock:  AINC
# Stock:  AINV
# Stock:  AIO
# Stock:  AIQ
# Stock:  AIR
# Stock:  AIRG
# Stock:  AIRI
# Stock:  AIRR
# Stock:  AIRT
# Stock:  AIRTP
# Stock:  AIV
# Stock:  AIW
# Stock:  AIZ
# Stock:  AIZN
# Stock:  AJAX.U
# Stock:  AJG
# Stock:  AJRD
# Stock:  AJX
# Stock:  AJXA
# Stock:  AKAM
# Stock:  AKAOQ
# Stock:  AKBA
# Stock:  AKIC
# Stock:  AKICU
# Stock:  AKO.A
# Stock:  AKO.B
# Stock:  AKR
# Stock:  AKRO
# Stock:  AKTS
# Stock:  AKTX
# Stock:  AKU
# Stock:  AKUS
# Stock:  AKYA
# Stock:  AL
# Stock:  AL-A
# Stock:  ALAC
# Stock:  ALACR
# Stock:  ALACU
# Stock:  ALB
# Stock:  ALBO
# Stock:  ALC
# Stock:  ALCO
# Stock:  ALDX
# Stock:  ALE
# Stock:  ALEC
# Stock:  ALEX
# Stock:  ALFA
# Stock:  ALG
# Stock:  ALGM
# Stock:  ALGN
# Stock:  ALGS
# Stock:  ALGT
# Stock:  ALIM
# Stock:  ALIN-A
# Stock:  ALIN-B
# Stock:  ALIN-E
# Stock:  ALJJ
# Stock:  ALK
# Stock:  ALKS
# Stock:  ALKT
# Stock:  ALL
# Stock:  ALL-B
# Stock:  ALL-G
# Stock:  ALL-H
# Stock:  ALL-I
# Stock:  ALLE
# Stock:  ALLK
# Stock:  ALLO
# Stock:  ALLT
# Stock:  ALLY
# Stock:  ALLY-A
# Stock:  ALNA
# Stock:  ALNY
# Stock:  ALOT
# Stock:  ALP-Q
# Stock:  ALPN
# Stock:  ALRM
# Stock:  ALRN
# Stock:  ALRS
# Stock:  ALSK
# Stock:  ALSN
# Stock:  ALT
# Stock:  ALTG-A
# Stock:  ALTL
# Stock:  ALTM
# Stock:  ALTO
# Stock:  ALTR
# Stock:  ALTS
# Stock:  ALTU
# Stock:  ALTUU
# Stock:  ALTY
# Stock:  ALUS
# Stock:  ALUS.U
# Stock:  ALV
# Stock:  ALVR
# Stock:  ALX
# Stock:  ALXN
# Stock:  ALXO
# Stock:  ALYA
# Stock:  AM
# Stock:  AMAL
# Stock:  AMAOU
# Stock:  AMAT
# Stock:  AMBA
# Stock:  AMBC
# Stock:  AMBO
# Stock:  AMCA
# Stock:  AMCR
# Stock:  AMCX
# Stock:  AMD
# Stock:  AME
# Stock:  AMED
# Stock:  AMER
# Stock:  AMG
# Stock:  AMGN
# Stock:  AMH
# Stock:  AMH-D
# Stock:  AMH-E
# Stock:  AMH-G
# Stock:  AMH-H
# Stock:  AMHC
# Stock:  AMHCU
# Stock:  AMJ
# Stock:  AMK
# Stock:  AMKR
# Stock:  AMLP
# Stock:  AMN
# Stock:  AMNA
# Stock:  AMNB
# Stock:  AMND
# Stock:  AMOM
# Stock:  AMOT
# Stock:  AMOV
# Stock:  AMP
# Stock:  AMPE
# Stock:  AMPG
# Stock:  AMPH
# Stock:  AMPI
# Stock:  AMPI.U
# Stock:  AMPY
# Stock:  AMR
# Stock:  AMRB
# Stock:  AMRC
# Stock:  AMRK
# Stock:  AMRN
# Stock:  AMRS
# Stock:  AMRX
# Stock:  AMS
# Stock:  AMSC
# Stock:  AMSF
# Stock:  AMST
# Stock:  AMSWA
# Stock:  AMT
# Stock:  AMTB
# Stock:  AMTI
# Stock:  AMTR
# Stock:  AMTX
# Stock:  AMUB
# Stock:  AMWD
# Stock:  AMYT
# Stock:  AN
# Stock:  ANAB
# Stock:  ANAC
# Stock:  ANAC.U
# Stock:  ANDA
# Stock:  ANDAR
# Stock:  ANDAU
# Stock:  ANDE
# Stock:  ANET
# Stock:  ANEW
# Stock:  ANF
# Stock:  ANFIF
# Stock:  ANGI
# Stock:  ANGL
# Stock:  ANGN
# Stock:  ANGO
# Stock:  ANIK
# Stock:  ANIP
# Stock:  ANIX
# Stock:  ANNX
# Stock:  ANPC
# Stock:  ANSS
# Stock:  ANTE
# Stock:  ANTH
# Stock:  ANTM
# Stock:  ANVS
# Stock:  ANY
# Stock:  ANZUU
# Stock:  AOA
# Stock:  AOD
# Stock:  AOK
# Stock:  AOM
# Stock:  AON
# Stock:  AONE
# Stock:  AONE.U
# Stock:  AOR
# Stock:  AOS
# Stock:  AOSL
# Stock:  AOUT
# Stock:  AP
# Stock:  APA
# Stock:  APAM
# Stock:  APD
# Stock:  APEI
# Stock:  APEN
# Stock:  APG
# Stock:  APGB
# Stock:  APGB.U
# Stock:  APH
# Stock:  APHA
# Stock:  API
# Stock:  APLE
# Stock:  APLS
# Stock:  APLT
# Stock:  APM
# Stock:  APO
# Stock:  APO-A
# Stock:  APO-B
# Stock:  APOG
# Stock:  APOP
# Stock:  APP
# Stock:  APPF
# Stock:  APPH
# Stock:  APPN
# Stock:  APPS
# Stock:  APR
# Stock:  APRE
# Stock:  APRN
# Stock:  APRZ
# Stock:  APSG
# Stock:  APSG.U
# Stock:  APT
# Stock:  APTO
# Stock:  APTS
# Stock:  APTV
# Stock:  APTV-A
# Stock:  APTX
# Stock:  APVO
# Stock:  APWC
# Stock:  APXT
# Stock:  APXTU
# Stock:  APYX
# Stock:  AQB
# Stock:  AQMS
# Stock:  AQN
# Stock:  AQNA
# Stock:  AQNB
# Stock:  AQST
# Stock:  AQUA
# Stock:  AQWA
# Stock:  AR
# Stock:  ARAV
# Stock:  ARAY
# Stock:  ARB
# Stock:  ARBG
# Stock:  ARBGU
# Stock:  ARC
# Stock:  ARCB
# Stock:  ARCC
# Stock:  ARCE
# Stock:  ARCH
# Stock:  ARCM
# Stock:  ARCO
# Stock:  ARCT
# Stock:  ARCW
# Stock:  ARD
# Stock:  ARDC
# Stock:  ARDS
# Stock:  ARDX
# Stock:  ARE
# Stock:  AREC
# Stock:  ARES
# Stock:  ARES-A
# Stock:  ARGD
# Stock:  ARGO
# Stock:  ARGO-A
# Stock:  ARGT
# Stock:  ARGX
# Stock:  ARI
# Stock:  ARKF
# Stock:  ARKG
# Stock:  ARKK
# Stock:  ARKO
# Stock:  ARKQ
# Stock:  ARKR
# Stock:  ARKW
# Stock:  ARKX
# Stock:  ARL
# Stock:  ARLO
# Stock:  ARLP
# Stock:  ARMK
# Stock:  ARMP
# Stock:  ARMR
# Stock:  ARNA
# Stock:  ARNC
# Stock:  AROC
# Stock:  AROW
# Stock:  ARPO
# Stock:  ARQT
# Stock:  ARR
# Stock:  ARR-C
# Stock:  ARRW
# Stock:  ARRY
# Stock:  ARTL
# Stock:  ARTNA
# Stock:  ARTW
# Stock:  ARVL
# Stock:  ARVN
# Stock:  ARW
# Stock:  ARWR
# Stock:  ARYA
# Stock:  ARYD
# Stock:  ASA
# Stock:  ASAI
# Stock:  ASAN
# Stock:  ASAQ
# Stock:  ASAQ.U
# Stock:  ASAX
# Stock:  ASAXU
# Stock:  ASB
# Stock:  ASB-D
# Stock:  ASB-E
# Stock:  ASB-F
# Stock:  ASC
# Stock:  ASEA
# Stock:  ASET
# Stock:  ASG
# Stock:  ASGI
# Stock:  ASGN
# Stock:  ASH
# Stock:  ASHR
# Stock:  ASHS
# Stock:  ASHX
# Stock:  ASIX
# Stock:  ASLE
# Stock:  ASLN
# Stock:  ASM
# Stock:  ASMB
# Stock:  ASML
# Stock:  ASND
# Stock:  ASPC
# Stock:  ASPCU
# Stock:  ASPL
# Stock:  ASPL.U
# Stock:  ASPN
# Stock:  ASPS
# Stock:  ASPU
# Stock:  ASPY
# Stock:  ASR
# Stock:  ASRT
# Stock:  ASRV
# Stock:  ASRVP
# Stock:  ASTC
# Stock:  ASTS
# Stock:  ASUR
# Stock:  ASX
# Stock:  ASXC
# Stock:  ASYS
# Stock:  ASZ
# Stock:  ASZ.U
# Stock:  AT
# Stock:  ATA
# Stock:  ATA.U
# Stock:  ATAC
# Stock:  ATAC.U
# Stock:  ATAQ
# Stock:  ATAQ.U
# Stock:  ATAX
# Stock:  ATC
# Stock:  ATCO
# Stock:  ATCO-D
# Stock:  ATCO-E
# Stock:  ATCO-G
# Stock:  ATCO-H
# Stock:  ATCO-I
# Stock:  ATCX
# Stock:  ATEC
# Stock:  ATEN
# Stock:  ATEX
# Stock:  ATGE
# Stock:  ATH
# Stock:  ATH-A
# Stock:  ATH-B
# Stock:  ATH-C
# Stock:  ATH-D
# Stock:  ATHA
# Stock:  ATHE
# Stock:  ATHM
# Stock:  ATHN.U
# Stock:  ATHX
# Stock:  ATI
# Stock:  ATIF
# Stock:  ATKR
# Stock:  ATLC
# Stock:  ATLO
# Stock:  ATMP
# Stock:  ATMR
# Stock:  ATMR.U
# Stock:  ATNF
# Stock:  ATNI
# Stock:  ATNM
# Stock:  ATNX
# Stock:  ATO
# Stock:  ATOM
# Stock:  ATOS
# Stock:  ATR
# Stock:  ATRA
# Stock:  ATRC
# Stock:  ATRI
# Stock:  ATRO
# Stock:  ATRS
# Stock:  ATSG
# Stock:  ATSPT
# Stock:  ATSPU
# Stock:  ATTO
# Stock:  ATUS
# Stock:  ATVCU
# Stock:  ATVI
# Stock:  ATXI
# Stock:  AU
# Stock:  AUB
# Stock:  AUBAP
# Stock:  AUBN
# Stock:  AUD
# Stock:  AUDC
# Stock:  AUGZ
# Stock:  AUPH
# Stock:  AURCU
# Stock:  AUS
# Stock:  AUS.U
# Stock:  AUSF
# Stock:  AUTO
# Stock:  AUUD
# Stock:  AUVI
# Stock:  AUY
# Stock:  AVA
# Stock:  AVAL
# Stock:  AVAN
# Stock:  AVAN.U
# Stock:  AVAV
# Stock:  AVB
# Stock:  AVCO
# Stock:  AVCT
# Stock:  AVD
# Stock:  AVDE
# Stock:  AVDG
# Stock:  AVDL
# Stock:  AVDR
# Stock:  AVDV
# Stock:  AVEM
# Stock:  AVEO
# Stock:  AVGO
# Stock:  AVGOP
# Stock:  AVGR
# Stock:  AVHOQ
# Stock:  AVID
# Stock:  AVIG
# Stock:  AVIR
# Stock:  AVK
# Stock:  AVLR
# Stock:  AVMU
# Stock:  AVNS
# Stock:  AVNT
# Stock:  AVNW
# Stock:  AVO
# Stock:  AVRO
# Stock:  AVT
# Stock:  AVTR
# Stock:  AVTR-A
# Stock:  AVUS
# Stock:  AVUV
# Stock:  AVXL
# Stock:  AVYA
# Stock:  AWAY
# Stock:  AWF
# Stock:  AWH
# Stock:  AWI
# Stock:  AWK
# Stock:  AWR
# Stock:  AWRE
# Stock:  AWTM
# Stock:  AWX
# Stock:  AX
# Stock:  AXAS
# Stock:  AXDX
# Stock:  AXGN
# Stock:  AXL
# Stock:  AXLA
# Stock:  AXNX
# Stock:  AXON
# Stock:  AXP
# Stock:  AXR
# Stock:  AXS
# Stock:  AXS-E
# Stock:  AXSM
# Stock:  AXTA
# Stock:  AXTI
# Stock:  AXU
# Stock:  AY
# Stock:  AYI
# Stock:  AYLA
# Stock:  AYRO
# Stock:  AYTU
# Stock:  AYX
# Stock:  AZAA
# Stock:  AZAJ
# Stock:  AZAL
# Stock:  AZAO
# Stock:  AZBA
# Stock:  AZBJ
# Stock:  AZBL
# Stock:  AZBO
# Stock:  AZEK
# Stock:  AZN
# Stock:  AZO
# Stock:  AZPN
# Stock:  AZRE
# Stock:  AZRX
# Stock:  AZUL
# Stock:  AZYO
# Stock:  AZZ
# Stock:  B
# Stock:  BA
# Stock:  BAB
# Stock:  BAC
# Stock:  BAC-B
# Stock:  BAC-E
# Stock:  BAC-K
# Stock:  BAC-L
# Stock:  BAC-M
# Stock:  BAC-N
# Stock:  BAC-O
# Stock:  BAC-P
# Stock:  BAH
# Stock:  BAK
# Stock:  BAL
# Stock:  BALY
# Stock:  BAMH
# Stock:  BAMI
# Stock:  BANC
# Stock:  BANC-E
# Stock:  BAND
# Stock:  BANF
# Stock:  BANFP
# Stock:  BANR
# Stock:  BANX
# Stock:  BAOS
# Stock:  BAP
# Stock:  BAPR
# Stock:  BAR
# Stock:  BASX
# Stock:  BATL
# Stock:  BATRA
# Stock:  BATRK
# Stock:  BATT
# Stock:  BAUG
# Stock:  BAX
# Stock:  BB
# Stock:  BBAR
# Stock:  BBAX
# Stock:  BBBY
# Stock:  BBC
# Stock:  BBCA
# Stock:  BBCP
# Stock:  BBD
# Stock:  BBDC
# Stock:  BBDO
# Stock:  BBEU
# Stock:  BBGI
# Stock:  BBH
# Stock:  BBI
# Stock:  BBIG
# Stock:  BBIN
# Stock:  BBIO
# Stock:  BBJP
# Stock:  BBL
# Stock:  BBMC
# Stock:  BBN
# Stock:  BBP
# Stock:  BBQ
# Stock:  BBRE
# Stock:  BBSA
# Stock:  BBSC
# Stock:  BBSI
# Stock:  BBU
# Stock:  BBUS
# Stock:  BBVA
# Stock:  BBW
# Stock:  BBY
# Stock:  BC
# Stock:  BC-A
# Stock:  BC-B
# Stock:  BC-C
# Stock:  BCAB
# Stock:  BCAC
# Stock:  BCACU
# Stock:  BCAT
# Stock:  BCBP
# Stock:  BCC
# Stock:  BCD
# Stock:  BCDA
# Stock:  BCE
# Stock:  BCEI
# Stock:  BCEL
# Stock:  BCH
# Stock:  BCI
# Stock:  BCLI
# Stock:  BCM
# Stock:  BCML
# Stock:  BCOMF
# Stock:  BCOR
# Stock:  BCOV
# Stock:  BCOW
# Stock:  BCPC
# Stock:  BCRHF
# Stock:  BCRX
# Stock:  BCS
# Stock:  BCSF
# Stock:  BCTF
# Stock:  BCTG
# Stock:  BCTX
# Stock:  BCV
# Stock:  BCV-A
# Stock:  BCX
# Stock:  BCYP
# Stock:  BCYPU
# Stock:  BDC
# Stock:  BDCX
# Stock:  BDCZ
# Stock:  BDDXF
# Stock:  BDEC
# Stock:  BDJ
# Stock:  BDL
# Stock:  BDN
# Stock:  BDR
# Stock:  BDRY
# Stock:  BDSI
# Stock:  BDSX
# Stock:  BDTX
# Stock:  BDX
# Stock:  BDXB
# Stock:  BE
# Stock:  BEAM
# Stock:  BECN
# Stock:  BEDU
# Stock:  BEDZ
# Stock:  BEEM
# Stock:  BEKE
# Stock:  BELFA
# Stock:  BELFB
# Stock:  BEN
# Stock:  BENE
# Stock:  BENER
# Stock:  BENEU
# Stock:  BEP
# Stock:  BEP-A
# Stock:  BEPC
# Stock:  BEPH
# Stock:  BERY
# Stock:  BEST
# Stock:  BETZ
# Stock:  BF.A
# Stock:  BF.B
# Stock:  BFAM
# Stock:  BFC
# Stock:  BFEB
# Stock:  BFI
# Stock:  BFIN
# Stock:  BFIT
# Stock:  BFK
# Stock:  BFLY
# Stock:  BFOR
# Stock:  BFS
# Stock:  BFS-D
# Stock:  BFS-E
# Stock:  BFST
# Stock:  BFTR
# Stock:  BFZ
# Stock:  BG
# Stock:  BGB
# Stock:  BGCP
# Stock:  BGFV
# Stock:  BGH
# Stock:  BGI
# Stock:  BGIO
# Stock:  BGLD
# Stock:  BGNE
# Stock:  BGR
# Stock:  BGRN
# Stock:  BGS
# Stock:  BGSF
# Stock:  BGSX.U
# Stock:  BGT
# Stock:  BGX
# Stock:  BGY
# Stock:  BH.A
# Stock:  BHAT
# Stock:  BHB
# Stock:  BHC
# Stock:  BHFAL
# Stock:  BHFAN
# Stock:  BHFAO
# Stock:  BHFAP
# Stock:  BHLB
# Stock:  BHP
# Stock:  BHR
# Stock:  BHR-B
# Stock:  BHR-D
# Stock:  BHSE
# Stock:  BHSEU
# Stock:  BHV
# Stock:  BHVN
# Stock:  BIB
# Stock:  BIBL
# Stock:  BICK
# Stock:  BIF
# Stock:  BIG
# Stock:  BIGC
# Stock:  BIGZ
# Stock:  BIIB
# Stock:  BIL
# Stock:  BILI
# Stock:  BILL
# Stock:  BILS
# Stock:  BIMI
# Stock:  BIO
# Stock:  BIO.B
# Stock:  BIOC
# Stock:  BIOL
# Stock:  BIOT
# Stock:  BIOTU
# Stock:  BIOX
# Stock:  BIP
# Stock:  BIP-A
# Stock:  BIP-B
# Stock:  BIPC
# Stock:  BIQIF
# Stock:  BIS
# Stock:  BIT
# Stock:  BITE
# Stock:  BITE.U
# Stock:  BIV
# Stock:  BIVI
# Stock:  BIZD
# Stock:  BJ
# Stock:  BJAN
# Stock:  BJK
# Stock:  BJRI
# Stock:  BJUL
# Stock:  BJUN
# Stock:  BK
# Stock:  BKAG
# Stock:  BKCC
# Stock:  BKD
# Stock:  BKEM
# Stock:  BKEP
# Stock:  BKEPP
# Stock:  BKF
# Stock:  BKH
# Stock:  BKHY
# Stock:  BKI
# Stock:  BKIE
# Stock:  BKLC
# Stock:  BKLN
# Stock:  BKMC
# Stock:  BKN
# Stock:  BKNG
# Stock:  BKR
# Stock:  BKSB
# Stock:  BKSC
# Stock:  BKSE
# Stock:  BKT
# Stock:  BKTI
# Stock:  BKU
# Stock:  BKYI
# Stock:  BL
# Stock:  BLBD
# Stock:  BLCM
# Stock:  BLCN
# Stock:  BLCT
# Stock:  BLD
# Stock:  BLDG
# Stock:  BLDP
# Stock:  BLDR
# Stock:  BLE
# Stock:  BLES
# Stock:  BLFS
# Stock:  BLHY
# Stock:  BLI
# Stock:  BLK
# Stock:  BLKB
# Stock:  BLL
# Stock:  BLMN
# Stock:  BLNK
# Stock:  BLPH
# Stock:  BLSA
# Stock:  BLTS
# Stock:  BLTSU
# Stock:  BLU
# Stock:  BLUA.U
# Stock:  BLUE
# Stock:  BLUW
# Stock:  BLUWU
# Stock:  BLV
# Stock:  BLW
# Stock:  BLX
# Stock:  BMA
# Stock:  BMAR
# Stock:  BMAY
# Stock:  BMBL
# Stock:  BME
# Stock:  BMEA
# Stock:  BMED
# Stock:  BMEZ
# Stock:  BMI
# Stock:  BML-G
# Stock:  BML-H
# Stock:  BML-J
# Stock:  BML-L
# Stock:  BMO
# Stock:  BMRA
# Stock:  BMRC
# Stock:  BMRN
# Stock:  BMTC
# Stock:  BMTX
# Stock:  BMY
# Stock:  BND
# Stock:  BNDW
# Stock:  BNDX
# Stock:  BNE
# Stock:  BNED
# Stock:  BNFT
# Stock:  BNKD
# Stock:  BNKU
# Stock:  BNL
# Stock:  BNO
# Stock:  BNS
# Stock:  BNSO
# Stock:  BNTC
# Stock:  BNTX
# Stock:  BNY
# Stock:  BOAC
# Stock:  BOAC.U
# Stock:  BOAS
# Stock:  BOAS.U
# Stock:  BOB
# Stock:  BOCH
# Stock:  BOCT
# Stock:  BOE
# Stock:  BOH
# Stock:  BOIL
# Stock:  BOKF
# Stock:  BOKFL
# Stock:  BOLT
# Stock:  BOMMF
# Stock:  BOMN
# Stock:  BOND
# Stock:  BOOM
# Stock:  BOOT
# Stock:  BORNY
# Stock:  BORR
# Stock:  BOSC
# Stock:  BOSS
# Stock:  BOSXF
# Stock:  BOTJ
# Stock:  BOTZ
# Stock:  BOUT
# Stock:  BOWX
# Stock:  BOWXU
# Stock:  BOX
# Stock:  BOXL
# Stock:  BPFH
# Stock:  BPMC
# Stock:  BPMP
# Stock:  BPOP
# Stock:  BPOPM
# Stock:  BPOPN
# Stock:  BPRN
# Stock:  BPT
# Stock:  BPTH
# Stock:  BPTS
# Stock:  BPY
# Stock:  BPYPN
# Stock:  BPYPO
# Stock:  BPYPP
# Stock:  BPYU
# Stock:  BPYUP
# Stock:  BQ
# Stock:  BR
# Stock:  BRBR
# Stock:  BRBS
# Stock:  BRC
# Stock:  BREZ
# Stock:  BREZR
# Stock:  BRF
# Stock:  BRFS
# Stock:  BRG
# Stock:  BRG-C
# Stock:  BRG-D
# Stock:  BRID
# Stock:  BRK.A
# Stock:  BRK.B
# Stock:  BRKL
# Stock:  BRKR
# Stock:  BRKS
# Stock:  BRLI
# Stock:  BRLIR
# Stock:  BRLIU
# Stock:  BRMK
# Stock:  BRN
# Stock:  BRO
# Stock:  BROG
# Stock:  BRP
# Stock:  BRPA
# Stock:  BRPAR
# Stock:  BRPAU
# Stock:  BRPMU
# Stock:  BRQS
# Stock:  BRT
# Stock:  BRX
# Stock:  BRY
# Stock:  BRZU
# Stock:  BSA
# Stock:  BSAC
# Stock:  BSAE
# Stock:  BSBE
# Stock:  BSBK
# Stock:  BSBR
# Stock:  BSCE
# Stock:  BSCL
# Stock:  BSCM
# Stock:  BSCN
# Stock:  BSCO
# Stock:  BSCP
# Stock:  BSCQ
# Stock:  BSCR
# Stock:  BSCS
# Stock:  BSCU
# Stock:  BSDE
# Stock:  BSEP
# Stock:  BSJL
# Stock:  BSJM
# Stock:  BSJP
# Stock:  BSJQ
# Stock:  BSJR
# Stock:  BSM
# Stock:  BSML
# Stock:  BSMM
# Stock:  BSMN
# Stock:  BSMO
# Stock:  BSMP
# Stock:  BSMQ
# Stock:  BSMR
# Stock:  BSMS
# Stock:  BSMT
# Stock:  BSMU
# Stock:  BSMX
# Stock:  BSN
# Stock:  BSN.U
# Stock:  BSPE
# Stock:  BSPM
# Stock:  BSQR
# Stock:  BSRR
# Stock:  BST
# Stock:  BSTZ
# Stock:  BSV
# Stock:  BSVN
# Stock:  BSX
# Stock:  BSX-A
# Stock:  BSY
# Stock:  BTA
# Stock:  BTAI
# Stock:  BTAL
# Stock:  BTAQ
# Stock:  BTAQU
# Stock:  BTBT
# Stock:  BTC
# Stock:  BTCM
# Stock:  BTEGF
# Stock:  BTEK
# Stock:  BTG
# Stock:  BTI
# Stock:  BTN
# Stock:  BTO
# Stock:  BTRS
# Stock:  BTT
# Stock:  BTU
# Stock:  BTWNU
# Stock:  BTX
# Stock:  BTZ
# Stock:  BUD
# Stock:  BUFD
# Stock:  BUFF
# Stock:  BUFR
# Stock:  BUG
# Stock:  BUI
# Stock:  BUL
# Stock:  BUR
# Stock:  BURL
# Stock:  BUSE
# Stock:  BUYZ
# Stock:  BUZZ
# Stock:  BV
# Stock:  BVH
# Stock:  BVN
# Stock:  BVS
# Stock:  BVXV
# Stock:  BW
# Stock:  BWA
# Stock:  BWAC
# Stock:  BWACU
# Stock:  BWAY
# Stock:  BWB
# Stock:  BWEN
# Stock:  BWFG
# Stock:  BWG
# Stock:  BWL.A
# Stock:  BWMX
# Stock:  BWSN
# Stock:  BWX
# Stock:  BWXT
# Stock:  BWZ
# Stock:  BX
# Stock:  BXC
# Stock:  BXG
# Stock:  BXMT
# Stock:  BXMX
# Stock:  BXP
# Stock:  BXRX
# Stock:  BXS
# Stock:  BXS-A
# Stock:  BY
# Stock:  BYD
# Stock:  BYFC
# Stock:  BYLD
# Stock:  BYM
# Stock:  BYSI
# Stock:  BYTSU
# Stock:  BZH
# Stock:  BZQ
# Stock:  C
# Stock:  C-J
# Stock:  C-K
# Stock:  C-N
# Stock:  CAAP
# Stock:  CABA
# Stock:  CABO
# Stock:  CACC
# Stock:  CACG
# Stock:  CACI
# Stock:  CADE
# Stock:  CAE
# Stock:  CAF
# Stock:  CAG
# Stock:  CAH
# Stock:  CAHC
# Stock:  CAHCU
# Stock:  CAI
# Stock:  CAI-A
# Stock:  CAI-B
# Stock:  CAJ
# Stock:  CAKE
# Stock:  CAL
# Stock:  CALA
# Stock:  CALB
# Stock:  CALF
# Stock:  CALI
# Stock:  CALM
# Stock:  CALT
# Stock:  CALX
# Stock:  CAMP
# Stock:  CAMT
# Stock:  CAN
# Stock:  CANE
# Stock:  CANF
# Stock:  CANG
# Stock:  CAP
# Stock:  CAP.U
# Stock:  CAPA
# Stock:  CAPAU
# Stock:  CAPE
# Stock:  CAPL
# Stock:  CAPR
# Stock:  CAR
# Stock:  CARA
# Stock:  CARE
# Stock:  CARG
# Stock:  CARR
# Stock:  CARS
# Stock:  CARV
# Stock:  CARZ
# Stock:  CAS
# Stock:  CAS.U
# Stock:  CASA
# Stock:  CASH
# Stock:  CASI
# Stock:  CASS
# Stock:  CASY
# Stock:  CAT
# Stock:  CATB
# Stock:  CATC
# Stock:  CATH
# Stock:  CATM
# Stock:  CATO
# Stock:  CATY
# Stock:  CAWW
# Stock:  CB
# Stock:  CBAH
# Stock:  CBAH.U
# Stock:  CBAN
# Stock:  CBAT
# Stock:  CBAY
# Stock:  CBB
# Stock:  CBB-B
# Stock:  CBD
# Stock:  CBFV
# Stock:  CBH
# Stock:  CBIO
# Stock:  CBJCL
# Stock:  CBKCQ
# Stock:  CBLAQ
# Stock:  CBLDQ
# Stock:  CBLEQ
# Stock:  CBLI
# Stock:  CBLS
# Stock:  CBMB
# Stock:  CBNK
# Stock:  CBOE
# Stock:  CBON
# Stock:  CBRE
# Stock:  CBRL
# Stock:  CBSE
# Stock:  CBSH
# Stock:  CBT
# Stock:  CBTG
# Stock:  CBTRP
# Stock:  CBTX
# Stock:  CBU
# Stock:  CBZ
# Stock:  CC
# Stock:  CCAC
# Stock:  CCAC.U
# Stock:  CCAP
# Stock:  CCB
# Stock:  CCBG
# Stock:  CCD
# Stock:  CCF
# Stock:  CCI
# Stock:  CCIV
# Stock:  CCIV.U
# Stock:  CCK
# Stock:  CCL
# Stock:  CCLP
# Stock:  CCM
# Stock:  CCNE
# Stock:  CCNEP
# Stock:  CCO
# Stock:  CCOI
# Stock:  CCON
# Stock:  CCOR
# Stock:  CCRC
# Stock:  CCRN
# Stock:  CCRV
# Stock:  CCU
# Stock:  CCV
# Stock:  CCV.U
# Stock:  CCVI
# Stock:  CCVI.U
# Stock:  CCX
# Stock:  CCX.U
# Stock:  CCXI
# Stock:  CCZ
# Stock:  CD
# Stock:  CDAK
# Stock:  CDAY
# Stock:  CDC
# Stock:  CDE
# Stock:  CDEV
# Stock:  CDK
# Stock:  CDL
# Stock:  CDLX
# Stock:  CDMO
# Stock:  CDNA
# Stock:  CDNS
# Stock:  CDOR
# Stock:  CDR
# Stock:  CDR-B
# Stock:  CDR-C
# Stock:  CDTI
# Stock:  CDTX
# Stock:  CDW
# Stock:  CDXC
# Stock:  CDXS
# Stock:  CDZI
# Stock:  CE
# Stock:  CEA
# Stock:  CEE
# Stock:  CEF
# Stock:  CEFA
# Stock:  CEFD
# Stock:  CEFS
# Stock:  CEIX
# Stock:  CELC
# Stock:  CELG.RT
# Stock:  CELH
# Stock:  CELJF
# Stock:  CELP
# Stock:  CEM
# Stock:  CEMB
# Stock:  CEMI
# Stock:  CEN
# Stock:  CENH
# Stock:  CENHU
# Stock:  CENT
# Stock:  CENTA
# Stock:  CENX
# Stock:  CEPU
# Stock:  CEQP
# Stock:  CEQP-
# Stock:  CERC
# Stock:  CERE
# Stock:  CERN
# Stock:  CERS
# Stock:  CERT
# Stock:  CET
# Stock:  CETX
# Stock:  CETXP
# Stock:  CEV
# Stock:  CEVA
# Stock:  CEW
# Stock:  CEY
# Stock:  CF
# Stock:  CFA
# Stock:  CFAC
# Stock:  CFACU
# Stock:  CFB
# Stock:  CFBK
# Stock:  CFCV
# Stock:  CFFEU
# Stock:  CFFI
# Stock:  CFFN
# Stock:  CFFVU
# Stock:  CFG
# Stock:  CFG-D
# Stock:  CFG-E
# Stock:  CFIV
# Stock:  CFIVU
# Stock:  CFMS
# Stock:  CFO
# Stock:  CFR
# Stock:  CFR-B
# Stock:  CFRX
# Stock:  CFV
# Stock:  CFVIU
# Stock:  CFX
# Stock:  CFXA
# Stock:  CG
# Stock:  CGA
# Stock:  CGAU
# Stock:  CGBD
# Stock:  CGC
# Stock:  CGEM
# Stock:  CGEN
# Stock:  CGGYY
# Stock:  CGNT
# Stock:  CGNX
# Stock:  CGO
# Stock:  CGRN
# Stock:  CGW
# Stock:  CHAA
# Stock:  CHAA.U
# Stock:  CHAD
# Stock:  CHAQ
# Stock:  CHAQ.U
# Stock:  CHAU
# Stock:  CHB
# Stock:  CHCI
# Stock:  CHCO
# Stock:  CHCT
# Stock:  CHD
# Stock:  CHDN
# Stock:  CHE
# Stock:  CHEF
# Stock:  CHEK
# Stock:  CHFW
# Stock:  CHFW.U
# Stock:  CHGG
# Stock:  CHGX
# Stock:  CHH
# Stock:  CHI
# Stock:  CHIC
# Stock:  CHIE
# Stock:  CHIH
# Stock:  CHII
# Stock:  CHIK
# Stock:  CHIL
# Stock:  CHIM
# Stock:  CHIQ
# Stock:  CHIR
# Stock:  CHIS
# Stock:  CHIU
# Stock:  CHIX
# Stock:  CHK
# Stock:  CHKP
# Stock:  CHKR
# Stock:  CHMA
# Stock:  CHMG
# Stock:  CHMI
# Stock:  CHMI-A
# Stock:  CHMI-B
# Stock:  CHN
# Stock:  CHNA
# Stock:  CHNG
# Stock:  CHNGU
# Stock:  CHNR
# Stock:  CHPM
# Stock:  CHPMU
# Stock:  CHPT
# Stock:  CHRA
# Stock:  CHRS
# Stock:  CHRW
# Stock:  CHS
# Stock:  CHSCL
# Stock:  CHSCM
# Stock:  CHSCN
# Stock:  CHSCO
# Stock:  CHSCP
# Stock:  CHT
# Stock:  CHTR
# Stock:  CHUY
# Stock:  CHW
# Stock:  CHWY
# Stock:  CHX
# Stock:  CHY
# Stock:  CI
# Stock:  CIA
# Stock:  CIB
# Stock:  CIBR
# Stock:  CID
# Stock:  CIDM
# Stock:  CIEN
# Stock:  CIF
# Stock:  CIG
# Stock:  CIG.C
# Stock:  CIGI
# Stock:  CIH
# Stock:  CII
# Stock:  CIK
# Stock:  CIL
# Stock:  CIM
# Stock:  CIM-A
# Stock:  CIM-B
# Stock:  CIM-C
# Stock:  CIM-D
# Stock:  CINF
# Stock:  CINR
# Stock:  CIO
# Stock:  CIO-A
# Stock:  CIR
# Stock:  CIT
# Stock:  CIT-B
# Stock:  CIVB
# Stock:  CIX
# Stock:  CIXX
# Stock:  CIZ
# Stock:  CIZN
# Stock:  CJJD
# Stock:  CKPT
# Stock:  CKX
# Stock:  CL
# Stock:  CLAA.U
# Stock:  CLAR
# Stock:  CLAS
# Stock:  CLAS.U
# Stock:  CLB
# Stock:  CLBS
# Stock:  CLDB
# Stock:  CLDL
# Stock:  CLDS
# Stock:  CLDT
# Stock:  CLDX
# Stock:  CLEU
# Stock:  CLF
# Stock:  CLFD
# Stock:  CLGN
# Stock:  CLGX
# Stock:  CLH
# Stock:  CLI
# Stock:  CLII
# Stock:  CLII.U
# Stock:  CLIM
# Stock:  CLIM.U
# Stock:  CLIR
# Stock:  CLIX
# Stock:  CLLS
# Stock:  CLM
# Stock:  CLMT
# Stock:  CLNC
# Stock:  CLNE
# Stock:  CLNN
# Stock:  CLNY
# Stock:  CLNY-G
# Stock:  CLNY-H
# Stock:  CLNY-I
# Stock:  CLNY-J
# Stock:  CLOU
# Stock:  CLPR
# Stock:  CLPS
# Stock:  CLPT
# Stock:  CLR
# Stock:  CLRB
# Stock:  CLRG
# Stock:  CLRM
# Stock:  CLRMU
# Stock:  CLRO
# Stock:  CLS
# Stock:  CLSD
# Stock:  CLSK
# Stock:  CLSN
# Stock:  CLTL
# Stock:  CLUBQ
# Stock:  CLVR
# Stock:  CLVS
# Stock:  CLVT
# Stock:  CLW
# Stock:  CLWT
# Stock:  CLX
# Stock:  CLXT
# Stock:  CM
# Stock:  CMA
# Stock:  CMBM
# Stock:  CMBS
# Stock:  CMC
# Stock:  CMCL
# Stock:  CMCM
# Stock:  CMCO
# Stock:  CMCSA
# Stock:  CMCT
# Stock:  CMCTP
# Stock:  CMD
# Stock:  CMDY
# Stock:  CME
# Stock:  CMF
# Stock:  CMG
# Stock:  CMI
# Stock:  CMII
# Stock:  CMIIU
# Stock:  CMLF
# Stock:  CMLFU
# Stock:  CMLS
# Stock:  CMLTU
# Stock:  CMMB
# Stock:  CMO
# Stock:  CMO-E
# Stock:  CMP
# Stock:  CMPI
# Stock:  CMPR
# Stock:  CMPS
# Stock:  CMPX
# Stock:  CMRE
# Stock:  CMRE-B
# Stock:  CMRE-C
# Stock:  CMRE-D
# Stock:  CMRE-E
# Stock:  CMRX
# Stock:  CMS
# Stock:  CMS-B
# Stock:  CMSA
# Stock:  CMSC
# Stock:  CMSD
# Stock:  CMT
# Stock:  CMTL
# Stock:  CMU
# Stock:  CN
# Stock:  CNA
# Stock:  CNBKA
# Stock:  CNBS
# Stock:  CNC
# Stock:  CNCE
# Stock:  CNCR
# Stock:  CND
# Stock:  CND.U
# Stock:  CNDT
# Stock:  CNET
# Stock:  CNEY
# Stock:  CNF
# Stock:  CNFR
# Stock:  CNFRL
# Stock:  CNHI
# Stock:  CNI
# Stock:  CNK
# Stock:  CNMD
# Stock:  CNNB
# Stock:  CNNE
# Stock:  CNO
# Stock:  CNO-A
# Stock:  CNOB
# Stock:  CNP
# Stock:  CNP-B
# Stock:  CNQ
# Stock:  CNR
# Stock:  CNRG
# Stock:  CNS
# Stock:  CNSL
# Stock:  CNSP
# Stock:  CNST
# Stock:  CNTFY
# Stock:  CNTG
# Stock:  CNTTQ
# Stock:  CNTY
# Stock:  CNX
# Stock:  CNXC
# Stock:  CNXN
# Stock:  CNXT
# Stock:  CNYA
# Stock:  CO
# Stock:  COCP
# Stock:  CODA
# Stock:  CODI
# Stock:  CODI-A
# Stock:  CODI-B
# Stock:  CODI-C
# Stock:  CODX
# Stock:  COE
# Stock:  COF
# Stock:  COF-G
# Stock:  COF-H
# Stock:  COF-I
# Stock:  COF-J
# Stock:  COF-K
# Stock:  COFS
# Stock:  COG
# Stock:  COGT
# Stock:  COHN
# Stock:  COHR
# Stock:  COHU
# Stock:  COIN
# Stock:  COKE
# Stock:  COLB
# Stock:  COLD
# Stock:  COLI
# Stock:  COLIU
# Stock:  COLL
# Stock:  COLM
# Stock:  COM
# Stock:  COMB
# Stock:  COMM
# Stock:  COMP
# Stock:  COMS
# Stock:  COMT
# Stock:  CONE
# Stock:  CONN
# Stock:  CONX
# Stock:  CONXU
# Stock:  COO
# Stock:  COOL
# Stock:  COOLU
# Stock:  COOP
# Stock:  COP
# Stock:  COPX
# Stock:  COR
# Stock:  CORE
# Stock:  CORN
# Stock:  CORP
# Stock:  CORR
# Stock:  CORR-A
# Stock:  CORT
# Stock:  COST
# Stock:  COTRP
# Stock:  COTY
# Stock:  COUP
# Stock:  COUR
# Stock:  COVA
# Stock:  COVAU
# Stock:  COW
# Stock:  COWN
# Stock:  COWNL
# Stock:  COWZ
# Stock:  CP
# Stock:  CPA
# Stock:  CPAC
# Stock:  CPB
# Stock:  CPE
# Stock:  CPER
# Stock:  CPF
# Stock:  CPG
# Stock:  CPHC
# Stock:  CPHI
# Stock:  CPI
# Stock:  CPIX
# Stock:  CPK
# Stock:  CPLG
# Stock:  CPLP
# Stock:  CPNG
# Stock:  CPRI
# Stock:  CPRT
# Stock:  CPRX
# Stock:  CPS
# Stock:  CPSH
# Stock:  CPSI
# Stock:  CPSR
# Stock:  CPSR.U
# Stock:  CPSS
# Stock:  CPT
# Stock:  CPTA
# Stock:  CPTAG
# Stock:  CPTAL
# Stock:  CPTK
# Stock:  CPTK.U
# Stock:  CPUH
# Stock:  CPUH.U
# Stock:  CPZ
# Stock:  CQP
# Stock:  CQQQ
# Stock:  CR
# Stock:  CRAI
# Stock:  CRAK
# Stock:  CRBN
# Stock:  CRBP
# Stock:  CRC
# Stock:  CRCT
# Stock:  CRD.A
# Stock:  CRDF
# Stock:  CREE
# Stock:  CRESY
# Stock:  CREX
# Stock:  CRF
# Stock:  CRH
# Stock:  CRHC
# Stock:  CRHC.U
# Stock:  CRI
# Stock:  CRIS
# Stock:  CRK
# Stock:  CRKN
# Stock:  CRL
# Stock:  CRM
# Stock:  CRMD
# Stock:  CRMT
# Stock:  CRNC
# Stock:  CRNT
# Stock:  CRNX
# Stock:  CROC
# Stock:  CRON
# Stock:  CROX
# Stock:  CRS
# Stock:  CRSA
# Stock:  CRSAU
# Stock:  CRSP
# Stock:  CRSR
# Stock:  CRT
# Stock:  CRTD
# Stock:  CRTO
# Stock:  CRTX
# Stock:  CRU
# Stock:  CRU.U
# Stock:  CRUS
# Stock:  CRVL
# Stock:  CRVS
# Stock:  CRWD
# Stock:  CRWS
# Stock:  CRY
# Stock:  CRZNU
# Stock:  CS
# Stock:  CSA
# Stock:  CSAN
# Stock:  CSB
# Stock:  CSBR
# Stock:  CSCO
# Stock:  CSD
# Stock:  CSGP
# Stock:  CSGS
# Stock:  CSII
# Stock:  CSIQ
# Stock:  CSL
# Stock:  CSLT
# Stock:  CSM
# Stock:  CSML
# Stock:  CSOD
# Stock:  CSPI
# Stock:  CSPR
# Stock:  CSQ
# Stock:  CSR
# Stock:  CSR-C
# Stock:  CSSE
# Stock:  CSSEN
# Stock:  CSSEP
# Stock:  CSTA
# Stock:  CSTA.U
# Stock:  CSTE
# Stock:  CSTL
# Stock:  CSTM
# Stock:  CSTR
# Stock:  CSU
# Stock:  CSV
# Stock:  CSWC
# Stock:  CSWI
# Stock:  CSX
# Stock:  CTA-A
# Stock:  CTA-B
# Stock:  CTAC
# Stock:  CTAC.U
# Stock:  CTAQ
# Stock:  CTAQU
# Stock:  CTAS
# Stock:  CTB
# Stock:  CTBB
# Stock:  CTBI
# Stock:  CTDD
# Stock:  CTEC
# Stock:  CTEK
# Stock:  CTG
# Stock:  CTHR
# Stock:  CTIB
# Stock:  CTIC
# Stock:  CTK
# Stock:  CTLP
# Stock:  CTLT
# Stock:  CTMX
# Stock:  CTO
# Stock:  CTOS
# Stock:  CTR
# Stock:  CTRM
# Stock:  CTRN
# Stock:  CTS
# Stock:  CTSH
# Stock:  CTSO
# Stock:  CTT
# Stock:  CTVA
# Stock:  CTXR
# Stock:  CTXS
# Stock:  CUBA
# Stock:  CUBB
# Stock:  CUBE
# Stock:  CUBI
# Stock:  CUBI-C
# Stock:  CUBI-D
# Stock:  CUBI-E
# Stock:  CUBI-F
# Stock:  CUE
# Stock:  CUEN
# Stock:  CUK
# Stock:  CULP
# Stock:  CURE
# Stock:  CURI
# Stock:  CURO
# Stock:  CUT
# Stock:  CUTR
# Stock:  CUZ
# Stock:  CVA
# Stock:  CVAC
# Stock:  CVBF
# Stock:  CVCO
# Stock:  CVCY
# Stock:  CVE
# Stock:  CVEO
# Stock:  CVET
# Stock:  CVGI
# Stock:  CVGW
# Stock:  CVI
# Stock:  CVII
# Stock:  CVII.U
# Stock:  CVLG
# Stock:  CVLT
# Stock:  CVLY
# Stock:  CVM
# Stock:  CVNA
# Stock:  CVR
# Stock:  CVS
# Stock:  CVU
# Stock:  CVV
# Stock:  CVX
# Stock:  CVY
# Stock:  CW
# Stock:  CWB
# Stock:  CWBC
# Stock:  CWBR
# Stock:  CWCO
# Stock:  CWEB
# Stock:  CWEN
# Stock:  CWEN.A
# Stock:  CWH
# Stock:  CWI
# Stock:  CWK
# Stock:  CWS
# Stock:  CWST
# Stock:  CWT
# Stock:  CX
# Stock:  CXDC
# Stock:  CXDO
# Stock:  CXE
# Stock:  CXH
# Stock:  CXP
# Stock:  CXSE
# Stock:  CXW
# Stock:  CYAD
# Stock:  CYAN
# Stock:  CYB
# Stock:  CYBE
# Stock:  CYBR
# Stock:  CYCC
# Stock:  CYCCP
# Stock:  CYCN
# Stock:  CYD
# Stock:  CYH
# Stock:  CYRN
# Stock:  CYRX
# Stock:  CYTH
# Stock:  CYTK
# Stock:  CYTR
# Stock:  CZA
# Stock:  CZNC
# Stock:  CZR
# Stock:  CZWI
# Stock:  D
# Stock:  DAC
# Stock:  DADA
# Stock:  DAGXF
# Stock:  DAIO
# Stock:  DAKT
# Stock:  DAL
# Stock:  DALI
# Stock:  DALT
# Stock:  DAN
# Stock:  DAO
# Stock:  DAPP
# Stock:  DAPR
# Stock:  DAR
# Stock:  DARE
# Stock:  DASH
# Stock:  DAUG
# Stock:  DAVA
# Stock:  DAX
# Stock:  DB
# Stock:  DBA
# Stock:  DBAW
# Stock:  DBB
# Stock:  DBC
# Stock:  DBD
# Stock:  DBDR
# Stock:  DBDRU
# Stock:  DBE
# Stock:  DBEF
# Stock:  DBEH
# Stock:  DBEM
# Stock:  DBEU
# Stock:  DBEZ
# Stock:  DBGR
# Stock:  DBI
# Stock:  DBJA
# Stock:  DBJP
# Stock:  DBL
# Stock:  DBLV
# Stock:  DBMF
# Stock:  DBO
# Stock:  DBOC
# Stock:  DBP
# Stock:  DBS
# Stock:  DBTX
# Stock:  DBV
# Stock:  DBVT
# Stock:  DBX
# Stock:  DCBO
# Stock:  DCF
# Stock:  DCI
# Stock:  DCO
# Stock:  DCOM
# Stock:  DCOMP
# Stock:  DCP
# Stock:  DCP-B
# Stock:  DCP-C
# Stock:  DCPH
# Stock:  DCRB
# Stock:  DCRBU
# Stock:  DCRCU
# Stock:  DCRN
# Stock:  DCRNU
# Stock:  DCT
# Stock:  DCTH
# Stock:  DCUE
# Stock:  DD
# Stock:  DDD
# Stock:  DDEC
# Stock:  DDF
# Stock:  DDG
# Stock:  DDIV
# Stock:  DDLS
# Stock:  DDM
# Stock:  DDMX
# Stock:  DDMXU
# Stock:  DDOG
# Stock:  DDPXF
# Stock:  DDS
# Stock:  DDT
# Stock:  DDWM
# Stock:  DE
# Stock:  DEA
# Stock:  DECK
# Stock:  DECZ
# Stock:  DEED
# Stock:  DEEF
# Stock:  DEENF
# Stock:  DEEP
# Stock:  DEF
# Stock:  DEFA
# Stock:  DEFN
# Stock:  DEH
# Stock:  DEH.U
# Stock:  DEI
# Stock:  DELL
# Stock:  DEM
# Stock:  DEMZ
# Stock:  DEN
# Stock:  DENN
# Stock:  DEO
# Stock:  DES
# Stock:  DESP
# Stock:  DESTQ
# Stock:  DEUS
# Stock:  DEW
# Stock:  DEX
# Stock:  DFAE
# Stock:  DFAI
# Stock:  DFAU
# Stock:  DFE
# Stock:  DFEB
# Stock:  DFEN
# Stock:  DFFN
# Stock:  DFH
# Stock:  DFHT
# Stock:  DFHTU
# Stock:  DFHY
# Stock:  DFIN
# Stock:  DFJ
# Stock:  DFND
# Stock:  DFNL
# Stock:  DFNS
# Stock:  DFNS.U
# Stock:  DFNV
# Stock:  DFODQ
# Stock:  DFP
# Stock:  DFPH
# Stock:  DFPHU
# Stock:  DFS
# Stock:  DFVL
# Stock:  DFVS
# Stock:  DG
# Stock:  DGICA
# Stock:  DGICB
# Stock:  DGII
# Stock:  DGL
# Stock:  DGLDF
# Stock:  DGLY
# Stock:  DGNR
# Stock:  DGNR.U
# Stock:  DGNS
# Stock:  DGNU
# Stock:  DGP
# Stock:  DGRE
# Stock:  DGRO
# Stock:  DGRS
# Stock:  DGRW
# Stock:  DGS
# Stock:  DGT
# Stock:  DGX
# Stock:  DGZ
# Stock:  DHBC
# Stock:  DHBCU
# Stock:  DHC
# Stock:  DHCA
# Stock:  DHCAU
# Stock:  DHCNI
# Stock:  DHCNL
# Stock:  DHF
# Stock:  DHHC
# Stock:  DHHCU
# Stock:  DHI
# Stock:  DHIL
# Stock:  DHR
# Stock:  DHR-A
# Stock:  DHR-B
# Stock:  DHS
# Stock:  DHT
# Stock:  DIA
# Stock:  DIAL
# Stock:  DIAX
# Stock:  DIG
# Stock:  DIM
# Stock:  DIN
# Stock:  DINT
# Stock:  DIOD
# Stock:  DIS
# Stock:  DISAU
# Stock:  DISCA
# Stock:  DISCB
# Stock:  DISCK
# Stock:  DISH
# Stock:  DIT
# Stock:  DIV
# Stock:  DIVA
# Stock:  DIVB
# Stock:  DIVO
# Stock:  DIVS
# Stock:  DIVZ
# Stock:  DJAN
# Stock:  DJCB
# Stock:  DJCO
# Stock:  DJD
# Stock:  DJP
# Stock:  DJUL
# Stock:  DJUN
# Stock:  DK
# Stock:  DKL
# Stock:  DKNG
# Stock:  DKS
# Stock:  DLA
# Stock:  DLB
# Stock:  DLCA
# Stock:  DLCAU
# Stock:  DLHC
# Stock:  DLN
# Stock:  DLNG
# Stock:  DLNG-A
# Stock:  DLNG-B
# Stock:  DLPN
# Stock:  DLR
# Stock:  DLR-C
# Stock:  DLR-J
# Stock:  DLR-K
# Stock:  DLR-L
# Stock:  DLS
# Stock:  DLTH
# Stock:  DLTR
# Stock:  DLX
# Stock:  DLY
# Stock:  DM
# Stock:  DMAC
# Stock:  DMAR
# Stock:  DMAY
# Stock:  DMB
# Stock:  DMCY
# Stock:  DMDV
# Stock:  DMF
# Stock:  DMLP
# Stock:  DMO
# Stock:  DMRC
# Stock:  DMRE
# Stock:  DMRI
# Stock:  DMRL
# Stock:  DMRM
# Stock:  DMRS
# Stock:  DMS
# Stock:  DMTK
# Stock:  DMXF
# Stock:  DMYI
# Stock:  DMYI.U
# Stock:  DMYQ
# Stock:  DMYQ.U
# Stock:  DNB
# Stock:  DNIF
# Stock:  DNL
# Stock:  DNLI
# Stock:  DNMR
# Stock:  DNN
# Stock:  DNOV
# Stock:  DNOW
# Stock:  DNP
# Stock:  DNZ
# Stock:  DNZ.U
# Stock:  DOC
# Stock:  DOCN
# Stock:  DOCT
# Stock:  DOCU
# Stock:  DODXF
# Stock:  DOG
# Stock:  DOGZ
# Stock:  DOL
# Stock:  DOMO
# Stock:  DON
# Stock:  DOO
# Stock:  DOOO
# Stock:  DOOR
# Stock:  DORM
# Stock:  DOV
# Stock:  DOW
# Stock:  DOX
# Stock:  DOYU
# Stock:  DPG
# Stock:  DPST
# Stock:  DPW
# Stock:  DPZ
# Stock:  DQ
# Stock:  DRD
# Stock:  DRE
# Stock:  DRH
# Stock:  DRH-A
# Stock:  DRI
# Stock:  DRIO
# Stock:  DRIP
# Stock:  DRIV
# Stock:  DRN
# Stock:  DRNA
# Stock:  DRRX
# Stock:  DRSK
# Stock:  DRTT
# Stock:  DRUA
# Stock:  DRV
# Stock:  DRVN
# Stock:  DRW
# Stock:  DS-B
# Stock:  DS-C
# Stock:  DS-D
# Stock:  DSAC
# Stock:  DSACU
# Stock:  DSE
# Stock:  DSEP
# Stock:  DSGN
# Stock:  DSI
# Stock:  DSJA
# Stock:  DSKE
# Stock:  DSL
# Stock:  DSLVF
# Stock:  DSM
# Stock:  DSOC
# Stock:  DSP
# Stock:  DSPG
# Stock:  DSS
# Stock:  DSSI
# Stock:  DSTL
# Stock:  DSTX
# Stock:  DSU
# Stock:  DSWL
# Stock:  DSX
# Stock:  DSX-B
# Stock:  DT
# Stock:  DTB
# Stock:  DTD
# Stock:  DTE
# Stock:  DTEC
# Stock:  DTF
# Stock:  DTH
# Stock:  DTIL
# Stock:  DTJ
# Stock:  DTLA-
# Stock:  DTOCU
# Stock:  DTP
# Stock:  DTSS
# Stock:  DTW
# Stock:  DTY
# Stock:  DUDE
# Stock:  DUG
# Stock:  DUK-A
# Stock:  DUKB
# Stock:  DUKH
# Stock:  DUNE
# Stock:  DUNEU
# Stock:  DUO
# Stock:  DURA
# Stock:  DUSA
# Stock:  DUSL
# Stock:  DUST
# Stock:  DV
# Stock:  DVAX
# Stock:  DVCR
# Stock:  DVD
# Stock:  DVLU
# Stock:  DVN
# Stock:  DVY
# Stock:  DVYA
# Stock:  DVYE
# Stock:  DWAS
# Stock:  DWAT
# Stock:  DWCR
# Stock:  DWEQ
# Stock:  DWIN
# Stock:  DWIN.U
# Stock:  DWLD
# Stock:  DWMC
# Stock:  DWMF
# Stock:  DWPP
# Stock:  DWSH
# Stock:  DWSN
# Stock:  DWX
# Stock:  DX
# Stock:  DX-C
# Stock:  DXC
# Stock:  DXCM
# Stock:  DXD
# Stock:  DXF
# Stock:  DXJ
# Stock:  DXJS
# Stock:  DXLG
# Stock:  DXPE
# Stock:  DXR
# Stock:  DYAI
# Stock:  DYFN
# Stock:  DYHG
# Stock:  DYN
# Stock:  DYNF
# Stock:  DYSL
# Stock:  DYYXF
# Stock:  DZSI
# Stock:  DZZ
# Stock:  E
# Stock:  EAC
# Stock:  EACPU
# Stock:  EAD
# Stock:  EAF
# Stock:  EAOA
# Stock:  EAOK
# Stock:  EAOM
# Stock:  EAOR
# Stock:  EARN
# Stock:  EARS
# Stock:  EASG
# Stock:  EAST
# Stock:  EB
# Stock:  EBACU
# Stock:  EBAY
# Stock:  EBC
# Stock:  EBF
# Stock:  EBIZ
# Stock:  EBLU
# Stock:  EBMT
# Stock:  EBND
# Stock:  EBR.B
# Stock:  EBS
# Stock:  EBSB
# Stock:  EBTC
# Stock:  ECCB
# Stock:  ECCX
# Stock:  ECCY
# Stock:  ECF-A
# Stock:  ECHO
# Stock:  ECNS
# Stock:  ECON
# Stock:  ECOZ
# Stock:  ED
# Stock:  EDD
# Stock:  EDI
# Stock:  EDOW
# Stock:  EDU
# Stock:  EEFT
# Stock:  EEMD
# Stock:  EES
# Stock:  EEV
# Stock:  EFAX
# Stock:  EFC-A
# Stock:  EFIX
# Stock:  EFSC
# Stock:  EGAN
# Stock:  EGLE
# Stock:  EGRX
# Stock:  EHT
# Stock:  EIGR
# Stock:  EIX
# Stock:  EJFAU
# Stock:  ELDN
# Stock:  EMLP
# Stock:  EMPW.U
# Stock:  EMR
# Stock:  EMTL
# Stock:  EMX
# Stock:  ENBL
# Stock:  ENFAU
# Stock:  ENG
# Stock:  ENJ
# Stock:  ENLC
# Stock:  ENLV
# Stock:  ENO
# Stock:  ENOR
# Stock:  ENPH
# Stock:  ENR-A
# Stock:  ENS
# Stock:  ENTA
# Stock:  ENTR
# Stock:  ENVA
# Stock:  ENVI
# Stock:  ENZ
# Stock:  EOD
# Stock:  EOLS
# Stock:  EOS
# Stock:  EOSE
# Stock:  EP-C
# Stock:  EPAM
# Stock:  EPAY
# Stock:  EPC
# Stock:  EPHY
# Stock:  EPHYU
# Stock:  EPI
# Stock:  EPOL
# Stock:  EPP
# Stock:  EPR
# Stock:  EPR-C
# Stock:  EPR-E
# Stock:  EPR-G
# Stock:  EPS
# Stock:  EPSN
# Stock:  EPU
# Stock:  EPV
# Stock:  EPWR
# Stock:  EPZM
# Stock:  EQ
# Stock:  EQAL
# Stock:  EQBK
# Stock:  EQC
# Stock:  EQC-D
# Stock:  EQD
# Stock:  EQD.U
# Stock:  EQFN
# Stock:  EQH
# Stock:  EQH-A
# Stock:  EQH-C
# Stock:  EQHA
# Stock:  EQHA.U
# Stock:  EQIX
# Stock:  EQL
# Stock:  EQNR
# Stock:  EQOP
# Stock:  EQOS
# Stock:  EQR
# Stock:  EQRR
# Stock:  EQWL
# Stock:  EQX
# Stock:  ERC
# Stock:  ERES
# Stock:  ERESU
# Stock:  ERF
# Stock:  ERH
# Stock:  ERIC
# Stock:  ERIE
# Stock:  ERII
# Stock:  ERJ
# Stock:  ERLFF
# Stock:  ERM
# Stock:  ERSX
# Stock:  ERTH
# Stock:  ERUS
# Stock:  ERX
# Stock:  ERY
# Stock:  ERYP
# Stock:  ES
# Stock:  ESBA
# Stock:  ESBK
# Stock:  ESCA
# Stock:  ESCR
# Stock:  ESE
# Stock:  ESEA
# Stock:  ESEB
# Stock:  ESG
# Stock:  ESGA
# Stock:  ESGC
# Stock:  ESGD
# Stock:  ESGE
# Stock:  ESGG
# Stock:  ESGN
# Stock:  ESGR
# Stock:  ESGRO
# Stock:  ESGRP
# Stock:  ESGS
# Stock:  ESGU
# Stock:  ESGV
# Stock:  ESHY
# Stock:  ESI
# Stock:  ESLT
# Stock:  ESM.U
# Stock:  ESML
# Stock:  ESNC
# Stock:  ESNG
# Stock:  ESNT
# Stock:  ESP
# Stock:  ESPO
# Stock:  ESPR
# Stock:  ESQ
# Stock:  ESRT
# Stock:  ESS
# Stock:  ESSA
# Stock:  ESSC
# Stock:  ESSCR
# Stock:  ESSCU
# Stock:  ESTA
# Stock:  ESTC
# Stock:  ESTE
# Stock:  ESTRF
# Stock:  ESXB
# Stock:  ET
# Stock:  ET-C
# Stock:  ET-D
# Stock:  ET-E
# Stock:  ETAC
# Stock:  ETACU
# Stock:  ETB
# Stock:  ETG
# Stock:  ETH
# Stock:  ETHO
# Stock:  ETI-
# Stock:  ETJ
# Stock:  ETN
# Stock:  ETNB
# Stock:  ETO
# Stock:  ETON
# Stock:  ETR
# Stock:  ETRN
# Stock:  ETSY
# Stock:  ETTX
# Stock:  ETV
# Stock:  ETW
# Stock:  ETWO
# Stock:  ETX
# Stock:  EUCG
# Stock:  EUCR
# Stock:  EUCRU
# Stock:  EUDG
# Stock:  EUDV
# Stock:  EUFN
# Stock:  EUFX
# Stock:  EUM
# Stock:  EUO
# Stock:  EURL
# Stock:  EURN
# Stock:  EURZ
# Stock:  EUSA
# Stock:  EUSB
# Stock:  EUSC
# Stock:  EUSG
# Stock:  EUSGU
# Stock:  EVA
# Stock:  EVBG
# Stock:  EVBN
# Stock:  EVC
# Stock:  EVER
# Stock:  EVF
# Stock:  EVFM
# Stock:  EVGN
# Stock:  EVH
# Stock:  EVI
# Stock:  EVK
# Stock:  EVM
# Stock:  EVN
# Stock:  EVOJ
# Stock:  EVOJU
# Stock:  EVOK
# Stock:  EVOL
# Stock:  EVOP
# Stock:  EVRG
# Stock:  EVRI
# Stock:  EVT
# Stock:  EVTC
# Stock:  EVV
# Stock:  EVX
# Stock:  EVY
# Stock:  EW
# Stock:  EWA
# Stock:  EWBC
# Stock:  EWC
# Stock:  EWCO
# Stock:  EWD
# Stock:  EWEB
# Stock:  EWG
# Stock:  EWGS
# Stock:  EWH
# Stock:  EWI
# Stock:  EWJ
# Stock:  EWJE
# Stock:  EWJV
# Stock:  EWK
# Stock:  EWL
# Stock:  EWM
# Stock:  EWMC
# Stock:  EWN
# Stock:  EWO
# Stock:  EWP
# Stock:  EWQ
# Stock:  EWRE
# Stock:  EWS
# Stock:  EWSC
# Stock:  EWT
# Stock:  EWTX
# Stock:  EWU
# Stock:  EWUS
# Stock:  EWV
# Stock:  EWW
# Stock:  EWX
# Stock:  EWY
# Stock:  EWZ
# Stock:  EWZS
# Stock:  EXAS
# Stock:  EXC
# Stock:  EXD
# Stock:  EXEL
# Stock:  EXFO
# Stock:  EXG
# Stock:  EXI
# Stock:  EXK
# Stock:  EXLS
# Stock:  EXN
# Stock:  EXP
# Stock:  EXPC
# Stock:  EXPCU
# Stock:  EXPD
# Stock:  EXPE
# Stock:  EXPI
# Stock:  EXPO
# Stock:  EXPR
# Stock:  EXR
# Stock:  EXTN
# Stock:  EXTR
# Stock:  EYE
# Stock:  EYEG
# Stock:  EYEN
# Stock:  EYES
# Stock:  EYLD
# Stock:  EYPT
# Stock:  EZA
# Stock:  EZGO
# Stock:  EZJ
# Stock:  EZM
# Stock:  EZPW
# Stock:  EZU
# Stock:  F
# Stock:  F-B
# Stock:  F-C
# Stock:  FAAR
# Stock:  FAB
# Stock:  FACA
# Stock:  FACA.U
# Stock:  FACT
# Stock:  FAD
# Stock:  FAF
# Stock:  FAII
# Stock:  FAII.U
# Stock:  FALN
# Stock:  FAM
# Stock:  FAMI
# Stock:  FAN
# Stock:  FANG
# Stock:  FAPR
# Stock:  FARM
# Stock:  FARO
# Stock:  FAS
# Stock:  FAST
# Stock:  FATBP
# Stock:  FATE
# Stock:  FAUG
# Stock:  FAX
# Stock:  FB
# Stock:  FBC
# Stock:  FBCG
# Stock:  FBCV
# Stock:  FBHS
# Stock:  FBIO
# Stock:  FBIOP
# Stock:  FBIZ
# Stock:  FBK
# Stock:  FBNC
# Stock:  FBND
# Stock:  FBP
# Stock:  FBRX
# Stock:  FBZ
# Stock:  FC
# Stock:  FCA
# Stock:  FCAC
# Stock:  FCACU
# Stock:  FCAL
# Stock:  FCAP
# Stock:  FCAX
# Stock:  FCAX.U
# Stock:  FCBC
# Stock:  FCBP
# Stock:  FCCO
# Stock:  FCCY
# Stock:  FCEF
# Stock:  FCEL
# Stock:  FCF
# Stock:  FCFS
# Stock:  FCG
# Stock:  FCNCA
# Stock:  FCNCP
# Stock:  FCO
# Stock:  FCOM
# Stock:  FCOR
# Stock:  FCPI
# Stock:  FCPT
# Stock:  FCRD
# Stock:  FCRW
# Stock:  FCRZ
# Stock:  FCT
# Stock:  FCTR
# Stock:  FCVT
# Stock:  FCX
# Stock:  FDBC
# Stock:  FDD
# Stock:  FDEC
# Stock:  FDEM
# Stock:  FDEU
# Stock:  FDEV
# Stock:  FDG
# Stock:  FDHY
# Stock:  FDIS
# Stock:  FDIV
# Stock:  FDL
# Stock:  FDLO
# Stock:  FDM
# Stock:  FDMO
# Stock:  FDMT
# Stock:  FDN
# Stock:  FDNI
# Stock:  FDP
# Stock:  FDRR
# Stock:  FDS
# Stock:  FDT
# Stock:  FDTS
# Stock:  FDUS
# Stock:  FDUSG
# Stock:  FDUSZ
# Stock:  FDX
# Stock:  FE
# Stock:  FEBZ
# Stock:  FEDU
# Stock:  FEDX
# Stock:  FEIM
# Stock:  FELE
# Stock:  FEM
# Stock:  FEMB
# Stock:  FEN
# Stock:  FENC
# Stock:  FENG
# Stock:  FENY
# Stock:  FEP
# Stock:  FERG
# Stock:  FET
# Stock:  FEUL
# Stock:  FEUZ
# Stock:  FEVR
# Stock:  FEX
# Stock:  FEZ
# Stock:  FF
# Stock:  FFA
# Stock:  FFBC
# Stock:  FFC
# Stock:  FFEB
# Stock:  FFG
# Stock:  FFHG
# Stock:  FFIC
# Stock:  FFIN
# Stock:  FFIU
# Stock:  FFIV
# Stock:  FFNW
# Stock:  FFR
# Stock:  FFSG
# Stock:  FFTG
# Stock:  FFTI
# Stock:  FFTY
# Stock:  FFWM
# Stock:  FGB
# Stock:  FGBI
# Stock:  FGD
# Stock:  FGEN
# Stock:  FGF
# Stock:  FGFPP
# Stock:  FGM
# Stock:  FGNA
# Stock:  FGNA.U
# Stock:  FGRO
# Stock:  FHB
# Stock:  FHI
# Stock:  FHLC
# Stock:  FHN
# Stock:  FHN-A
# Stock:  FHN-B
# Stock:  FHN-C
# Stock:  FHN-D
# Stock:  FHN-E
# Stock:  FHS
# Stock:  FHTX
# Stock:  FI
# Stock:  FIBK
# Stock:  FIBR
# Stock:  FICO
# Stock:  FICS
# Stock:  FID
# Stock:  FIDI
# Stock:  FIDU
# Stock:  FIEE
# Stock:  FIEGF
# Stock:  FIF
# Stock:  FIGB
# Stock:  FIHD
# Stock:  FIII
# Stock:  FIIIU
# Stock:  FILL
# Stock:  FINM
# Stock:  FINMU
# Stock:  FINS
# Stock:  FINV
# Stock:  FINX
# Stock:  FIS
# Stock:  FISI
# Stock:  FISK
# Stock:  FISR
# Stock:  FISV
# Stock:  FITB
# Stock:  FITBI
# Stock:  FITBO
# Stock:  FITE
# Stock:  FIV
# Stock:  FIVA
# Stock:  FIVE
# Stock:  FIVN
# Stock:  FIW
# Stock:  FIX
# Stock:  FIXD
# Stock:  FIZZ
# Stock:  FJAN
# Stock:  FJNK
# Stock:  FJP
# Stock:  FJUN
# Stock:  FKU
# Stock:  FKWL
# Stock:  FL
# Stock:  FLACU
# Stock:  FLAU
# Stock:  FLAX
# Stock:  FLBL
# Stock:  FLBR
# Stock:  FLC
# Stock:  FLCA
# Stock:  FLCB
# Stock:  FLCH
# Stock:  FLCO
# Stock:  FLDM
# Stock:  FLEE
# Stock:  FLEH
# Stock:  FLEX
# Stock:  FLFG
# Stock:  FLGB
# Stock:  FLGE
# Stock:  FLGR
# Stock:  FLGT
# Stock:  FLHK
# Stock:  FLHY
# Stock:  FLIA
# Stock:  FLIC
# Stock:  FLIR
# Stock:  FLIY
# Stock:  FLJH
# Stock:  FLJP
# Stock:  FLL
# Stock:  FLLA
# Stock:  FLLV
# Stock:  FLM
# Stock:  FLMB
# Stock:  FLME
# Stock:  FLME.U
# Stock:  FLMI
# Stock:  FLMN
# Stock:  FLMX
# Stock:  FLN
# Stock:  FLNG
# Stock:  FLNT
# Stock:  FLO
# Stock:  FLOT
# Stock:  FLOW
# Stock:  FLQD
# Stock:  FLQE
# Stock:  FLQG
# Stock:  FLQH
# Stock:  FLQL
# Stock:  FLQM
# Stock:  FLQS
# Stock:  FLR
# Stock:  FLRG
# Stock:  FLRN
# Stock:  FLRT
# Stock:  FLRU
# Stock:  FLS
# Stock:  FLSA
# Stock:  FLSP
# Stock:  FLSW
# Stock:  FLT
# Stock:  FLTB
# Stock:  FLTR
# Stock:  FLTW
# Stock:  FLUD
# Stock:  FLUX
# Stock:  FLV
# Stock:  FLWS
# Stock:  FLXN
# Stock:  FLXS
# Stock:  FLY
# Stock:  FLYT
# Stock:  FLZA
# Stock:  FM
# Stock:  FMAC
# Stock:  FMAC.U
# Stock:  FMAG
# Stock:  FMAO
# Stock:  FMAR
# Stock:  FMAT
# Stock:  FMAY
# Stock:  FMB
# Stock:  FMBH
# Stock:  FMBI
# Stock:  FMBIO
# Stock:  FMBIP
# Stock:  FMC
# Stock:  FMF
# Stock:  FMHI
# Stock:  FMIL
# Stock:  FMIVU
# Stock:  FMN
# Stock:  FMNB
# Stock:  FMO
# Stock:  FMS
# Stock:  FMTX
# Stock:  FMX
# Stock:  FMY
# Stock:  FN
# Stock:  FNB
# Stock:  FNB-E
# Stock:  FNCB
# Stock:  FNCH
# Stock:  FNCL
# Stock:  FND
# Stock:  FNDA
# Stock:  FNDB
# Stock:  FNDC
# Stock:  FNDE
# Stock:  FNDF
# Stock:  FNDX
# Stock:  FNF
# Stock:  FNGD
# Stock:  FNGO
# Stock:  FNGS
# Stock:  FNGU
# Stock:  FNGZ
# Stock:  FNHC
# Stock:  FNI
# Stock:  FNK
# Stock:  FNKO
# Stock:  FNLC
# Stock:  FNOV
# Stock:  FNV
# Stock:  FNWB
# Stock:  FNX
# Stock:  FNY
# Stock:  FOA
# Stock:  FOCS
# Stock:  FOCT
# Stock:  FOE
# Stock:  FOF
# Stock:  FOLD
# Stock:  FONR
# Stock:  FOR
# Stock:  FORA
# Stock:  FORD
# Stock:  FORE
# Stock:  FOREU
# Stock:  FORM
# Stock:  FORR
# Stock:  FORTY
# Stock:  FOSL
# Stock:  FOUR
# Stock:  FOVL
# Stock:  FOX
# Stock:  FOXA
# Stock:  FOXF
# Stock:  FOXW
# Stock:  FOXWU
# Stock:  FPA
# Stock:  FPAC
# Stock:  FPAC.U
# Stock:  FPAY
# Stock:  FPE
# Stock:  FPEI
# Stock:  FPF
# Stock:  FPH
# Stock:  FPI
# Stock:  FPI-B
# Stock:  FPL
# Stock:  FPRO
# Stock:  FPX
# Stock:  FPXE
# Stock:  FPXI
# Stock:  FQAL
# Stock:  FR
# Stock:  FRA
# Stock:  FRAF
# Stock:  FRAK
# Stock:  FRANQ
# Stock:  FRBA
# Stock:  FRBK
# Stock:  FRC
# Stock:  FRC-H
# Stock:  FRC-I
# Stock:  FRC-J
# Stock:  FRC-K
# Stock:  FRC-L
# Stock:  FRD
# Stock:  FRDM
# Stock:  FREE
# Stock:  FREL
# Stock:  FREQ
# Stock:  FRG
# Stock:  FRGAP
# Stock:  FRGI
# Stock:  FRHC
# Stock:  FRI
# Stock:  FRLG
# Stock:  FRLN
# Stock:  FRME
# Stock:  FROG
# Stock:  FRONU
# Stock:  FRPH
# Stock:  FRPT
# Stock:  FRSGU
# Stock:  FRST
# Stock:  FRSX
# Stock:  FRT
# Stock:  FRT-C
# Stock:  FRTA
# Stock:  FRTY
# Stock:  FRWAU
# Stock:  FRX.U
# Stock:  FRXB.U
# Stock:  FSBW
# Stock:  FSD
# Stock:  FSEA
# Stock:  FSEC
# Stock:  FSEP
# Stock:  FSFG
# Stock:  FSI
# Stock:  FSII
# Stock:  FSK
# Stock:  FSKR
# Stock:  FSLF
# Stock:  FSLR
# Stock:  FSLY
# Stock:  FSM
# Stock:  FSMB
# Stock:  FSMO
# Stock:  FSNB
# Stock:  FSNB.U
# Stock:  FSP
# Stock:  FSR
# Stock:  FSRV
# Stock:  FSRVU
# Stock:  FSRX
# Stock:  FSRXU
# Stock:  FSS
# Stock:  FSSI
# Stock:  FSSIU
# Stock:  FST
# Stock:  FST.U
# Stock:  FSTA
# Stock:  FSTR
# Stock:  FSTX
# Stock:  FSV
# Stock:  FSZ
# Stock:  FT
# Stock:  FTAA
# Stock:  FTAAU
# Stock:  FTAG
# Stock:  FTAI
# Stock:  FTAI-A
# Stock:  FTAI-B
# Stock:  FTAI-C
# Stock:  FTC
# Stock:  FTCS
# Stock:  FTCV
# Stock:  FTCVU
# Stock:  FTDR
# Stock:  FTEC
# Stock:  FTEV
# Stock:  FTEV.U
# Stock:  FTF
# Stock:  FTFT
# Stock:  FTGC
# Stock:  FTHI
# Stock:  FTHM
# Stock:  FTHY
# Stock:  FTI
# Stock:  FTIV
# Stock:  FTIVU
# Stock:  FTK
# Stock:  FTLB
# Stock:  FTLS
# Stock:  FTNT
# Stock:  FTOC
# Stock:  FTOCU
# Stock:  FTPAU
# Stock:  FTRCQ
# Stock:  FTRI
# Stock:  FTS
# Stock:  FTSD
# Stock:  FTSI
# Stock:  FTSL
# Stock:  FTV
# Stock:  FTV-A
# Stock:  FTXD
# Stock:  FTXG
# Stock:  FTXH
# Stock:  FTXL
# Stock:  FTXN
# Stock:  FTXO
# Stock:  FTXR
# Stock:  FUBO
# Stock:  FUE
# Stock:  FUL
# Stock:  FULC
# Stock:  FULT
# Stock:  FULTP
# Stock:  FUMB
# Stock:  FUN
# Stock:  FUNC
# Stock:  FUND
# Stock:  FUNL
# Stock:  FURY
# Stock:  FUSB
# Stock:  FUSE
# Stock:  FUSE.U
# Stock:  FUSN
# Stock:  FUT
# Stock:  FUTU
# Stock:  FUTY
# Stock:  FUV
# Stock:  FV
# Stock:  FVAL
# Stock:  FVAM
# Stock:  FVC
# Stock:  FVCB
# Stock:  FVD
# Stock:  FVE
# Stock:  FVIV.U
# Stock:  FVRR
# Stock:  FVT
# Stock:  FVT.U
# Stock:  FWAA
# Stock:  FWDB
# Stock:  FWONA
# Stock:  FWONK
# Stock:  FWP
# Stock:  FWRD
# Stock:  FXA
# Stock:  FXB
# Stock:  FXC
# Stock:  FXD
# Stock:  FXE
# Stock:  FXF
# Stock:  FXH
# Stock:  FXI
# Stock:  FXL
# Stock:  FXN
# Stock:  FXO
# Stock:  FXP
# Stock:  FXR
# Stock:  FXU
# Stock:  FXY
# Stock:  FXZ
# Stock:  FYC
# Stock:  FYLD
# Stock:  FYT
# Stock:  FYX
# Stock:  FZT.U
# Stock:  G
# Stock:  GAA
# Stock:  GAB
# Stock:  GAB-G
# Stock:  GAB-H
# Stock:  GAB-J
# Stock:  GAB-K
# Stock:  GABC
# Stock:  GAIA
# Stock:  GAIN
# Stock:  GAINL
# Stock:  GAINN
# Stock:  GAL
# Stock:  GALT
# Stock:  GAM
# Stock:  GAM-B
# Stock:  GAMCU
# Stock:  GAMR
# Stock:  GAN
# Stock:  GANX
# Stock:  GAPA.U
# Stock:  GASS
# Stock:  GATO
# Stock:  GAU
# Stock:  GAZ
# Stock:  GB
# Stock:  GBAB
# Stock:  GBCI
# Stock:  GBDC
# Stock:  GBDV
# Stock:  GBF
# Stock:  GBGR
# Stock:  GBIL
# Stock:  GBIO
# Stock:  GBL
# Stock:  GBLD
# Stock:  GBLI
# Stock:  GBLIL
# Stock:  GBLO
# Stock:  GBNH
# Stock:  GBNY
# Stock:  GBOX
# Stock:  GBR
# Stock:  GBRG
# Stock:  GBRGR
# Stock:  GBRGU
# Stock:  GBS
# Stock:  GBT
# Stock:  GBUG
# Stock:  GBX
# Stock:  GCAC
# Stock:  GCACU
# Stock:  GCBC
# Stock:  GCC
# Stock:  GCEC
# Stock:  GCI
# Stock:  GCMG
# Stock:  GCO
# Stock:  GCOR
# Stock:  GCOW
# Stock:  GCP
# Stock:  GCV
# Stock:  GD
# Stock:  GDDY
# Stock:  GDEN
# Stock:  GDL
# Stock:  GDL-C
# Stock:  GDMA
# Stock:  GDO
# Stock:  GDOT
# Stock:  GDP
# Stock:  GDS
# Stock:  GDV
# Stock:  GDV-G
# Stock:  GDV-H
# Stock:  GDX
# Stock:  GDXD
# Stock:  GDXU
# Stock:  GDYN
# Stock:  GE
# Stock:  GECC
# Stock:  GECCL
# Stock:  GECCM
# Stock:  GECCN
# Stock:  GEF
# Stock:  GEF.B
# Stock:  GEG
# Stock:  GEL
# Stock:  GEM
# Stock:  GENC
# Stock:  GENE
# Stock:  GENI
# Stock:  GENN
# Stock:  GENY
# Stock:  GEO
# Stock:  GEOS
# Stock:  GER
# Stock:  GERM
# Stock:  GERN
# Stock:  GES
# Stock:  GEVO
# Stock:  GF
# Stock:  GFASY
# Stock:  GFED
# Stock:  GFF
# Stock:  GFI
# Stock:  GFL
# Stock:  GFLU
# Stock:  GFN
# Stock:  GFNCP
# Stock:  GFNSZ
# Stock:  GFX
# Stock:  GFX.U
# Stock:  GGB
# Stock:  GGG
# Stock:  GGM
# Stock:  GGMCU
# Stock:  GGN-B
# Stock:  GGO
# Stock:  GGO-A
# Stock:  GGPIU
# Stock:  GGRW
# Stock:  GGT
# Stock:  GGT-E
# Stock:  GGT-G
# Stock:  GGZ
# Stock:  GGZ-A
# Stock:  GHAC
# Stock:  GHACU
# Stock:  GHC
# Stock:  GHG
# Stock:  GHLD
# Stock:  GHM
# Stock:  GHSI
# Stock:  GHVI
# Stock:  GHVIU
# Stock:  GHY
# Stock:  GHYB
# Stock:  GHYG
# Stock:  GIB
# Stock:  GIFI
# Stock:  GIG
# Stock:  GIGB
# Stock:  GIGE
# Stock:  GIGGU
# Stock:  GIGM
# Stock:  GII
# Stock:  GIII
# Stock:  GIIXU
# Stock:  GIK
# Stock:  GIK.U
# Stock:  GIL
# Stock:  GILD
# Stock:  GILT
# Stock:  GIM
# Stock:  GINN
# Stock:  GIS
# Stock:  GIX
# Stock:  GIX.RT
# Stock:  GIX.U
# Stock:  GJH
# Stock:  GJO
# Stock:  GJP
# Stock:  GJR
# Stock:  GJS
# Stock:  GJT
# Stock:  GKOS
# Stock:  GL
# Stock:  GL-C
# Stock:  GLAD
# Stock:  GLADL
# Stock:  GLAQ
# Stock:  GLAQU
# Stock:  GLBL
# Stock:  GLBLU
# Stock:  GLBS
# Stock:  GLBZ
# Stock:  GLCN
# Stock:  GLD
# Stock:  GLDD
# Stock:  GLDG
# Stock:  GLDI
# Stock:  GLDM
# Stock:  GLEO
# Stock:  GLEO.U
# Stock:  GLG
# Stock:  GLHAU
# Stock:  GLIF
# Stock:  GLIN
# Stock:  GLL
# Stock:  GLMD
# Stock:  GLNG
# Stock:  GLO
# Stock:  GLOB
# Stock:  GLOG-A
# Stock:  GLOP
# Stock:  GLOP-A
# Stock:  GLOP-B
# Stock:  GLOP-C
# Stock:  GLP
# Stock:  GLP-A
# Stock:  GLP-B
# Stock:  GLPG
# Stock:  GLPI
# Stock:  GLQ
# Stock:  GLRE
# Stock:  GLRY
# Stock:  GLSI
# Stock:  GLSPU
# Stock:  GLT
# Stock:  GLTO
# Stock:  GLTR
# Stock:  GLU
# Stock:  GLU-A
# Stock:  GLU-B
# Stock:  GLUU
# Stock:  GLV
# Stock:  GLW
# Stock:  GLYC
# Stock:  GM
# Stock:  GMAB
# Stock:  GMBL
# Stock:  GMBT
# Stock:  GMBTU
# Stock:  GME
# Stock:  GMED
# Stock:  GMF
# Stock:  GMII
# Stock:  GMLPP
# Stock:  GMMVF
# Stock:  GMOLQ
# Stock:  GMOM
# Stock:  GMRE-A
# Stock:  GMS
# Stock:  GMTA
# Stock:  GMTX
# Stock:  GNAC
# Stock:  GNACU
# Stock:  GNAF
# Stock:  GNCA
# Stock:  GNE
# Stock:  GNE-A
# Stock:  GNFT
# Stock:  GNK
# Stock:  GNL
# Stock:  GNL-A
# Stock:  GNL-B
# Stock:  GNLN
# Stock:  GNMA
# Stock:  GNOG
# Stock:  GNOM
# Stock:  GNPK
# Stock:  GNPK.U
# Stock:  GNPX
# Stock:  GNR
# Stock:  GNRC
# Stock:  GNRS
# Stock:  GNRSU
# Stock:  GNSS
# Stock:  GNT
# Stock:  GNT-A
# Stock:  GNTX
# Stock:  GNTY
# Stock:  GNUS
# Stock:  GNW
# Stock:  GO
# Stock:  GOAC
# Stock:  GOAC.U
# Stock:  GOAT
# Stock:  GOAU
# Stock:  GOCO
# Stock:  GOED
# Stock:  GOEV
# Stock:  GOEX
# Stock:  GOF
# Stock:  GOGL
# Stock:  GOGO
# Stock:  GOL
# Stock:  GOLD
# Stock:  GOLF
# Stock:  GOOD
# Stock:  GOODM
# Stock:  GOODN
# Stock:  GOOGL
# Stock:  GOOS
# Stock:  GORO
# Stock:  GOSS
# Stock:  GOVT
# Stock:  GOVX
# Stock:  GOVZ
# Stock:  GP
# Stock:  GPAC
# Stock:  GPACU
# Stock:  GPC
# Stock:  GPI
# Stock:  GPJA
# Stock:  GPK
# Stock:  GPM
# Stock:  GPMT
# Stock:  GPN
# Stock:  GPORQ
# Stock:  GPP
# Stock:  GPRE
# Stock:  GPRO
# Stock:  GPS
# Stock:  GPX
# Stock:  GQRE
# Stock:  GRA
# Stock:  GRAY
# Stock:  GRBK
# Stock:  GRC
# Stock:  GRCL
# Stock:  GRCY
# Stock:  GRCYU
# Stock:  GREK
# Stock:  GRES
# Stock:  GRF
# Stock:  GRFS
# Stock:  GRID
# Stock:  GRIL
# Stock:  GRIN
# Stock:  GRMN
# Stock:  GRN
# Stock:  GRNB
# Stock:  GRNQ
# Stock:  GRNV
# Stock:  GRNVR
# Stock:  GRNVU
# Stock:  GROW
# Stock:  GROY
# Stock:  GRP.U
# Stock:  GRPN
# Stock:  GRSV
# Stock:  GRSVU
# Stock:  GRTS
# Stock:  GRTX
# Stock:  GRU
# Stock:  GRUB
# Stock:  GRVY
# Stock:  GRWG
# Stock:  GRX
# Stock:  GS
# Stock:  GS-A
# Stock:  GS-C
# Stock:  GS-D
# Stock:  GS-J
# Stock:  GS-K
# Stock:  GS-N
# Stock:  GSAH
# Stock:  GSAH.U
# Stock:  GSAQU
# Stock:  GSAT
# Stock:  GSBC
# Stock:  GSBD
# Stock:  GSCE
# Stock:  GSEE
# Stock:  GSEU
# Stock:  GSEV
# Stock:  GSEVU
# Stock:  GSEW
# Stock:  GSG
# Stock:  GSHD
# Stock:  GSHHY
# Stock:  GSID
# Stock:  GSIE
# Stock:  GSIG
# Stock:  GSIT
# Stock:  GSJY
# Stock:  GSK
# Stock:  GSKY
# Stock:  GSL
# Stock:  GSL-B
# Stock:  GSLC
# Stock:  GSLD
# Stock:  GSM
# Stock:  GSMG
# Stock:  GSP
# Stock:  GSPY
# Stock:  GSQD
# Stock:  GSQD.U
# Stock:  GSS
# Stock:  GSSC
# Stock:  GSST
# Stock:  GSUS
# Stock:  GSV
# Stock:  GSX
# Stock:  GSY
# Stock:  GT
# Stock:  GTBP
# Stock:  GTE
# Stock:  GTEC
# Stock:  GTES
# Stock:  GTH
# Stock:  GTHX
# Stock:  GTIM
# Stock:  GTIP
# ...
# Stock:  BHACU
# Stock:  YMLI
# Stock:  OPB
# Stock:  CALQU
# Stock:  RLJE
# Stock:  WSG
# Stock:  TRCO
# Stock:  NAO
# Stock:  ESGL
# Stock:  AMBR
# Stock:  RYZZ
# Stock:  FTEO
# Stock:  ORIT
# Stock:  JMT
# Stock:  ANCX
# Stock:  PBSK_DELISTED
# Stock:  SPWRV
# Stock:  EHIC
# Stock:  ULTI
# Stock:  RSYS
# Stock:  EIP
# Stock:  LEXEA
# Stock:  OIIL
# Stock:  LACK
# Stock:  BNKZ
# Stock:  HDS
# Stock:  RCP
# Stock:  FAUS
# Stock:  FNSR
# Stock:  KST
# Stock:  VPCB
# Stock:  HTFA
# Stock:  FTAC
# Stock:  JASNQ
# Stock:  PERY
# Stock:  PPLC
# Stock:  OTEL
# Stock:  CVRR
# Stock:  UQM
# Stock:  RWCD
# Stock:  CCH.U
# Stock:  TAPR
# Stock:  SMEZ
# Stock:  CTACU_DELISTED
# Stock:  LOAK.U
# Stock:  WAAS
# Stock:  FCE.A_DELISTED
# Stock:  PACQ
# Stock:  NITE
# Stock:  UBM
# Stock:  AURC
# Stock:  AGGE
# Stock:  LHX
# Stock:  DDE
# Stock:  XLEY
# Stock:  67058h102
# Stock:  SVU
# Stock:  NEED
# Stock:  WSCI
# Stock:  ISRL
# Stock:  UBG
# Stock:  BPL
# Stock:  VRTU
# Stock:  CORV
# Stock:  XRM
# Stock:  HYGO
# Stock:  EDR
# Stock:  E018385
# Stock:  FRSG
# Stock:  SNDEQ
# Stock:  AAON
# Stock:  KYE
# Stock:  ICAN
# Stock:  SYE
# Stock:  PAF
# Stock:  NOVSU
# Stock:  ZBIO
# Stock:  MUH
# Stock:  DVHL
# Stock:  BGGSQ
# Stock:  ARYBU
# Stock:  JHA
# Stock:  EGLTQ
# Stock:  GMFL
# Stock:  V005840
# Stock:  INB
# Stock:  WAGE
# Stock:  AAT
# Stock:  MTSC
# Stock:  C032597
# Stock:  DBKO
# Stock:  IID
# Stock:  BLH
# Stock:  MBVXQ
# Stock:  LCAHU
# Stock:  EGIF
# Stock:  DOFSQ
# Stock:  CMFNL
# Stock:  RXRA
# Stock:  AAXJ
# Stock:  ABEO
# Stock:  ABIO
# Stock:  ABT
# Stock:  ACACU
# Stock:  ACC
# Stock:  ZHOK
# Stock:  CHFN
# Stock:  DWTR
# Stock:  IPVI
# Stock:  AVAH
# Stock:  VALPQ
# Stock:  ACIO
# Stock:  ACM
# Stock:  ACOR
# Stock:  ACRX
# Stock:  ACTDU
# Stock:  ACVF
# Stock:  ADAG
# Stock:  ADERU
# Stock:  ADI
# Stock:  ADMP
# Stock:  ADOM
# Stock:  ACWX
# Stock:  ADCT
# Stock:  AESC
# Stock:  AFAQU
# Stock:  AFGC
# Stock:  AFIF
# Stock:  AFLG
# Stock:  AFTY
# Stock:  AGBAR
# Stock:  AGD
# Stock:  AGG
# Stock:  AGLE
# Stock:  AGNCO
# Stock:  AGRO
# Stock:  AGX
# Stock:  AHC
# Stock:  AIA
# Stock:  ADEX.U
# Stock:  ADPT
# Stock:  AEL
# Stock:  AGR
# Stock:  AIRC
# Stock:  AIT
# Stock:  ALHC
# Stock:  AMEH
# Stock:  AMZA
# Stock:  AMTBB
# Stock:  AMWL
# Stock:  AMX
# Stock:  ANAT
# Stock:  ARRWU
# Stock:  ASTE
# Stock:  AUMN
# Stock:  AUOTY
# Stock:  AUTL
# Stock:  AVSF
# Stock:  AVY
# Stock:  AWP
# Stock:  BABA
# Stock:  BAM
# Stock:  BCO
# Stock:  BH
# Stock:  BHF
# Stock:  BHE
# Stock:  BHK
# Stock:  BHTG
# Stock:  BIDU
# Stock:  BKE
# Stock:  BLIN
# Stock:  BLOK
# Stock:  BLUA
# Stock:  BP
# Stock:  BNDC
# Stock:  BNOV
# Stock:  BNGO
# Stock:  BNR
# Stock:  BSCT
# Stock:  BSGM
# Stock:  BSJO
# Stock:  BSL
# Stock:  BSIG
# Stock:  BSET
# Stock:  BSJN
# Stock:  BSJS
# Stock:  BTEC
# Stock:  BTWN
# Stock:  BYND
# Stock:  BZUN
# Stock:  CAC
# Stock:  CCCC
# Stock:  CEI
# Stock:  CCEP
# Stock:  CCJ
# Stock:  CCMP
# Stock:  CCS
# Stock:  CECE
# Stock:  CLBK
# Stock:  CAAS
# Stock:  CLDR
# Stock:  CRD.B
# Stock:  CSF
# Stock:  CTRE
# Stock:  DHX
# Stock:  DS
# Stock:  DSGX
# Stock:  DTEA
# Stock:  DTN
# Stock:  DUK
# Stock:  DUOT
# Stock:  EDN
# Stock:  EDTK
# Stock:  EDV
# Stock:  EELV
# Stock:  EEMV
# Stock:  EFAD
# Stock:  EFF
# Stock:  EFO
# Stock:  EFV
# Stock:  EGHT
# Stock:  EGP
# Stock:  EHC
# Stock:  EIDO
# Stock:  EIRL
# Stock:  EJUL
# Stock:  ELAN
# Stock:  ELLO
# Stock:  ELS
# Stock:  ELYS
# Stock:  EMBD
# Stock:  DVA
# Stock:  DVOL
# Stock:  DWAW
# Stock:  DWM
# Stock:  DWUS
# Stock:  DXGE
# Stock:  DY
# Stock:  DYNT
# Stock:  EA
# Stock:  EAI
# Stock:  EAR
# Stock:  EATZ
# Stock:  EBIX
# Stock:  EBR
# Stock:  ECC
# Stock:  ECH
# Stock:  ECOM
# Stock:  ECTM
# Stock:  EDF
# Stock:  EDOG
# Stock:  EDTXU
# Stock:  EEA
# Stock:  EEMA
# Stock:  EET
# Stock:  EFAV
# Stock:  EFIV
# Stock:  EFR
# Stock:  EFZ
# Stock:  PPG
# Stock:  PPIH
# Stock:  PPT
# Stock:  PPX
# Stock:  PRF
# Stock:  PRGS
# Stock:  PRK
# Stock:  PROG
# Stock:  PRPC
# Stock:  PRQR
# Stock:  PRSRU
# Stock:  EAGG
# Stock:  PRTG
# Stock:  PSAC
# Stock:  PSB
# Stock:  EAPR
# Stock:  EAT
# Stock:  EBET
# Stock:  EBON
# Stock:  EC
# Stock:  ECF
# Stock:  ECOL
# Stock:  ECPG
# Stock:  EDEN
# Stock:  EDOC
# Stock:  EDTX
# Stock:  EDZ
# Stock:  EEM
# Stock:  EEMX
# Stock:  EFAS
# Stock:  EFG
# Stock:  EFOI
# Stock:  EFX
# Stock:  EGIS
# Stock:  EGPT
# Stock:  EHI
# Stock:  EIG
# Stock:  EIS
# Stock:  EKAR
# Stock:  ELAT
# Stock:  ELMD
# Stock:  ELSE
# Stock:  EM
# Stock:  EMBH
# Stock:  EME
# Stock:  EMHY
# Stock:  EMLC
# Stock:  EMNT
# Stock:  EMQQ
# Stock:  EMTY
# Stock:  ENBA
# Stock:  ENFR
# Stock:  ENOB
# Stock:  ENR
# Stock:  ECCW
# Stock:  ENTG
# Stock:  ENVB
# Stock:  ENZL
# Stock:  ECL
# Stock:  ECOR
# Stock:  EDAP
# Stock:  EDIT
# Stock:  EDRY
# Stock:  EDUC
# Stock:  EEH
# Stock:  EEMO
# Stock:  EEX
# Stock:  EFBI
# Stock:  EFL
# Stock:  EFT
# Stock:  EGBN
# Stock:  EGLX
# Stock:  EGY
# Stock:  EHTH
# Stock:  EIM
# Stock:  EJAN
# Stock:  EL
# Stock:  ELD
# Stock:  ELP
# Stock:  ELVT
# Stock:  EMAN
# Stock:  EMCF
# Stock:  EMFM
# Stock:  EMITF
# Stock:  EMMF
# Stock:  EMP
# Stock:  EMSG
# Stock:  EMXC
# Stock:  ENDP
# Stock:  ENIA
# Stock:  ENNV
# Stock:  ENPC
# Stock:  ENSG
# Stock:  ENTX
# Stock:  ENVIU
# Stock:  EOG
# Stock:  EOT
# Stock:  EPD
# Stock:  EPIX
# Stock:  EPRF
# Stock:  ECLN
# Stock:  ECOW
# Stock:  EDC
# Stock:  EDIV
# Stock:  EDSA
# Stock:  EDUT
# Stock:  EEIQ
# Stock:  EEMS
# Stock:  EFA
# Stock:  EFC
# Stock:  EFNL
# Stock:  EFU
# Stock:  EGF
# Stock:  EGO
# Stock:  EH
# Stock:  EIC
# Stock:  EINC
# Stock:  EJFA
# Stock:  ELA
# Stock:  ELF
# Stock:  ELY
# Stock:  EMB
# Stock:  EMD
# Stock:  EMGF
# Stock:  EMKR
# Stock:  EMMS
# Stock:  EMPW
# Stock:  EMSH
# Stock:  EMXF
# Stock:  ENFA
# Stock:  ENIC
# Stock:  ENNVU
# Stock:  ENPC.U
# Stock:  EKSO
# Stock:  ELC
# Stock:  ELOX
# Stock:  ELTK
# Stock:  EMAG
# Stock:  EMCB
# Stock:  EMF
# Stock:  EMIF
# Stock:  EMMA
# Stock:  ENSV
# Stock:  ENV
# Stock:  ENX
# Stock:  EOI
# Stock:  EPAC
# Stock:  EPHE
# Stock:  EPM
# Stock:  EPRT
# Stock:  EPWR.U
# Stock:  EMDV
# Stock:  EMHC
# Stock:  EML
# Stock:  EMN
# Stock:  EMO
# Stock:  ENB
# Stock:  EQT
# Stock:  ETY
# Stock:  EVG
# Stock:  EVLO
# Stock:  FACT.U
# Stock:  FAIL
# Stock:  FANH
# Stock:  FAT
# Stock:  FAZ
# Stock:  FBGX
# Stock:  FBMS
# Stock:  FBT
# Stock:  FDVV
# Stock:  FEI
# Stock:  FEMS
# Stock:  FEO
# Stock:  FEYE
# Stock:  FFBW
# Stock:  FFHL
# Stock:  FITBP
# Stock:  FIVG
# Stock:  FIXX
# Stock:  FJUL
# Stock:  FLAC
# Stock:  FLDR
# Stock:  FLFR
# Stock:  FLGV
# Stock:  FLIN
# Stock:  FLKR
# Stock:  FRO
# Stock:  FRX
# Stock:  FTA
# Stock:  FTCH
# Stock:  FTEK
# Stock:  FXG
# Stock:  FXNC
# Stock:  GDRX
# Stock:  GDXJ
# Stock:  GGAL
# Stock:  GGN
# Stock:  GH
# Stock:  GHL
# Stock:  GLOG
# Stock:  GMDA
# Stock:  GMIIU
# Stock:  GMRE
# Stock:  GPL
# Stock:  GSAQ
# Stock:  HARP
# Stock:  HAWX
# Stock:  HBANO
# Stock:  HBIO
# Stock:  HBT
# Stock:  HCIC
# Stock:  HLIO
# Stock:  HLXA
# Stock:  HMHC
# Stock:  HNP
# Stock:  HPX
# Stock:  HSBC
# Stock:  IDRV
# Stock:  IFBD
# Stock:  GIIX
# Stock:  INBX
# Stock:  IPI
# Stock:  IPKW
# Stock:  IPWR
# Stock:  IQDY
# Stock:  IWL
# Stock:  IWML
# Stock:  JELD
# Stock:  JLL
# Stock:  KBE
# Stock:  KEX
# Stock:  KNL
# Stock:  LCR
# Stock:  KRA
# Stock:  LDOS
# Stock:  LMT
# Stock:  LVTX
# Stock:  M
# Stock:  MAGA
# Stock:  MCO
# Stock:  MCRI
# Stock:  MDC
# Stock:  MINC
# Stock:  MIRM
# Stock:  MITK
# Stock:  MO
# Stock:  MITO
# Stock:  MJJ
# Stock:  MKGI
# Stock:  MLP
# Stock:  MMTM
# Stock:  MNA
# Stock:  MNOV
# Stock:  MNSB
# Stock:  MNTX
# Stock:  MOGU
# Stock:  MOG.B
# Stock:  MOMO
# Stock:  MORF
# Stock:  MOTN
# Stock:  MTG
# Stock:  MTN
# Stock:  MTRN
# Stock:  MTUL
# Stock:  MTW
# Stock:  MUB
# Stock:  MUFG
# Stock:  MUSA
# Stock:  MVO
# Stock:  MWA
# Stock:  MXE
# Stock:  MYRG
# Stock:  MVP
# Stock:  MWK
# Stock:  MXF
# Stock:  MYD
# Stock:  MYJ
# Stock:  OACB.U
# Stock:  OGE
# Stock:  OPBK
# Stock:  ORN
# Stock:  PAIC
# Stock:  PEGA
# Stock:  PEO
# Stock:  PKB
# Stock:  REI
# Stock:  ROK
# Stock:  SAFE
# Stock:  SCVX
# Stock:  SDIV
# Stock:  SMRTQ
# Stock:  SOGO
# Stock:  SOJD
# Stock:  SPRQ.U
# Stock:  SPYD
# Stock:  SYY
# Stock:  SVFAU
# Stock:  TEX
# Stock:  SYTA
# Stock:  TIP
# Stock:  TYD
# Stock:  TZA
# Stock:  UAA
# Stock:  UAUG
# Stock:  UBOH
# Stock:  UBX
# Stock:  UCO
# Stock:  UNG
# Stock:  UNOV
# Stock:  UPC
# Stock:  UPW
# Stock:  URGN
# Stock:  USA
# Stock:  USDU
# Stock:  URG
# Stock:  URTY
# Stock:  USAS
# Stock:  USDP
# Stock:  USFR
# Stock:  USLB
# Stock:  USML
# Stock:  USRT
# Stock:  VEI
# Stock:  VENAU
# Stock:  VERU
# Stock:  VFC
# Stock:  VFMF
# Stock:  VGAC.U
# Stock:  VGM
# Stock:  VHAQ.RT
# Stock:  VIACA
# Stock:  VICR
# Stock:  VIHAU
# Stock:  VINP
# Stock:  VIR
# Stock:  USAP
# Stock:  USD
# Stock:  UTSI
# Stock:  VFMO
# Stock:  VGI
# Stock:  VHAQ.U
# Stock:  VIACP
# Stock:  VKTX
# Stock:  VLU
# Stock:  VOSO
# Stock:  VPC
# Stock:  VPN
# Stock:  VRCA
# Stock:  VPL
# Stock:  WBIY
# Stock:  WCC
# Stock:  WDIV
# Stock:  WEC
# Stock:  WEBL
# Stock:  WERN
# Stock:  WFC
# Stock:  WHR
# Stock:  WLDN
# Stock:  WLMS
# Stock:  WMK
# Stock:  WOMN
# Stock:  WOW
# Stock:  WPF
# Stock:  WPS
# Stock:  WRN
# Stock:  WSO
# Stock:  WTBA
# Stock:  WTM
# Stock:  WTRU
# Stock:  WVE
# Stock:  WWE
# Stock:  WYNN
# Stock:  XDAT
# Stock:  WPCA
# Stock:  XOMA
# Stock:  XP
# Stock:  XPH
# Stock:  XRLV
# Stock:  XSLV
# Stock:  XT
# Stock:  XVZ
# Stock:  XYLG
# Stock:  YANG
# Stock:  YELL
# Stock:  YGYI
# Stock:  YLDE
# Stock:  YOLO
# Stock:  YSAC
# Stock:  YUM
# Stock:  YYY
# Stock:  ZEN
# Stock:  ZGYHR
# Stock:  ZION
# Stock:  ZIVZF
# Stock:  ZOM
# Stock:  ASO
# Stock:  JE-A
# Stock:  BCYC
# Stock:  SCE-B
# Stock:  PRE-F
# Stock:  WFC-T
# Stock:  RNR-CCL
# Stock:  WFC-W
# Stock:  UMH-B
# Stock:  DLR-G
# Stock:  GRX-B
# Stock:  BXP-B
# Stock:  PSA-VCL
# Stock:  FRC-F
# Stock:  STPK.U
# Stock:  SBEA
# Stock:  TFC-F
# Stock:  WRB-B
# Stock:  SAN-B
# Stock:  AHT-H
# Stock:  RNAZ
# Stock:  AGO-E
# Stock:  PSA-B
# Stock:  PSA-W
# Stock:  NYCB-A
# Stock:  BRG-A
# Stock:  NEE-R_DELISTED
# Stock:  SRE-A
# Stock:  BK-C
# Stock:  BAC-A
# Stock:  EDR
# Stock:  PDOT
# Stock:  HGI
# Stock:  MACQ
# Stock:  PXUS
# Stock:  UWN
# Stock:  JMBA
# Stock:  WRLSR
# Stock:  IBDL
# Stock:  GNBC
# Stock:  AMCIU
# Stock:  PMOM
# Stock:  ABAX
# Stock:  IHYV_DELISTED
# Stock:  AFSI_DELISTED
# Stock:  XLUY
# Stock:  NPN
# Stock:  USDY
# Stock:  GG
# Stock:  W004759
# Stock:  J010799
# Stock:  ADRD
# Stock:  PS
# Stock:  SPNX
# Stock:  DEWJ
# Stock:  EGOV
# Stock:  SYV
# Stock:  IHYD
# Stock:  CPL
# Stock:  BITA
# Stock:  5326esc96
# Stock:  SPYB
# Stock:  ZF
# Stock:  FHK
# Stock:  PACDQ
# Stock:  NGHC
# Stock:  RWSL
# Stock:  GBLIZ
# Stock:  CUR
# Stock:  AHPAU_DELISTED
# Stock:  NGHCP
# Stock:  MBNAB
# Stock:  FUD
# Stock:  ESRX
# Stock:  CBS.A
# Stock:  HMTA
# Stock:  PKD_DELISTED
# Stock:  T021735
# Stock:  TAHO
# Stock:  PPSC
# Stock:  BAC-C
# Stock:  SCHY
# Stock:  SCE-K
# Stock:  IPHI
# Stock:  IVTY
# Stock:  PGLC
# Stock:  DMYD.U
# Stock:  CYOU
# Stock:  BNKO
# Stock:  CMSSU
# Stock:  NRCG
# Stock:  FVAC.U
# Stock:  NCB
# Stock:  ARVR
# Stock:  MLPS
# Stock:  PPMC
# Stock:  MUS
# Stock:  HCACU
# Stock:  HEWI
# Stock:  SPEL
# Stock:  NXTM
# Stock:  GMHIU
# Stock:  BNCL
# Stock:  ACAMU
# Stock:  NEE-I
# Stock:  PRVA
# Stock:  RPUT
# Stock:  KMM
# Stock:  LXFT
# Stock:  RTN
# Stock:  LANDP
# Stock:  BVAL
# Stock:  SCTO
# Stock:  CYTX
# Stock:  GWR
# Stock:  DDBI
# Stock:  CRRTQ
# Stock:  DPHCU
# Stock:  CHKAQ
# Stock:  F022618
# Stock:  IPHS
# Stock:  ALGR
# Stock:  AUSE
# Stock:  H011806
# Stock:  BDCL
# Stock:  LGVW.U
# Stock:  HHYX
# Stock:  FCB
# Stock:  RP
# Stock:  SCE-E
# Stock:  CHL
# Stock:  ESESQ
# Stock:  PLND
# Stock:  WBC
# Stock:  KERX_DELISTED
# Stock:  LHO_DELISTED
# Stock:  BSKYU
# Stock:  ACQR
# Stock:  TUGCU
# Stock:  TNAV
# Stock:  PPLN
# Stock:  EEQ
# Stock:  APDN
# Stock:  CBPO
# Stock:  LTXB
# Stock:  INSUU
# Stock:  EWEM
# Stock:  BCSF.RT
# Stock:  OILU
# Stock:  LM
# Stock:  BDCS
# Stock:  CORI_DELISTED
# Stock:  SORL
# Stock:  ALGRR
# Stock:  ADRU
# Stock:  MARKP
# Stock:  ITUS
# Stock:  SRF
# Stock:  ADOCU
# Stock:  BBF
# Stock:  EIA
# Stock:  SAUC
# Stock:  AHPA_DELISTED
# Stock:  HCCOU
# Stock:  30151e814
# Stock:  AMAO
# Stock:  HAHA
# Stock:  LGC.U
# Stock:  HYDD
# Stock:  DPLO
# Stock:  NTC
# Stock:  FLIO
# Stock:  PSTH.U
# Stock:  QGTA
# Stock:  ARTX
# Stock:  LOXO
# Stock:  INAU
# Stock:  SXCP
# Stock:  MCACR
# Stock:  REIS
# Stock:  NHA
# Stock:  MTFB
# Stock:  EEP
# Stock:  GDXX
# Stock:  MZF
# Stock:  DYNC_DELISTED
# Stock:  GLIBA
# Stock:  MFINL
# Stock:  TPIV
# Stock:  COWNZ
# Stock:  WFC-V
# Stock:  BLMT
# Stock:  ZAGG
# Stock:  BIOS
# Stock:  MEN
# Stock:  LOACR
# Stock:  QCP
# Stock:  HSBC-A
# Stock:  WFC-P
# Stock:  TNP-C
# Stock:  SCE-C
# Stock:  SCE-D
# Stock:  MBNAA
# Stock:  JPLS
# Stock:  TLDH
# Stock:  AABA
# Stock:  PGNX
# Stock:  NGLS-A
# Stock:  MXDE
# Stock:  WRB-C
# Stock:  TFCFA
# Stock:  CRHM
# Stock:  MCMJU
# Stock:  OXLCO
# Stock:  SQMRF
# Stock:  BANC-D
# Stock:  TWO-D
# Stock:  NEE-Q
# Stock:  COMG
# Stock:  CHU
# Stock:  SOIL
# Stock:  DEZU
# Stock:  SWIN
# Stock:  DX-B
# Stock:  TCO-J
# Stock:  GNMK
# Stock:  GDV-A
# Stock:  JHDG
# Stock:  ANDV
# Stock:  BUYN
# Stock:  TVPT
# Stock:  CCI-A
# Stock:  GDAT
# Stock:  FTACU
# Stock:  STAG-C
# Stock:  TWO-E
# Stock:  MYF
# Stock:  BEER
# Stock:  NEE-J
# Stock:  FRC-G
# Stock:  TST
# Stock:  P
# Stock:  GMLP
# Stock:  NBST
# Stock:  XIVH
# Stock:  WREI
# Stock:  JCAP-B
# Stock:  USB-O
# Stock:  DLR-I
# Stock:  CKH
# Stock:  TETF
# Stock:  CWAY
# Stock:  NTRP
# Stock:  BHAC
# Stock:  EMBU
# Stock:  GAINM
# Stock:  MUDSU
# Stock:  WEB
# Stock:  GBNK
# Stock:  TWLV
# Stock:  INXX
# Stock:  ESL
# Stock:  DNRCQ
# Stock:  PFE.WI
# Stock:  SCID
# Stock:  IDY
# Stock:  INDU_DELISTED
# Stock:  GHII
# Stock:  ARA
# Stock:  STI
# Stock:  BZM
# Stock:  CIVI
# Stock:  ORSNU
# Stock:  HKRSQ
# Stock:  YIN
# Stock:  HEUS
# Stock:  MHE
# Stock:  ATHN
# Stock:  KONE
# Stock:  IDTI
# Stock:  UN
# Stock:  EQGP
# Stock:  MCEP
# Stock:  V010203
# Stock:  MAB
# Stock:  VIAB
# Stock:  XL
# Stock:  ARYA
# Stock:  EMCI
# Stock:  OCSI
# Stock:  LN
# Stock:  RARX
# Stock:  DHCP
# Stock:  BBOX
# Stock:  AYR
# Stock:  GGP
# Stock:  TCO-K
# Stock:  C-S
# Stock:  LCM
# Stock:  EAGLU
# Stock:  PNC-Q
# Stock:  GRX-ACL
# Stock:  SITC-K
# Stock:  CIICU
# Stock:  TIVO
# Stock:  VIA
# Stock:  SAQNU
# Stock:  LABL
# Stock:  RPLA.U
# Stock:  BFL
# Stock:  LKM
# Stock:  AAC
# Stock:  UHN
# Stock:  H024400
# Stock:  DTYL
# Stock:  BFRA
# Stock:  CREG
# Stock:  CSCW
# Stock:  DXYN
# Stock:  SFB
# Stock:  SHG
# Stock:  SIJ
# Stock:  SND
# Stock:  SSBI
# Stock:  TA
# Stock:  TRC
# Stock:  TREB
# Stock:  TS
# Stock:  UIVM
# Stock:  VFVA
# Stock:  VPU
# Stock:  VTC
# Stock:  WDAY
# Stock:  WDC
# Stock:  WMS
# Stock:  BLRX
# Stock:  BRPM
# Stock:  CCNC
# Stock:  CNTB
# Stock:  DSEY
# Stock:  EQS
# Stock:  EVAX
# Stock:  XUSA
# Stock:  S019582
# Stock:  K442505
# Stock:  WBIA
# Stock:  FNTEU
# Stock:  CFFAU
# Stock:  AGC
# Stock:  GASL
# Stock:  CXO
# Stock:  DDOC
# Stock:  PNK
# Stock:  EIO
# Stock:  GDMA
# Stock:  FDC
# Stock:  IPOC.U
# Stock:  MYND
# Stock:  EGC
# Stock:  MCADR
# Stock:  UONEK
# Stock:  TBRGU
# Stock:  ENLK
# Stock:  EXIV
# Stock:  MEET
# Stock:  MDSO
# Stock:  INSYQ
# Stock:  SPAQ.U
# Stock:  UJPY
# Stock:  RLH
# Stock:  SIGM
# Stock:  DWFI
# Stock:  DGSE
# Stock:  NGHCO
# Stock:  SJCPP
# Stock:  CRAY
# Stock:  RWDE
# Stock:  MOC
# Stock:  SNH
# Stock:  CUO
# Stock:  ULBR
# Stock:  PAY
# Stock:  TLP
# Stock:  LOGM
# Stock:  RMGN
# Stock:  SYNT
# Stock:  KED
# Stock:  ALD
# Stock:  BRACU
# Stock:  NCOM
# Stock:  FSNN
# Stock:  AMCIU
# Stock:  HPJ
# Stock:  LION
# Stock:  PACA
# Stock:  SAMAU
# Stock:  ONCE
# Stock:  OVLC
# Stock:  PSAU
# Stock:  SDI
# Stock:  GPT
# Stock:  ARII_DELISTED
# Stock:  VMAX
# Stock:  ECYT
# Stock:  JSYNU
# Stock:  BKK
# Stock:  GLACU
# Stock:  SPA
# Stock:  HACW
# Stock:  EMJ
# Stock:  NEOS
# Stock:  CFVI
# Stock:  YGEHY
# Stock:  GHDX
# Stock:  OFSSL
# Stock:  ORM
# Stock:  BEAT
# Stock:  NMY
# Stock:  UCBA
# Stock:  COTV
# Stock:  BSE
# Stock:  IEMV_DELISTED
# Stock:  MFT
# Stock:  ARTAU
# Stock:  BIKR
# Stock:  BSD
# Stock:  KTWO_DELISTED
# Stock:  BNGOU
# Stock:  MBTF
# Stock:  P027445
# Stock:  PDLIV
# Stock:  SEND
# Stock:  ARYAU
# Stock:  KAAC
# Stock:  BTYS
# Stock:  VRNTV
# Stock:  TWLVU_DELISTED
# Stock:  MSACU
# Stock:  HHHHU
# Stock:  CHKE
# Stock:  HMSY
# Stock:  CNDF
# Stock:  ABB
# Stock:  LCAHU_DELISTED
# Stock:  DMYT.U
# Stock:  OPHT
# Stock:  SYNC
# Stock:  BRPM
# Stock:  SCA
# Stock:  BZF
# Stock:  OAK
# Stock:  SCIX
# Stock:  CARO
# Stock:  TPVY
# Stock:  GASX
# Stock:  SHLL.U
# Stock:  MYL
# Stock:  OMED
# Stock:  FMK
# Stock:  WTID
# Stock:  JMF
# Stock:  ORG
# Stock:  CCT_DELISTED
# Stock:  ETP
# Stock:  MYOK
# Stock:  SHLM
# Stock:  NYH
# Stock:  MSL
# Stock:  HAO
# Stock:  FLLC
# Stock:  AMGP
# Stock:  EAE
# Stock:  RWED
# Stock:  HPR
# Stock:  CSRA.U
# Stock:  AXJV
# Stock:  ARQL
# Stock:  CVIAQ
# Stock:  FTVA_DELISTED
# Stock:  HFXJ
# Stock:  GBUY
# Stock:  USAG
# Stock:  EVJ
# Stock:  MFO
# Stock:  EVR
# Stock:  FCN
# Stock:  FSMD
# Stock:  GPRK
# Stock:  SMHD
# Stock:  QEP
# Stock:  NYRT
# Stock:  FRSH
# Stock:  SAGG
# Stock:  CROP
# Stock:  AET_DELISTED
# Stock:  CGROU
# Stock:  CCIHY
# Stock:  HFRO
# Stock:  EVHC
# Stock:  HTUS
# Stock:  IVZ
# Stock:  KT
# Stock:  KZR
# Stock:  LB
# Stock:  MCK
# Stock:  PRFT
# Stock:  QTWO
# Stock:  QUAD
# Stock:  CLNS
# Stock:  F023180
# Stock:  VINCU
# Stock:  CDMOP
# Stock:  DNK
# Stock:  TFC-G
# Stock:  AGM-A
# Stock:  NLY-D
# Stock:  PSA-X
# Stock:  NPAUU
# Stock:  LSVX
# Stock:  TIG
# Stock:  AJAX
# Stock:  A
# Stock:  AA
# Stock:  ALTA
# Stock:  IEUR
# Stock:  ITT
# Stock:  IWN
# Stock:  KB
# Stock:  LBTYB
# Stock:  LEJU
# Stock:  LEMB
# Stock:  MOR
# Stock:  NAK
# Stock:  NERV
# Stock:  OLK
# Stock:  PCGU
# Stock:  PGRW
# Stock:  RGCO
# Stock:  ROST
# Stock:  SHAK
# Stock:  BTNB
# Stock:  CLOV
# Stock:  FTSM
# Stock:  GATX
# Stock:  HEFA
# Stock:  JNJ
# Stock:  KCAPL
# Stock:  MBIN
# Stock:  MDIA
# Stock:  METC
# Stock:  MFA
# Stock:  NYMX
# Stock:  OFG
# Stock:  PBF
# Stock:  PEBK
# Stock:  RCG
# Stock:  RLI
# Stock:  SHYG
# Stock:  SPGI
# Stock:  SPXC
# Stock:  VWO
# Stock:  WMT
# Stock:  AAPL
# Stock:  AMZN
# Stock:  GOOG
# Stock:  MVIS
# Stock:  OKTA
# Stock:  PINS
# Stock:  AMC
# Stock:  SPOT

# %%
stock_dictdict
# Out:
# {'AAA': yfinance.Ticker object <AAA>,
#  'AAAU': yfinance.Ticker object <AAAU>,
#  'AAC.U': yfinance.Ticker object <AAC.U>,
#  'AACG': yfinance.Ticker object <AACG>,
#  'AACQ': yfinance.Ticker object <AACQ>,
#  'AACQU': yfinance.Ticker object <AACQU>,
#  'AADR': yfinance.Ticker object <AADR>,
#  'AAIC': yfinance.Ticker object <AAIC>,
#  'AAIC-B': yfinance.Ticker object <AAIC-B>,
#  'AAIC-C': yfinance.Ticker object <AAIC-C>,
#  'AAL': yfinance.Ticker object <AAL>,
#  'AAMC': yfinance.Ticker object <AAMC>,
#  'AAME': yfinance.Ticker object <AAME>,
#  'AAN': yfinance.Ticker object <AAN>,
#  'VVC': yfinance.Ticker object <VVC>,
#  'AAOI': yfinance.Ticker object <AAOI>,
#  'AAP': yfinance.Ticker object <AAP>,
#  'AAQC.U': yfinance.Ticker object <AAQC.U>,
#  'AAU': yfinance.Ticker object <AAU>,
#  'AAVVF': yfinance.Ticker object <AAVVF>,
#  'ILG': yfinance.Ticker object <ILG>,
#  'HCRF': yfinance.Ticker object <HCRF>,
#  'TPGH_DELISTED': yfinance.Ticker object <TPGH_DELISTED>,
#  'AAWW': yfinance.Ticker object <AAWW>,
#  'VIIZ': yfinance.Ticker object <VIIZ>,
#  'C016626': yfinance.Ticker object <C016626>,
#  'AB': yfinance.Ticker object <AB>,
#  'ABBV': yfinance.Ticker object <ABBV>,
#  'ABC': yfinance.Ticker object <ABC>,
#  'ABCB': yfinance.Ticker object <ABCB>,
#  'ABCL': yfinance.Ticker object <ABCL>,
#  'ABCM': yfinance.Ticker object <ABCM>,
#  'ABEQ': yfinance.Ticker object <ABEQ>,
#  'BSWN': yfinance.Ticker object <BSWN>,
#  'TSRO': yfinance.Ticker object <TSRO>,
#  'HEFV': yfinance.Ticker object <HEFV>,
#  'H015802': yfinance.Ticker object <H015802>,
#  'ABEV': yfinance.Ticker object <ABEV>,
#  'ABG': yfinance.Ticker object <ABG>,
#  'ABGI': yfinance.Ticker object <ABGI>,
#  'ABILF': yfinance.Ticker object <ABILF>,
#  'ABM': yfinance.Ticker object <ABM>,
#  'ABMD': yfinance.Ticker object <ABMD>,
#  'ABNB': yfinance.Ticker object <ABNB>,
#  'ABR': yfinance.Ticker object <ABR>,
#  'ABR-A': yfinance.Ticker object <ABR-A>,
#  'ABR-B': yfinance.Ticker object <ABR-B>,
#  'ABR-C': yfinance.Ticker object <ABR-C>,
#  'ABST': yfinance.Ticker object <ABST>,
#  'ABTX': yfinance.Ticker object <ABTX>,
#  'ABUS': yfinance.Ticker object <ABUS>,
#  'AC': yfinance.Ticker object <AC>,
#  'ACA': yfinance.Ticker object <ACA>,
#  'ACAC': yfinance.Ticker object <ACAC>,
#  'ACAD': yfinance.Ticker object <ACAD>,
#  'ACAH': yfinance.Ticker object <ACAH>,
#  'ACAHU': yfinance.Ticker object <ACAHU>,
#  'ACB': yfinance.Ticker object <ACB>,
#  'ACBAU': yfinance.Ticker object <ACBAU>,
#  'ACBI': yfinance.Ticker object <ACBI>,
#  'ACCD': yfinance.Ticker object <ACCD>,
#  'ACCO': yfinance.Ticker object <ACCO>,
#  'ACEL': yfinance.Ticker object <ACEL>,
#  'ACER': yfinance.Ticker object <ACER>,
#  'ACES': yfinance.Ticker object <ACES>,
#  'ACET': yfinance.Ticker object <ACET>,
#  'ACEV': yfinance.Ticker object <ACEV>,
#  'ACEVU': yfinance.Ticker object <ACEVU>,
#  'ACGL': yfinance.Ticker object <ACGL>,
#  'ACGLO': yfinance.Ticker object <ACGLO>,
#  'ACGLP': yfinance.Ticker object <ACGLP>,
#  'ACH': yfinance.Ticker object <ACH>,
#  'ACHC': yfinance.Ticker object <ACHC>,
#  'ACHL': yfinance.Ticker object <ACHL>,
#  'ACHV': yfinance.Ticker object <ACHV>,
#  'ACI': yfinance.Ticker object <ACI>,
#  'ACIC': yfinance.Ticker object <ACIC>,
#  'ACIC.U': yfinance.Ticker object <ACIC.U>,
#  'ACII': yfinance.Ticker object <ACII>,
#  'ACII.U': yfinance.Ticker object <ACII.U>,
#  'ACIU': yfinance.Ticker object <ACIU>,
#  'ACIW': yfinance.Ticker object <ACIW>,
#  'ACKIT': yfinance.Ticker object <ACKIT>,
#  'ACKIU': yfinance.Ticker object <ACKIU>,
#  'ACLS': yfinance.Ticker object <ACLS>,
#  'ACMR': yfinance.Ticker object <ACMR>,
#  'ACN': yfinance.Ticker object <ACN>,
#  'ACNB': yfinance.Ticker object <ACNB>,
#  'ACND': yfinance.Ticker object <ACND>,
#  'ACND.U': yfinance.Ticker object <ACND.U>,
#  'ACP': yfinance.Ticker object <ACP>,
#  'ACQRU': yfinance.Ticker object <ACQRU>,
#  'ACR': yfinance.Ticker object <ACR>,
#  'ACR-C': yfinance.Ticker object <ACR-C>,
#  'ACRE': yfinance.Ticker object <ACRE>,
#  'ACRS': yfinance.Ticker object <ACRS>,
#  'ACSG': yfinance.Ticker object <ACSG>,
#  'ACSI': yfinance.Ticker object <ACSI>,
#  'ACST': yfinance.Ticker object <ACST>,
#  'ACTC': yfinance.Ticker object <ACTC>,
#  'ACTCU': yfinance.Ticker object <ACTCU>,
#  'ACTG': yfinance.Ticker object <ACTG>,
#  'ACTV': yfinance.Ticker object <ACTV>,
#  'ACU': yfinance.Ticker object <ACU>,
#  'ACV': yfinance.Ticker object <ACV>,
#  'ACVA': yfinance.Ticker object <ACVA>,
#  'ACWF': yfinance.Ticker object <ACWF>,
#  'ACWI': yfinance.Ticker object <ACWI>,
#  'ACWV': yfinance.Ticker object <ACWV>,
#  'ACY': yfinance.Ticker object <ACY>,
#  'ADAP': yfinance.Ticker object <ADAP>,
#  'ADBE': yfinance.Ticker object <ADBE>,
#  'ADC': yfinance.Ticker object <ADC>,
#  'ADER': yfinance.Ticker object <ADER>,
#  'ADES': yfinance.Ticker object <ADES>,
#  'ADEX': yfinance.Ticker object <ADEX>,
#  'ADF.U': yfinance.Ticker object <ADF.U>,
#  'ADFI': yfinance.Ticker object <ADFI>,
#  'ADIL': yfinance.Ticker object <ADIL>,
#  'ADIV': yfinance.Ticker object <ADIV>,
#  'ADM': yfinance.Ticker object <ADM>,
#  'ADMA': yfinance.Ticker object <ADMA>,
#  'ADME': yfinance.Ticker object <ADME>,
#  'ADMS': yfinance.Ticker object <ADMS>,
#  'ADN': yfinance.Ticker object <ADN>,
#  'ADNT': yfinance.Ticker object <ADNT>,
#  'ADOC': yfinance.Ticker object <ADOC>,
#  'ADOCR': yfinance.Ticker object <ADOCR>,
#  'ADP': yfinance.Ticker object <ADP>,
#  'ADRA': yfinance.Ticker object <ADRA>,
#  'ADRA.U': yfinance.Ticker object <ADRA.U>,
#  'ADRE': yfinance.Ticker object <ADRE>,
#  'ADS': yfinance.Ticker object <ADS>,
#  'ADSK': yfinance.Ticker object <ADSK>,
#  'ADT': yfinance.Ticker object <ADT>,
#  'ADTN': yfinance.Ticker object <ADTN>,
#  'ADTX': yfinance.Ticker object <ADTX>,
#  'ADUS': yfinance.Ticker object <ADUS>,
#  'ADV': yfinance.Ticker object <ADV>,
#  'ADVM': yfinance.Ticker object <ADVM>,
#  'ADX': yfinance.Ticker object <ADX>,
#  'ADXN': yfinance.Ticker object <ADXN>,
#  'ADXS': yfinance.Ticker object <ADXS>,
#  'ADYX': yfinance.Ticker object <ADYX>,
#  'ADZCF': yfinance.Ticker object <ADZCF>,
#  'AE': yfinance.Ticker object <AE>,
#  'AEAC': yfinance.Ticker object <AEAC>,
#  'AEACU': yfinance.Ticker object <AEACU>,
#  'AEB': yfinance.Ticker object <AEB>,
#  'AEE': yfinance.Ticker object <AEE>,
#  'AEF': yfinance.Ticker object <AEF>,
#  'AEFC': yfinance.Ticker object <AEFC>,
#  'AEG': yfinance.Ticker object <AEG>,
#  'AEGN': yfinance.Ticker object <AEGN>,
#  'AEHL': yfinance.Ticker object <AEHL>,
#  'AEHR': yfinance.Ticker object <AEHR>,
#  'AEI': yfinance.Ticker object <AEI>,
#  'AEIS': yfinance.Ticker object <AEIS>,
#  'AEL-A': yfinance.Ticker object <AEL-A>,
#  'AEL-B': yfinance.Ticker object <AEL-B>,
#  'AEM': yfinance.Ticker object <AEM>,
#  'AEMD': yfinance.Ticker object <AEMD>,
#  'AENZ': yfinance.Ticker object <AENZ>,
#  'AEO': yfinance.Ticker object <AEO>,
#  'AEP': yfinance.Ticker object <AEP>,
#  'AEPPL': yfinance.Ticker object <AEPPL>,
#  'AEPPZ': yfinance.Ticker object <AEPPZ>,
#  'AER': yfinance.Ticker object <AER>,
#  'AERI': yfinance.Ticker object <AERI>,
#  'AES': yfinance.Ticker object <AES>,
#  'AESE': yfinance.Ticker object <AESE>,
#  'AESR': yfinance.Ticker object <AESR>,
#  'AEVA': yfinance.Ticker object <AEVA>,
#  'AEY': yfinance.Ticker object <AEY>,
#  'AEYE': yfinance.Ticker object <AEYE>,
#  'AEZS': yfinance.Ticker object <AEZS>,
#  'AFB': yfinance.Ticker object <AFB>,
#  'AFBI': yfinance.Ticker object <AFBI>,
#  'AFCG': yfinance.Ticker object <AFCG>,
#  'AFG': yfinance.Ticker object <AFG>,
#  'AFGB': yfinance.Ticker object <AFGB>,
#  'AFGD': yfinance.Ticker object <AFGD>,
#  'AFGE': yfinance.Ticker object <AFGE>,
#  'AFHBL': yfinance.Ticker object <AFHBL>,
#  'AFHIF': yfinance.Ticker object <AFHIF>,
#  'AFI': yfinance.Ticker object <AFI>,
#  'AFIB': yfinance.Ticker object <AFIB>,
#  'AFIN': yfinance.Ticker object <AFIN>,
#  'AFINO': yfinance.Ticker object <AFINO>,
#  'AFINP': yfinance.Ticker object <AFINP>,
#  'AFK': yfinance.Ticker object <AFK>,
#  'AFL': yfinance.Ticker object <AFL>,
#  'AFMC': yfinance.Ticker object <AFMC>,
#  'AFMD': yfinance.Ticker object <AFMD>,
#  'AFRM': yfinance.Ticker object <AFRM>,
#  'AFSM': yfinance.Ticker object <AFSM>,
#  'AFT': yfinance.Ticker object <AFT>,
#  'AFYA': yfinance.Ticker object <AFYA>,
#  'AG': yfinance.Ticker object <AG>,
#  'AGAC': yfinance.Ticker object <AGAC>,
#  'AGAC.U': yfinance.Ticker object <AGAC.U>,
#  'AGBA': yfinance.Ticker object <AGBA>,
#  'AGBAU': yfinance.Ticker object <AGBAU>,
#  'AGC': yfinance.Ticker object <AGC>,
#  'AGCB': yfinance.Ticker object <AGCB>,
#  'AGCO': yfinance.Ticker object <AGCO>,
#  'AGCUU': yfinance.Ticker object <AGCUU>,
#  'AGE': yfinance.Ticker object <AGE>,
#  'AGEN': yfinance.Ticker object <AGEN>,
#  'AGFS': yfinance.Ticker object <AGFS>,
#  'AGFXF': yfinance.Ticker object <AGFXF>,
#  'AGFY': yfinance.Ticker object <AGFY>,
#  'AGGRU': yfinance.Ticker object <AGGRU>,
#  'AGGY': yfinance.Ticker object <AGGY>,
#  'AGI': yfinance.Ticker object <AGI>,
#  'AGIO': yfinance.Ticker object <AGIO>,
#  'AGL': yfinance.Ticker object <AGL>,
#  'AGM': yfinance.Ticker object <AGM>,
#  'AGM-C': yfinance.Ticker object <AGM-C>,
#  'AGM-D': yfinance.Ticker object <AGM-D>,
#  'AGM-E': yfinance.Ticker object <AGM-E>,
#  'AGM-F': yfinance.Ticker object <AGM-F>,
#  'AGM.A': yfinance.Ticker object <AGM.A>,
#  'AGMH': yfinance.Ticker object <AGMH>,
#  'AGNC': yfinance.Ticker object <AGNC>,
#  'AGNCM': yfinance.Ticker object <AGNCM>,
#  'AGNCN': yfinance.Ticker object <AGNCN>,
#  'AGNCP': yfinance.Ticker object <AGNCP>,
#  'AGNG': yfinance.Ticker object <AGNG>,
#  'AGO': yfinance.Ticker object <AGO>,
#  'AGO-B': yfinance.Ticker object <AGO-B>,
#  'AGO-F': yfinance.Ticker object <AGO-F>,
#  'AGQ': yfinance.Ticker object <AGQ>,
#  'AGRX': yfinance.Ticker object <AGRX>,
#  'AGS': yfinance.Ticker object <AGS>,
#  'AGT': yfinance.Ticker object <AGT>,
#  'AGTC': yfinance.Ticker object <AGTC>,
#  'AGTI': yfinance.Ticker object <AGTI>,
#  'AGYS': yfinance.Ticker object <AGYS>,
#  'AGZ': yfinance.Ticker object <AGZ>,
#  'AGZD': yfinance.Ticker object <AGZD>,
#  'AHAC': yfinance.Ticker object <AHAC>,
#  'AHACU': yfinance.Ticker object <AHACU>,
#  'AHCO': yfinance.Ticker object <AHCO>,
#  'AHH': yfinance.Ticker object <AHH>,
#  'AHH-A': yfinance.Ticker object <AHH-A>,
#  'AHL-C': yfinance.Ticker object <AHL-C>,
#  'AHL-D': yfinance.Ticker object <AHL-D>,
#  'AHL-E': yfinance.Ticker object <AHL-E>,
#  'AHPI': yfinance.Ticker object <AHPI>,
#  'AHT': yfinance.Ticker object <AHT>,
#  'AHT-D': yfinance.Ticker object <AHT-D>,
#  'AHT-F': yfinance.Ticker object <AHT-F>,
#  'AHT-G': yfinance.Ticker object <AHT-G>,
#  'AHT-I': yfinance.Ticker object <AHT-I>,
#  'AI': yfinance.Ticker object <AI>,
#  'AIC': yfinance.Ticker object <AIC>,
#  'AIEQ': yfinance.Ticker object <AIEQ>,
#  'AIF': yfinance.Ticker object <AIF>,
#  'AIG': yfinance.Ticker object <AIG>,
#  'AIG-A': yfinance.Ticker object <AIG-A>,
#  'AIH': yfinance.Ticker object <AIH>,
#  'AIHS': yfinance.Ticker object <AIHS>,
#  'AIIQ': yfinance.Ticker object <AIIQ>,
#  'AIKI': yfinance.Ticker object <AIKI>,
#  'AIM': yfinance.Ticker object <AIM>,
#  'AIMC': yfinance.Ticker object <AIMC>,
#  'AIN': yfinance.Ticker object <AIN>,
#  'AINC': yfinance.Ticker object <AINC>,
#  'AINV': yfinance.Ticker object <AINV>,
#  'AIO': yfinance.Ticker object <AIO>,
#  'AIQ': yfinance.Ticker object <AIQ>,
#  'AIR': yfinance.Ticker object <AIR>,
#  'AIRG': yfinance.Ticker object <AIRG>,
#  'AIRI': yfinance.Ticker object <AIRI>,
#  'AIRR': yfinance.Ticker object <AIRR>,
#  'AIRT': yfinance.Ticker object <AIRT>,
#  'AIRTP': yfinance.Ticker object <AIRTP>,
#  'AIV': yfinance.Ticker object <AIV>,
#  'AIW': yfinance.Ticker object <AIW>,
#  'AIZ': yfinance.Ticker object <AIZ>,
#  'AIZN': yfinance.Ticker object <AIZN>,
#  'AJAX.U': yfinance.Ticker object <AJAX.U>,
#  'AJG': yfinance.Ticker object <AJG>,
#  'AJRD': yfinance.Ticker object <AJRD>,
#  'AJX': yfinance.Ticker object <AJX>,
#  'AJXA': yfinance.Ticker object <AJXA>,
#  'AKAM': yfinance.Ticker object <AKAM>,
#  'AKAOQ': yfinance.Ticker object <AKAOQ>,
#  'AKBA': yfinance.Ticker object <AKBA>,
#  'AKIC': yfinance.Ticker object <AKIC>,
#  'AKICU': yfinance.Ticker object <AKICU>,
#  'AKO.A': yfinance.Ticker object <AKO.A>,
#  'AKO.B': yfinance.Ticker object <AKO.B>,
#  'AKR': yfinance.Ticker object <AKR>,
#  'AKRO': yfinance.Ticker object <AKRO>,
#  'AKTS': yfinance.Ticker object <AKTS>,
#  'AKTX': yfinance.Ticker object <AKTX>,
#  'AKU': yfinance.Ticker object <AKU>,
#  'AKUS': yfinance.Ticker object <AKUS>,
#  'AKYA': yfinance.Ticker object <AKYA>,
#  'AL': yfinance.Ticker object <AL>,
#  'AL-A': yfinance.Ticker object <AL-A>,
#  'ALAC': yfinance.Ticker object <ALAC>,
#  'ALACR': yfinance.Ticker object <ALACR>,
#  'ALACU': yfinance.Ticker object <ALACU>,
#  'ALB': yfinance.Ticker object <ALB>,
#  'ALBO': yfinance.Ticker object <ALBO>,
#  'ALC': yfinance.Ticker object <ALC>,
#  'ALCO': yfinance.Ticker object <ALCO>,
#  'ALDX': yfinance.Ticker object <ALDX>,
#  'ALE': yfinance.Ticker object <ALE>,
#  'ALEC': yfinance.Ticker object <ALEC>,
#  'ALEX': yfinance.Ticker object <ALEX>,
#  'ALFA': yfinance.Ticker object <ALFA>,
#  'ALG': yfinance.Ticker object <ALG>,
#  'ALGM': yfinance.Ticker object <ALGM>,
#  'ALGN': yfinance.Ticker object <ALGN>,
#  'ALGS': yfinance.Ticker object <ALGS>,
#  'ALGT': yfinance.Ticker object <ALGT>,
#  'ALIM': yfinance.Ticker object <ALIM>,
#  'ALIN-A': yfinance.Ticker object <ALIN-A>,
#  'ALIN-B': yfinance.Ticker object <ALIN-B>,
#  'ALIN-E': yfinance.Ticker object <ALIN-E>,
#  'ALJJ': yfinance.Ticker object <ALJJ>,
#  'ALK': yfinance.Ticker object <ALK>,
#  'ALKS': yfinance.Ticker object <ALKS>,
#  'ALKT': yfinance.Ticker object <ALKT>,
#  'ALL': yfinance.Ticker object <ALL>,
#  'ALL-B': yfinance.Ticker object <ALL-B>,
#  'ALL-G': yfinance.Ticker object <ALL-G>,
#  'ALL-H': yfinance.Ticker object <ALL-H>,
#  'ALL-I': yfinance.Ticker object <ALL-I>,
#  'ALLE': yfinance.Ticker object <ALLE>,
#  'ALLK': yfinance.Ticker object <ALLK>,
#  'ALLO': yfinance.Ticker object <ALLO>,
#  'ALLT': yfinance.Ticker object <ALLT>,
#  'ALLY': yfinance.Ticker object <ALLY>,
#  'ALLY-A': yfinance.Ticker object <ALLY-A>,
#  'ALNA': yfinance.Ticker object <ALNA>,
#  'ALNY': yfinance.Ticker object <ALNY>,
#  'ALOT': yfinance.Ticker object <ALOT>,
#  'ALP-Q': yfinance.Ticker object <ALP-Q>,
#  'ALPN': yfinance.Ticker object <ALPN>,
#  'ALRM': yfinance.Ticker object <ALRM>,
#  'ALRN': yfinance.Ticker object <ALRN>,
#  'ALRS': yfinance.Ticker object <ALRS>,
#  'ALSK': yfinance.Ticker object <ALSK>,
#  'ALSN': yfinance.Ticker object <ALSN>,
#  'ALT': yfinance.Ticker object <ALT>,
#  'ALTG-A': yfinance.Ticker object <ALTG-A>,
#  'ALTL': yfinance.Ticker object <ALTL>,
#  'ALTM': yfinance.Ticker object <ALTM>,
#  'ALTO': yfinance.Ticker object <ALTO>,
#  'ALTR': yfinance.Ticker object <ALTR>,
#  'ALTS': yfinance.Ticker object <ALTS>,
#  'ALTU': yfinance.Ticker object <ALTU>,
#  'ALTUU': yfinance.Ticker object <ALTUU>,
#  'ALTY': yfinance.Ticker object <ALTY>,
#  'ALUS': yfinance.Ticker object <ALUS>,
#  'ALUS.U': yfinance.Ticker object <ALUS.U>,
#  'ALV': yfinance.Ticker object <ALV>,
#  'ALVR': yfinance.Ticker object <ALVR>,
#  'ALX': yfinance.Ticker object <ALX>,
#  'ALXN': yfinance.Ticker object <ALXN>,
#  'ALXO': yfinance.Ticker object <ALXO>,
#  'ALYA': yfinance.Ticker object <ALYA>,
#  'AM': yfinance.Ticker object <AM>,
#  'AMAL': yfinance.Ticker object <AMAL>,
#  'AMAOU': yfinance.Ticker object <AMAOU>,
#  'AMAT': yfinance.Ticker object <AMAT>,
#  'AMBA': yfinance.Ticker object <AMBA>,
#  'AMBC': yfinance.Ticker object <AMBC>,
#  'AMBO': yfinance.Ticker object <AMBO>,
#  'AMCA': yfinance.Ticker object <AMCA>,
#  'AMCR': yfinance.Ticker object <AMCR>,
#  'AMCX': yfinance.Ticker object <AMCX>,
#  'AMD': yfinance.Ticker object <AMD>,
#  'AME': yfinance.Ticker object <AME>,
#  'AMED': yfinance.Ticker object <AMED>,
#  'AMER': yfinance.Ticker object <AMER>,
#  'AMG': yfinance.Ticker object <AMG>,
#  'AMGN': yfinance.Ticker object <AMGN>,
#  'AMH': yfinance.Ticker object <AMH>,
#  'AMH-D': yfinance.Ticker object <AMH-D>,
#  'AMH-E': yfinance.Ticker object <AMH-E>,
#  'AMH-G': yfinance.Ticker object <AMH-G>,
#  'AMH-H': yfinance.Ticker object <AMH-H>,
#  'AMHC': yfinance.Ticker object <AMHC>,
#  'AMHCU': yfinance.Ticker object <AMHCU>,
#  'AMJ': yfinance.Ticker object <AMJ>,
#  'AMK': yfinance.Ticker object <AMK>,
#  'AMKR': yfinance.Ticker object <AMKR>,
#  'AMLP': yfinance.Ticker object <AMLP>,
#  'AMN': yfinance.Ticker object <AMN>,
#  'AMNA': yfinance.Ticker object <AMNA>,
#  'AMNB': yfinance.Ticker object <AMNB>,
#  'AMND': yfinance.Ticker object <AMND>,
#  'AMOM': yfinance.Ticker object <AMOM>,
#  'AMOT': yfinance.Ticker object <AMOT>,
#  'AMOV': yfinance.Ticker object <AMOV>,
#  'AMP': yfinance.Ticker object <AMP>,
#  'AMPE': yfinance.Ticker object <AMPE>,
#  'AMPG': yfinance.Ticker object <AMPG>,
#  'AMPH': yfinance.Ticker object <AMPH>,
#  'AMPI': yfinance.Ticker object <AMPI>,
#  'AMPI.U': yfinance.Ticker object <AMPI.U>,
#  'AMPY': yfinance.Ticker object <AMPY>,
#  'AMR': yfinance.Ticker object <AMR>,
#  'AMRB': yfinance.Ticker object <AMRB>,
#  'AMRC': yfinance.Ticker object <AMRC>,
#  'AMRK': yfinance.Ticker object <AMRK>,
#  'AMRN': yfinance.Ticker object <AMRN>,
#  'AMRS': yfinance.Ticker object <AMRS>,
#  'AMRX': yfinance.Ticker object <AMRX>,
#  'AMS': yfinance.Ticker object <AMS>,
#  'AMSC': yfinance.Ticker object <AMSC>,
#  'AMSF': yfinance.Ticker object <AMSF>,
#  'AMST': yfinance.Ticker object <AMST>,
#  'AMSWA': yfinance.Ticker object <AMSWA>,
#  'AMT': yfinance.Ticker object <AMT>,
#  'AMTB': yfinance.Ticker object <AMTB>,
#  'AMTI': yfinance.Ticker object <AMTI>,
#  'AMTR': yfinance.Ticker object <AMTR>,
#  'AMTX': yfinance.Ticker object <AMTX>,
#  'AMUB': yfinance.Ticker object <AMUB>,
#  'AMWD': yfinance.Ticker object <AMWD>,
#  'AMYT': yfinance.Ticker object <AMYT>,
#  'AN': yfinance.Ticker object <AN>,
#  'ANAB': yfinance.Ticker object <ANAB>,
#  'ANAC': yfinance.Ticker object <ANAC>,
#  'ANAC.U': yfinance.Ticker object <ANAC.U>,
#  'ANDA': yfinance.Ticker object <ANDA>,
#  'ANDAR': yfinance.Ticker object <ANDAR>,
#  'ANDAU': yfinance.Ticker object <ANDAU>,
#  'ANDE': yfinance.Ticker object <ANDE>,
#  'ANET': yfinance.Ticker object <ANET>,
#  'ANEW': yfinance.Ticker object <ANEW>,
#  'ANF': yfinance.Ticker object <ANF>,
#  'ANFIF': yfinance.Ticker object <ANFIF>,
#  'ANGI': yfinance.Ticker object <ANGI>,
#  'ANGL': yfinance.Ticker object <ANGL>,
#  'ANGN': yfinance.Ticker object <ANGN>,
#  'ANGO': yfinance.Ticker object <ANGO>,
#  'ANIK': yfinance.Ticker object <ANIK>,
#  'ANIP': yfinance.Ticker object <ANIP>,
#  'ANIX': yfinance.Ticker object <ANIX>,
#  'ANNX': yfinance.Ticker object <ANNX>,
#  'ANPC': yfinance.Ticker object <ANPC>,
#  'ANSS': yfinance.Ticker object <ANSS>,
#  'ANTE': yfinance.Ticker object <ANTE>,
#  'ANTH': yfinance.Ticker object <ANTH>,
#  'ANTM': yfinance.Ticker object <ANTM>,
#  'ANVS': yfinance.Ticker object <ANVS>,
#  'ANY': yfinance.Ticker object <ANY>,
#  'ANZUU': yfinance.Ticker object <ANZUU>,
#  'AOA': yfinance.Ticker object <AOA>,
#  'AOD': yfinance.Ticker object <AOD>,
#  'AOK': yfinance.Ticker object <AOK>,
#  'AOM': yfinance.Ticker object <AOM>,
#  'AON': yfinance.Ticker object <AON>,
#  'AONE': yfinance.Ticker object <AONE>,
#  'AONE.U': yfinance.Ticker object <AONE.U>,
#  'AOR': yfinance.Ticker object <AOR>,
#  'AOS': yfinance.Ticker object <AOS>,
#  'AOSL': yfinance.Ticker object <AOSL>,
#  'AOUT': yfinance.Ticker object <AOUT>,
#  'AP': yfinance.Ticker object <AP>,
#  'APA': yfinance.Ticker object <APA>,
#  'APAM': yfinance.Ticker object <APAM>,
#  'APD': yfinance.Ticker object <APD>,
#  'APEI': yfinance.Ticker object <APEI>,
#  'APEN': yfinance.Ticker object <APEN>,
#  'APG': yfinance.Ticker object <APG>,
#  'APGB': yfinance.Ticker object <APGB>,
#  'APGB.U': yfinance.Ticker object <APGB.U>,
#  'APH': yfinance.Ticker object <APH>,
#  'APHA': yfinance.Ticker object <APHA>,
#  'API': yfinance.Ticker object <API>,
#  'APLE': yfinance.Ticker object <APLE>,
#  'APLS': yfinance.Ticker object <APLS>,
#  'APLT': yfinance.Ticker object <APLT>,
#  'APM': yfinance.Ticker object <APM>,
#  'APO': yfinance.Ticker object <APO>,
#  'APO-A': yfinance.Ticker object <APO-A>,
#  'APO-B': yfinance.Ticker object <APO-B>,
#  'APOG': yfinance.Ticker object <APOG>,
#  'APOP': yfinance.Ticker object <APOP>,
#  'APP': yfinance.Ticker object <APP>,
#  'APPF': yfinance.Ticker object <APPF>,
#  'APPH': yfinance.Ticker object <APPH>,
#  'APPN': yfinance.Ticker object <APPN>,
#  'APPS': yfinance.Ticker object <APPS>,
#  'APR': yfinance.Ticker object <APR>,
#  'APRE': yfinance.Ticker object <APRE>,
#  'APRN': yfinance.Ticker object <APRN>,
#  'APRZ': yfinance.Ticker object <APRZ>,
#  'APSG': yfinance.Ticker object <APSG>,
#  'APSG.U': yfinance.Ticker object <APSG.U>,
#  'APT': yfinance.Ticker object <APT>,
#  'APTO': yfinance.Ticker object <APTO>,
#  'APTS': yfinance.Ticker object <APTS>,
#  'APTV': yfinance.Ticker object <APTV>,
#  'APTV-A': yfinance.Ticker object <APTV-A>,
#  'APTX': yfinance.Ticker object <APTX>,
#  'APVO': yfinance.Ticker object <APVO>,
#  'APWC': yfinance.Ticker object <APWC>,
#  'APXT': yfinance.Ticker object <APXT>,
#  'APXTU': yfinance.Ticker object <APXTU>,
#  'APYX': yfinance.Ticker object <APYX>,
#  'AQB': yfinance.Ticker object <AQB>,
#  'AQMS': yfinance.Ticker object <AQMS>,
#  'AQN': yfinance.Ticker object <AQN>,
#  'AQNA': yfinance.Ticker object <AQNA>,
#  'AQNB': yfinance.Ticker object <AQNB>,
#  'AQST': yfinance.Ticker object <AQST>,
#  'AQUA': yfinance.Ticker object <AQUA>,
#  'AQWA': yfinance.Ticker object <AQWA>,
#  'AR': yfinance.Ticker object <AR>,
#  'ARAV': yfinance.Ticker object <ARAV>,
#  'ARAY': yfinance.Ticker object <ARAY>,
#  'ARB': yfinance.Ticker object <ARB>,
#  'ARBG': yfinance.Ticker object <ARBG>,
#  'ARBGU': yfinance.Ticker object <ARBGU>,
#  'ARC': yfinance.Ticker object <ARC>,
#  'ARCB': yfinance.Ticker object <ARCB>,
#  'ARCC': yfinance.Ticker object <ARCC>,
#  'ARCE': yfinance.Ticker object <ARCE>,
#  'ARCH': yfinance.Ticker object <ARCH>,
#  'ARCM': yfinance.Ticker object <ARCM>,
#  'ARCO': yfinance.Ticker object <ARCO>,
#  'ARCT': yfinance.Ticker object <ARCT>,
#  'ARCW': yfinance.Ticker object <ARCW>,
#  'ARD': yfinance.Ticker object <ARD>,
#  'ARDC': yfinance.Ticker object <ARDC>,
#  'ARDS': yfinance.Ticker object <ARDS>,
#  'ARDX': yfinance.Ticker object <ARDX>,
#  'ARE': yfinance.Ticker object <ARE>,
#  'AREC': yfinance.Ticker object <AREC>,
#  'ARES': yfinance.Ticker object <ARES>,
#  'ARES-A': yfinance.Ticker object <ARES-A>,
#  'ARGD': yfinance.Ticker object <ARGD>,
#  'ARGO': yfinance.Ticker object <ARGO>,
#  'ARGO-A': yfinance.Ticker object <ARGO-A>,
#  'ARGT': yfinance.Ticker object <ARGT>,
#  'ARGX': yfinance.Ticker object <ARGX>,
#  'ARI': yfinance.Ticker object <ARI>,
#  'ARKF': yfinance.Ticker object <ARKF>,
#  'ARKG': yfinance.Ticker object <ARKG>,
#  'ARKK': yfinance.Ticker object <ARKK>,
#  'ARKO': yfinance.Ticker object <ARKO>,
#  'ARKQ': yfinance.Ticker object <ARKQ>,
#  'ARKR': yfinance.Ticker object <ARKR>,
#  'ARKW': yfinance.Ticker object <ARKW>,
#  'ARKX': yfinance.Ticker object <ARKX>,
#  'ARL': yfinance.Ticker object <ARL>,
#  'ARLO': yfinance.Ticker object <ARLO>,
#  'ARLP': yfinance.Ticker object <ARLP>,
#  'ARMK': yfinance.Ticker object <ARMK>,
#  'ARMP': yfinance.Ticker object <ARMP>,
#  'ARMR': yfinance.Ticker object <ARMR>,
#  'ARNA': yfinance.Ticker object <ARNA>,
#  'ARNC': yfinance.Ticker object <ARNC>,
#  'AROC': yfinance.Ticker object <AROC>,
#  'AROW': yfinance.Ticker object <AROW>,
#  'ARPO': yfinance.Ticker object <ARPO>,
#  'ARQT': yfinance.Ticker object <ARQT>,
#  'ARR': yfinance.Ticker object <ARR>,
#  'ARR-C': yfinance.Ticker object <ARR-C>,
#  'ARRW': yfinance.Ticker object <ARRW>,
#  'ARRY': yfinance.Ticker object <ARRY>,
#  'ARTL': yfinance.Ticker object <ARTL>,
#  'ARTNA': yfinance.Ticker object <ARTNA>,
#  'ARTW': yfinance.Ticker object <ARTW>,
#  'ARVL': yfinance.Ticker object <ARVL>,
#  'ARVN': yfinance.Ticker object <ARVN>,
#  'ARW': yfinance.Ticker object <ARW>,
#  'ARWR': yfinance.Ticker object <ARWR>,
#  'ARYA': yfinance.Ticker object <ARYA>,
#  'ARYD': yfinance.Ticker object <ARYD>,
#  'ASA': yfinance.Ticker object <ASA>,
#  'ASAI': yfinance.Ticker object <ASAI>,
#  'ASAN': yfinance.Ticker object <ASAN>,
#  'ASAQ': yfinance.Ticker object <ASAQ>,
#  'ASAQ.U': yfinance.Ticker object <ASAQ.U>,
#  'ASAX': yfinance.Ticker object <ASAX>,
#  'ASAXU': yfinance.Ticker object <ASAXU>,
#  'ASB': yfinance.Ticker object <ASB>,
#  'ASB-D': yfinance.Ticker object <ASB-D>,
#  'ASB-E': yfinance.Ticker object <ASB-E>,
#  'ASB-F': yfinance.Ticker object <ASB-F>,
#  'ASC': yfinance.Ticker object <ASC>,
#  'ASEA': yfinance.Ticker object <ASEA>,
#  'ASET': yfinance.Ticker object <ASET>,
#  'ASG': yfinance.Ticker object <ASG>,
#  'ASGI': yfinance.Ticker object <ASGI>,
#  'ASGN': yfinance.Ticker object <ASGN>,
#  'ASH': yfinance.Ticker object <ASH>,
#  'ASHR': yfinance.Ticker object <ASHR>,
#  'ASHS': yfinance.Ticker object <ASHS>,
#  'ASHX': yfinance.Ticker object <ASHX>,
#  'ASIX': yfinance.Ticker object <ASIX>,
#  'ASLE': yfinance.Ticker object <ASLE>,
#  'ASLN': yfinance.Ticker object <ASLN>,
#  'ASM': yfinance.Ticker object <ASM>,
#  'ASMB': yfinance.Ticker object <ASMB>,
#  'ASML': yfinance.Ticker object <ASML>,
#  'ASND': yfinance.Ticker object <ASND>,
#  'ASPC': yfinance.Ticker object <ASPC>,
#  'ASPCU': yfinance.Ticker object <ASPCU>,
#  'ASPL': yfinance.Ticker object <ASPL>,
#  'ASPL.U': yfinance.Ticker object <ASPL.U>,
#  'ASPN': yfinance.Ticker object <ASPN>,
#  'ASPS': yfinance.Ticker object <ASPS>,
#  'ASPU': yfinance.Ticker object <ASPU>,
#  'ASPY': yfinance.Ticker object <ASPY>,
#  'ASR': yfinance.Ticker object <ASR>,
#  'ASRT': yfinance.Ticker object <ASRT>,
#  'ASRV': yfinance.Ticker object <ASRV>,
#  'ASRVP': yfinance.Ticker object <ASRVP>,
#  'ASTC': yfinance.Ticker object <ASTC>,
#  'ASTS': yfinance.Ticker object <ASTS>,
#  'ASUR': yfinance.Ticker object <ASUR>,
#  'ASX': yfinance.Ticker object <ASX>,
#  'ASXC': yfinance.Ticker object <ASXC>,
#  'ASYS': yfinance.Ticker object <ASYS>,
#  'ASZ': yfinance.Ticker object <ASZ>,
#  'ASZ.U': yfinance.Ticker object <ASZ.U>,
#  'AT': yfinance.Ticker object <AT>,
#  'ATA': yfinance.Ticker object <ATA>,
#  'ATA.U': yfinance.Ticker object <ATA.U>,
#  'ATAC': yfinance.Ticker object <ATAC>,
#  'ATAC.U': yfinance.Ticker object <ATAC.U>,
#  'ATAQ': yfinance.Ticker object <ATAQ>,
#  'ATAQ.U': yfinance.Ticker object <ATAQ.U>,
#  'ATAX': yfinance.Ticker object <ATAX>,
#  'ATC': yfinance.Ticker object <ATC>,
#  'ATCO': yfinance.Ticker object <ATCO>,
#  'ATCO-D': yfinance.Ticker object <ATCO-D>,
#  'ATCO-E': yfinance.Ticker object <ATCO-E>,
#  'ATCO-G': yfinance.Ticker object <ATCO-G>,
#  'ATCO-H': yfinance.Ticker object <ATCO-H>,
#  'ATCO-I': yfinance.Ticker object <ATCO-I>,
#  'ATCX': yfinance.Ticker object <ATCX>,
#  'ATEC': yfinance.Ticker object <ATEC>,
#  'ATEN': yfinance.Ticker object <ATEN>,
#  'ATEX': yfinance.Ticker object <ATEX>,
#  'ATGE': yfinance.Ticker object <ATGE>,
#  'ATH': yfinance.Ticker object <ATH>,
#  'ATH-A': yfinance.Ticker object <ATH-A>,
#  'ATH-B': yfinance.Ticker object <ATH-B>,
#  'ATH-C': yfinance.Ticker object <ATH-C>,
#  'ATH-D': yfinance.Ticker object <ATH-D>,
#  'ATHA': yfinance.Ticker object <ATHA>,
#  'ATHE': yfinance.Ticker object <ATHE>,
#  'ATHM': yfinance.Ticker object <ATHM>,
#  'ATHN.U': yfinance.Ticker object <ATHN.U>,
#  'ATHX': yfinance.Ticker object <ATHX>,
#  'ATI': yfinance.Ticker object <ATI>,
#  'ATIF': yfinance.Ticker object <ATIF>,
#  'ATKR': yfinance.Ticker object <ATKR>,
#  'ATLC': yfinance.Ticker object <ATLC>,
#  'ATLO': yfinance.Ticker object <ATLO>,
#  'ATMP': yfinance.Ticker object <ATMP>,
#  'ATMR': yfinance.Ticker object <ATMR>,
#  'ATMR.U': yfinance.Ticker object <ATMR.U>,
#  'ATNF': yfinance.Ticker object <ATNF>,
#  'ATNI': yfinance.Ticker object <ATNI>,
#  'ATNM': yfinance.Ticker object <ATNM>,
#  'ATNX': yfinance.Ticker object <ATNX>,
#  'ATO': yfinance.Ticker object <ATO>,
#  'ATOM': yfinance.Ticker object <ATOM>,
#  'ATOS': yfinance.Ticker object <ATOS>,
#  'ATR': yfinance.Ticker object <ATR>,
#  'ATRA': yfinance.Ticker object <ATRA>,
#  'ATRC': yfinance.Ticker object <ATRC>,
#  'ATRI': yfinance.Ticker object <ATRI>,
#  'ATRO': yfinance.Ticker object <ATRO>,
#  'ATRS': yfinance.Ticker object <ATRS>,
#  'ATSG': yfinance.Ticker object <ATSG>,
#  'ATSPT': yfinance.Ticker object <ATSPT>,
#  'ATSPU': yfinance.Ticker object <ATSPU>,
#  'ATTO': yfinance.Ticker object <ATTO>,
#  'ATUS': yfinance.Ticker object <ATUS>,
#  'ATVCU': yfinance.Ticker object <ATVCU>,
#  'ATVI': yfinance.Ticker object <ATVI>,
#  'ATXI': yfinance.Ticker object <ATXI>,
#  'AU': yfinance.Ticker object <AU>,
#  'AUB': yfinance.Ticker object <AUB>,
#  'AUBAP': yfinance.Ticker object <AUBAP>,
#  'AUBN': yfinance.Ticker object <AUBN>,
#  'AUD': yfinance.Ticker object <AUD>,
#  'AUDC': yfinance.Ticker object <AUDC>,
#  'AUGZ': yfinance.Ticker object <AUGZ>,
#  'AUPH': yfinance.Ticker object <AUPH>,
#  'AURCU': yfinance.Ticker object <AURCU>,
#  'AUS': yfinance.Ticker object <AUS>,
#  'AUS.U': yfinance.Ticker object <AUS.U>,
#  'AUSF': yfinance.Ticker object <AUSF>,
#  'AUTO': yfinance.Ticker object <AUTO>,
#  'AUUD': yfinance.Ticker object <AUUD>,
#  'AUVI': yfinance.Ticker object <AUVI>,
#  'AUY': yfinance.Ticker object <AUY>,
#  'AVA': yfinance.Ticker object <AVA>,
#  'AVAL': yfinance.Ticker object <AVAL>,
#  'AVAN': yfinance.Ticker object <AVAN>,
#  'AVAN.U': yfinance.Ticker object <AVAN.U>,
#  'AVAV': yfinance.Ticker object <AVAV>,
#  'AVB': yfinance.Ticker object <AVB>,
#  'AVCO': yfinance.Ticker object <AVCO>,
#  'AVCT': yfinance.Ticker object <AVCT>,
#  'AVD': yfinance.Ticker object <AVD>,
#  'AVDE': yfinance.Ticker object <AVDE>,
#  'AVDG': yfinance.Ticker object <AVDG>,
#  'AVDL': yfinance.Ticker object <AVDL>,
#  'AVDR': yfinance.Ticker object <AVDR>,
#  'AVDV': yfinance.Ticker object <AVDV>,
#  'AVEM': yfinance.Ticker object <AVEM>,
#  'AVEO': yfinance.Ticker object <AVEO>,
#  'AVGO': yfinance.Ticker object <AVGO>,
#  'AVGOP': yfinance.Ticker object <AVGOP>,
#  'AVGR': yfinance.Ticker object <AVGR>,
#  'AVHOQ': yfinance.Ticker object <AVHOQ>,
#  'AVID': yfinance.Ticker object <AVID>,
#  'AVIG': yfinance.Ticker object <AVIG>,
#  'AVIR': yfinance.Ticker object <AVIR>,
#  'AVK': yfinance.Ticker object <AVK>,
#  'AVLR': yfinance.Ticker object <AVLR>,
#  'AVMU': yfinance.Ticker object <AVMU>,
#  'AVNS': yfinance.Ticker object <AVNS>,
#  'AVNT': yfinance.Ticker object <AVNT>,
#  'AVNW': yfinance.Ticker object <AVNW>,
#  'AVO': yfinance.Ticker object <AVO>,
#  'AVRO': yfinance.Ticker object <AVRO>,
#  'AVT': yfinance.Ticker object <AVT>,
#  'AVTR': yfinance.Ticker object <AVTR>,
#  'AVTR-A': yfinance.Ticker object <AVTR-A>,
#  'AVUS': yfinance.Ticker object <AVUS>,
#  'AVUV': yfinance.Ticker object <AVUV>,
#  'AVXL': yfinance.Ticker object <AVXL>,
#  'AVYA': yfinance.Ticker object <AVYA>,
#  'AWAY': yfinance.Ticker object <AWAY>,
#  'AWF': yfinance.Ticker object <AWF>,
#  'AWH': yfinance.Ticker object <AWH>,
#  'AWI': yfinance.Ticker object <AWI>,
#  'AWK': yfinance.Ticker object <AWK>,
#  'AWR': yfinance.Ticker object <AWR>,
#  'AWRE': yfinance.Ticker object <AWRE>,
#  'AWTM': yfinance.Ticker object <AWTM>,
#  'AWX': yfinance.Ticker object <AWX>,
#  'AX': yfinance.Ticker object <AX>,
#  'AXAS': yfinance.Ticker object <AXAS>,
#  'AXDX': yfinance.Ticker object <AXDX>,
#  'AXGN': yfinance.Ticker object <AXGN>,
#  'AXL': yfinance.Ticker object <AXL>,
#  'AXLA': yfinance.Ticker object <AXLA>,
#  'AXNX': yfinance.Ticker object <AXNX>,
#  'AXON': yfinance.Ticker object <AXON>,
#  'AXP': yfinance.Ticker object <AXP>,
#  'AXR': yfinance.Ticker object <AXR>,
#  'AXS': yfinance.Ticker object <AXS>,
#  'AXS-E': yfinance.Ticker object <AXS-E>,
#  'AXSM': yfinance.Ticker object <AXSM>,
#  'AXTA': yfinance.Ticker object <AXTA>,
#  'AXTI': yfinance.Ticker object <AXTI>,
#  'AXU': yfinance.Ticker object <AXU>,
#  'AY': yfinance.Ticker object <AY>,
#  'AYI': yfinance.Ticker object <AYI>,
#  'AYLA': yfinance.Ticker object <AYLA>,
#  'AYRO': yfinance.Ticker object <AYRO>,
#  'AYTU': yfinance.Ticker object <AYTU>,
#  'AYX': yfinance.Ticker object <AYX>,
#  'AZAA': yfinance.Ticker object <AZAA>,
#  'AZAJ': yfinance.Ticker object <AZAJ>,
#  'AZAL': yfinance.Ticker object <AZAL>,
#  'AZAO': yfinance.Ticker object <AZAO>,
#  'AZBA': yfinance.Ticker object <AZBA>,
#  'AZBJ': yfinance.Ticker object <AZBJ>,
#  'AZBL': yfinance.Ticker object <AZBL>,
#  'AZBO': yfinance.Ticker object <AZBO>,
#  'AZEK': yfinance.Ticker object <AZEK>,
#  'AZN': yfinance.Ticker object <AZN>,
#  'AZO': yfinance.Ticker object <AZO>,
#  'AZPN': yfinance.Ticker object <AZPN>,
#  'AZRE': yfinance.Ticker object <AZRE>,
#  'AZRX': yfinance.Ticker object <AZRX>,
#  'AZUL': yfinance.Ticker object <AZUL>,
#  'AZYO': yfinance.Ticker object <AZYO>,
#  'AZZ': yfinance.Ticker object <AZZ>,
#  'B': yfinance.Ticker object <B>,
#  'BA': yfinance.Ticker object <BA>,
#  'BAB': yfinance.Ticker object <BAB>,
#  'BAC': yfinance.Ticker object <BAC>,
#  'BAC-B': yfinance.Ticker object <BAC-B>,
#  'BAC-E': yfinance.Ticker object <BAC-E>,
#  'BAC-K': yfinance.Ticker object <BAC-K>,
#  'BAC-L': yfinance.Ticker object <BAC-L>,
#  'BAC-M': yfinance.Ticker object <BAC-M>,
#  'BAC-N': yfinance.Ticker object <BAC-N>,
#  'BAC-O': yfinance.Ticker object <BAC-O>,
#  'BAC-P': yfinance.Ticker object <BAC-P>,
#  'BAH': yfinance.Ticker object <BAH>,
#  'BAK': yfinance.Ticker object <BAK>,
#  'BAL': yfinance.Ticker object <BAL>,
#  'BALY': yfinance.Ticker object <BALY>,
#  'BAMH': yfinance.Ticker object <BAMH>,
#  'BAMI': yfinance.Ticker object <BAMI>,
#  'BANC': yfinance.Ticker object <BANC>,
#  'BANC-E': yfinance.Ticker object <BANC-E>,
#  'BAND': yfinance.Ticker object <BAND>,
#  'BANF': yfinance.Ticker object <BANF>,
#  'BANFP': yfinance.Ticker object <BANFP>,
#  'BANR': yfinance.Ticker object <BANR>,
#  'BANX': yfinance.Ticker object <BANX>,
#  'BAOS': yfinance.Ticker object <BAOS>,
#  'BAP': yfinance.Ticker object <BAP>,
#  'BAPR': yfinance.Ticker object <BAPR>,
#  'BAR': yfinance.Ticker object <BAR>,
#  'BASX': yfinance.Ticker object <BASX>,
#  'BATL': yfinance.Ticker object <BATL>,
#  'BATRA': yfinance.Ticker object <BATRA>,
#  'BATRK': yfinance.Ticker object <BATRK>,
#  'BATT': yfinance.Ticker object <BATT>,
#  'BAUG': yfinance.Ticker object <BAUG>,
#  'BAX': yfinance.Ticker object <BAX>,
#  'BB': yfinance.Ticker object <BB>,
#  'BBAR': yfinance.Ticker object <BBAR>,
#  'BBAX': yfinance.Ticker object <BBAX>,
#  'BBBY': yfinance.Ticker object <BBBY>,
#  'BBC': yfinance.Ticker object <BBC>,
#  'BBCA': yfinance.Ticker object <BBCA>,
#  'BBCP': yfinance.Ticker object <BBCP>,
#  'BBD': yfinance.Ticker object <BBD>,
#  'BBDC': yfinance.Ticker object <BBDC>,
#  'BBDO': yfinance.Ticker object <BBDO>,
#  'BBEU': yfinance.Ticker object <BBEU>,
#  'BBGI': yfinance.Ticker object <BBGI>,
#  'BBH': yfinance.Ticker object <BBH>,
#  'BBI': yfinance.Ticker object <BBI>,
#  'BBIG': yfinance.Ticker object <BBIG>,
#  'BBIN': yfinance.Ticker object <BBIN>,
#  'BBIO': yfinance.Ticker object <BBIO>,
#  'BBJP': yfinance.Ticker object <BBJP>,
#  'BBL': yfinance.Ticker object <BBL>,
#  'BBMC': yfinance.Ticker object <BBMC>,
#  'BBN': yfinance.Ticker object <BBN>,
#  'BBP': yfinance.Ticker object <BBP>,
#  'BBQ': yfinance.Ticker object <BBQ>,
#  'BBRE': yfinance.Ticker object <BBRE>,
#  'BBSA': yfinance.Ticker object <BBSA>,
#  'BBSC': yfinance.Ticker object <BBSC>,
#  'BBSI': yfinance.Ticker object <BBSI>,
#  'BBU': yfinance.Ticker object <BBU>,
#  'BBUS': yfinance.Ticker object <BBUS>,
#  'BBVA': yfinance.Ticker object <BBVA>,
#  'BBW': yfinance.Ticker object <BBW>,
#  'BBY': yfinance.Ticker object <BBY>,
#  'BC': yfinance.Ticker object <BC>,
#  'BC-A': yfinance.Ticker object <BC-A>,
#  'BC-B': yfinance.Ticker object <BC-B>,
#  'BC-C': yfinance.Ticker object <BC-C>,
#  'BCAB': yfinance.Ticker object <BCAB>,
#  'BCAC': yfinance.Ticker object <BCAC>,
#  'BCACU': yfinance.Ticker object <BCACU>,
#  'BCAT': yfinance.Ticker object <BCAT>,
#  'BCBP': yfinance.Ticker object <BCBP>,
#  'BCC': yfinance.Ticker object <BCC>,
#  'BCD': yfinance.Ticker object <BCD>,
#  'BCDA': yfinance.Ticker object <BCDA>,
#  'BCE': yfinance.Ticker object <BCE>,
#  'BCEI': yfinance.Ticker object <BCEI>,
#  'BCEL': yfinance.Ticker object <BCEL>,
#  'BCH': yfinance.Ticker object <BCH>,
#  'BCI': yfinance.Ticker object <BCI>,
#  'BCLI': yfinance.Ticker object <BCLI>,
#  'BCM': yfinance.Ticker object <BCM>,
#  'BCML': yfinance.Ticker object <BCML>,
#  'BCOMF': yfinance.Ticker object <BCOMF>,
#  'BCOR': yfinance.Ticker object <BCOR>,
#  'BCOV': yfinance.Ticker object <BCOV>,
#  'BCOW': yfinance.Ticker object <BCOW>,
#  'BCPC': yfinance.Ticker object <BCPC>,
#  'BCRHF': yfinance.Ticker object <BCRHF>,
#  'BCRX': yfinance.Ticker object <BCRX>,
#  'BCS': yfinance.Ticker object <BCS>,
#  'BCSF': yfinance.Ticker object <BCSF>,
#  'BCTF': yfinance.Ticker object <BCTF>,
#  'BCTG': yfinance.Ticker object <BCTG>,
#  'BCTX': yfinance.Ticker object <BCTX>,
#  'BCV': yfinance.Ticker object <BCV>,
#  'BCV-A': yfinance.Ticker object <BCV-A>,
#  'BCX': yfinance.Ticker object <BCX>,
#  'BCYP': yfinance.Ticker object <BCYP>,
#  'BCYPU': yfinance.Ticker object <BCYPU>,
#  'BDC': yfinance.Ticker object <BDC>,
#  'BDCX': yfinance.Ticker object <BDCX>,
#  'BDCZ': yfinance.Ticker object <BDCZ>,
#  'BDDXF': yfinance.Ticker object <BDDXF>,
#  'BDEC': yfinance.Ticker object <BDEC>,
#  'BDJ': yfinance.Ticker object <BDJ>,
#  'BDL': yfinance.Ticker object <BDL>,
#  'BDN': yfinance.Ticker object <BDN>,
#  'BDR': yfinance.Ticker object <BDR>,
#  'BDRY': yfinance.Ticker object <BDRY>,
#  'BDSI': yfinance.Ticker object <BDSI>,
#  'BDSX': yfinance.Ticker object <BDSX>,
#  'BDTX': yfinance.Ticker object <BDTX>,
#  'BDX': yfinance.Ticker object <BDX>,
#  'BDXB': yfinance.Ticker object <BDXB>,
#  'BE': yfinance.Ticker object <BE>,
#  'BEAM': yfinance.Ticker object <BEAM>,
#  'BECN': yfinance.Ticker object <BECN>,
#  'BEDU': yfinance.Ticker object <BEDU>,
#  'BEDZ': yfinance.Ticker object <BEDZ>,
#  'BEEM': yfinance.Ticker object <BEEM>,
#  'BEKE': yfinance.Ticker object <BEKE>,
#  'BELFA': yfinance.Ticker object <BELFA>,
#  'BELFB': yfinance.Ticker object <BELFB>,
#  'BEN': yfinance.Ticker object <BEN>,
#  'BENE': yfinance.Ticker object <BENE>,
#  'BENER': yfinance.Ticker object <BENER>,
#  'BENEU': yfinance.Ticker object <BENEU>,
#  'BEP': yfinance.Ticker object <BEP>,
#  'BEP-A': yfinance.Ticker object <BEP-A>,
#  'BEPC': yfinance.Ticker object <BEPC>,
#  'BEPH': yfinance.Ticker object <BEPH>,
#  'BERY': yfinance.Ticker object <BERY>,
#  'BEST': yfinance.Ticker object <BEST>,
#  'BETZ': yfinance.Ticker object <BETZ>,
#  'BF.A': yfinance.Ticker object <BF.A>,
#  'BF.B': yfinance.Ticker object <BF.B>,
#  'BFAM': yfinance.Ticker object <BFAM>,
#  'BFC': yfinance.Ticker object <BFC>,
#  'BFEB': yfinance.Ticker object <BFEB>,
#  'BFI': yfinance.Ticker object <BFI>,
#  'BFIN': yfinance.Ticker object <BFIN>,
#  'BFIT': yfinance.Ticker object <BFIT>,
#  'BFK': yfinance.Ticker object <BFK>,
#  'BFLY': yfinance.Ticker object <BFLY>,
#  'BFOR': yfinance.Ticker object <BFOR>,
#  'BFS': yfinance.Ticker object <BFS>,
#  'BFS-D': yfinance.Ticker object <BFS-D>,
#  'BFS-E': yfinance.Ticker object <BFS-E>,
#  'BFST': yfinance.Ticker object <BFST>,
#  'BFTR': yfinance.Ticker object <BFTR>,
#  'BFZ': yfinance.Ticker object <BFZ>,
#  'BG': yfinance.Ticker object <BG>,
#  'BGB': yfinance.Ticker object <BGB>,
#  'BGCP': yfinance.Ticker object <BGCP>,
#  'BGFV': yfinance.Ticker object <BGFV>,
#  'BGH': yfinance.Ticker object <BGH>,
#  'BGI': yfinance.Ticker object <BGI>,
#  'BGIO': yfinance.Ticker object <BGIO>,
#  'BGLD': yfinance.Ticker object <BGLD>,
#  'BGNE': yfinance.Ticker object <BGNE>,
#  'BGR': yfinance.Ticker object <BGR>,
#  'BGRN': yfinance.Ticker object <BGRN>,
#  'BGS': yfinance.Ticker object <BGS>,
#  'BGSF': yfinance.Ticker object <BGSF>,
#  'BGSX.U': yfinance.Ticker object <BGSX.U>,
#  'BGT': yfinance.Ticker object <BGT>,
#  'BGX': yfinance.Ticker object <BGX>,
#  'BGY': yfinance.Ticker object <BGY>,
#  'BH.A': yfinance.Ticker object <BH.A>,
#  'BHAT': yfinance.Ticker object <BHAT>,
#  'BHB': yfinance.Ticker object <BHB>,
#  'BHC': yfinance.Ticker object <BHC>,
#  'BHFAL': yfinance.Ticker object <BHFAL>,
#  'BHFAN': yfinance.Ticker object <BHFAN>,
#  'BHFAO': yfinance.Ticker object <BHFAO>,
#  'BHFAP': yfinance.Ticker object <BHFAP>,
#  'BHLB': yfinance.Ticker object <BHLB>,
#  'BHP': yfinance.Ticker object <BHP>,
#  'BHR': yfinance.Ticker object <BHR>,
#  'BHR-B': yfinance.Ticker object <BHR-B>,
#  'BHR-D': yfinance.Ticker object <BHR-D>,
#  'BHSE': yfinance.Ticker object <BHSE>,
#  'BHSEU': yfinance.Ticker object <BHSEU>,
#  'BHV': yfinance.Ticker object <BHV>,
#  'BHVN': yfinance.Ticker object <BHVN>,
#  'BIB': yfinance.Ticker object <BIB>,
#  'BIBL': yfinance.Ticker object <BIBL>,
#  'BICK': yfinance.Ticker object <BICK>,
#  'BIF': yfinance.Ticker object <BIF>,
#  'BIG': yfinance.Ticker object <BIG>,
#  'BIGC': yfinance.Ticker object <BIGC>,
#  'BIGZ': yfinance.Ticker object <BIGZ>,
#  'BIIB': yfinance.Ticker object <BIIB>,
#  'BIL': yfinance.Ticker object <BIL>,
#  'BILI': yfinance.Ticker object <BILI>,
#  'BILL': yfinance.Ticker object <BILL>,
#  'BILS': yfinance.Ticker object <BILS>,
#  'BIMI': yfinance.Ticker object <BIMI>,
#  'BIO': yfinance.Ticker object <BIO>,
#  'BIO.B': yfinance.Ticker object <BIO.B>,
#  'BIOC': yfinance.Ticker object <BIOC>,
#  'BIOL': yfinance.Ticker object <BIOL>,
#  'BIOT': yfinance.Ticker object <BIOT>,
#  'BIOTU': yfinance.Ticker object <BIOTU>,
#  'BIOX': yfinance.Ticker object <BIOX>,
#  ...}

# %%
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
s_and_p_500 = table[0]
